# %%
import requests
import json




username = "albert.einstein@example.com"
password = "xxxxx"

my_headers = {'content-type':'application/json'}
json_data = json.dumps({
   "email": username,
   "password": password
 })

# make an http-call to obtain a JWT-token
#response = requests.post("https://fdp.x-omics.nl/tokens", json_data, auth=('xxxx','xxxx'), headers=my_headers)
response = requests.post("https://fdp.x-omics.nl/tokens", json_data, headers=my_headers)
#response = requests.post("https://fdp.cmbi.umcn.nl/tokens", json_data, headers=my_headers) 

print(response)
#print(response.json())

# extract JWT access token
data = response.json()
print(data)
access_token = data["token"]


print(access_token)
# Out:
# <Response [200]>
# {'token': 'eyJhbGciOiJIUzI1NiJ9.eyJzdWIiOiI3ZTY0ODE4ZC02Mjc2LTQ2ZmItOGJiMS03MzJlNmUwOWY3ZTkiLCJpYXQiOjE2NDY4Njc0OTIsImV4cCI6MTY0ODA3NzA5Mn0._DL6Nez0McIMsPZ06mkU7K7dGd2r5UKDkMo5Z_fiktM'}
# eyJhbGciOiJIUzI1NiJ9.eyJzdWIiOiI3ZTY0ODE4ZC02Mjc2LTQ2ZmItOGJiMS03MzJlNmUwOWY3ZTkiLCJpYXQiOjE2NDY4Njc0OTIsImV4cCI6MTY0ODA3NzA5Mn0._DL6Nez0McIMsPZ06mkU7K7dGd2r5UKDkMo5Z_fiktM

# %%
#from rdflib import Graph

headers = {
    'Authorization': 'Bearer eyJhbGciOiJIUzI1NiJ9.eyJzdWIiOiI3ZTY0ODE4ZC02Mjc2LTQ2ZmItOGJiMS03MzJlNmUwOWY3ZTkiLCJpYXQiOjE2NDQzMDgzNjYsImV4cCI6MTY0NTUxNzk2Nn0.w5ZdoXBdw-kfC_n_L1FUxzQRizfARMMipZv4lLqfhlg',
    'Content-Type': 'text/turtle',
}


#graph = Graph()
#graph.parse('metadata.ttl', format='ttl')

#open text file in read mode
ttl_file = open("metadata.ttl", "r")
 
#read whole file to a string
payload = ttl_file.read() + "."
 
#close file
ttl_file.close()
 
print(payload)

#for s, p, o in g:
#    print(s, p, o)
response = requests.post('https://fdp.x-omics.nl/dataset/', headers=headers, data=payload)

print(response)
print(response.text)
# Out:
# @prefix dcat: <http://www.w3.org/ns/dcat#> .
# @prefix dct: <http://purl.org/dc/terms/> .
# @prefix foaf: <http://xmlns.com/foaf/0.1/> .
#
# <> a dcat:Dataset ;
#     dct:title "test" ;
#     dct:hasVersion "1.0" ;
#     dct:publisher [ a foaf:Agent ; foaf:name "Example User" ] ;
#     dcat:theme <http://www.wikidata.org/entity/Q14944328> ;
#     dct:isPartOf <https://fdp.x-omics.nl/catalog/c6c73d4f-97bb-40e7-9068-e1eeadf1f2a4> .
# <Response [201]>
# @prefix dcterms: <http://purl.org/dc/terms/> .
# @prefix dcat: <http://www.w3.org/ns/dcat#> .
# @prefix foaf: <http://xmlns.com/foaf/0.1/> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
# @prefix ldp: <http://www.w3.org/ns/ldp#> .
#
# <https://fdp.x-omics.nl/dataset/6554a235-f292-4119-ace4-f904bd719601> a dcat:Resource,
#     dcat:Dataset;
#   dcterms:title "test";
#   dcterms:hasVersion "1.0";
#   dcterms:publisher [ a foaf:Agent;
#       foaf:name "Example User"
#     ];
# ...

# %%
#below is the script for submit investigation

# %%
import requests

url = "https://fdp.x-omics.nl/dataset"

payload = "@prefix dcterms: <http://purl.org/dc/terms/> .\r\n@prefix dcat: <http://www.w3.org/ns/dcat#> .\r\n@prefix foaf: <http://xmlns.com/foaf/0.1/> .\r\n@prefix xsd: <http://www.w3.org/2001/XMLSchema#> .\r\n@prefix ldp: <http://www.w3.org/ns/ldp#> .\r\n\r\n<https://fdp.x-omics.nl/investigation/e54a55c9-9ac7-44d5-ad1e-832b5440c90d> a dcat:Resource,\r\n    <http://purl.org/biosemantics-lumc/ontologies/dcat-extension/Investigation>;\r\n  dcterms:accessRights <https://fdp.x-omics.nl/investigation/e54a55c9-9ac7-44d5-ad1e-832b5440c90d#accessRights>;\r\n  dcterms:conformsTo <https://fdp.x-omics.nl/profile/54484818-9427-413b-85f2-fefa0bd74c0a>;\r\n  dcterms:language <http://id.loc.gov/vocabulary/iso639-1/en>;\r\n  dcterms:license <http://rdflicense.appspot.com/rdflicense/cc-by-nc-nd3.0>;\r\n  <http://rdf.biosemantics.org/ontologies/fdp-o#metadataIdentifier> <https://fdp.x-omics.nl/investigation/e54a55c9-9ac7-44d5-ad1e-832b5440c90d#identifier>;\r\n  <http://rdf.biosemantics.org/ontologies/fdp-o#metadataIssued> \"2022-02-06T21:47:50.507Z\"^^xsd:dateTime;\r\n  <http://rdf.biosemantics.org/ontologies/fdp-o#metadataModified> \"2022-02-06T21:52:14.809Z\"^^xsd:dateTime;\r\n  dcat:theme <http://www.wikidata.org/entity/Q14944328> ;\r\n  dcterms:isPartOf <https://fdp.x-omics.nl/catalog/c6c73d4f-97bb-40e7-9068-e1eeadf1f2a4>;\r\n  dcterms:rights <http://rdflicense.appspot.com/rdflicense/cc-by-nc-nd3.0>;\r\n  <http://semanticscience.org/resource/SIO_000628> <https://fdp.x-omics.nl/investigation/e54a55c9-9ac7-44d5-ad1e-832b5440c90d/metrics/445c0a70d1e214e545b261559e2842f4>,\r\n    <https://fdp.x-omics.nl/investigation/e54a55c9-9ac7-44d5-ad1e-832b5440c90d/metrics/5d27e854a9e78eb3f663331cd47cdc13>;\r\n  foaf:homePage <http://example.com>;\r\n  <http://www.example.com/resources/publication> [ a <http://www.example.com/resources/Publication>;\r\n      <http://www.example.com/resources/author> [ a foaf:Person;\r\n          <http://d-nb.info/standards/elementset/gndaffiliation> \"Faculty of Medicine and Institute for Life Sciences, University of Southampton, United Kindom\";\r\n          <http://www.w3.org/2006/vcard/nsAddress> \"Faculty of Medicine and Institute for Life Sciences, University of Southampton\";\r\n          <http://www.w3.org/2006/vcard/nsrole> \"co-investigator\";\r\n          foaf:OnlineAccount \"H.De-Graaf@soton.ac.uk\";\r\n          foaf:firstName \"Hans\";\r\n          foaf:lastName \"de Graaf\"\r\n        ];\r\n      <http://www.example.com/resources/hasDOI> <https://doi.org/10.1136/bmjopen-2017-018594>;\r\n      <http://www.example.com/resources/hasPublicationID> <https://pubmed.ncbi.nlm.nih.gov/31652530/>;\r\n      <http://www.example.com/resources/hasStatus> \"published\";\r\n      dcterms:title \"\"\"Investigating Bordetella pertussis colonisation and immunity: protocol for an inpatient controlled human infection model\tPeriscope\"\"\"\r\n    ];\r\n  <http://www.w3.org/2000/01/rdf-schema#label> \"Pertussis Correlates of Protection Europe\";\r\n  dcterms:description \"PERISCOPE will develop novel functional antibody and cellular assays and employ cutting edge science to characterize innate and adaptive immune responses. Immune responses will be characterized through clinical trials that will compare aP with wP vaccine in a range of age groups, including infants. The impact of immunization in pregnancy on subsequent immune responses of infants to aP or wP will be determined in a European and an African setting. Experimental human and pre-clinical B. pertussis challenge models will be developed to identify immune signatures that predict protection against B. pertussis colonisation and/or disease. These signatures will then be compared to immune responses following vaccination. Potential biomarkers of protection against colonisation and/or disease will subsequently be evaluated in the human challenge model, cohorts of naturally infected individuals, including exposed household contacts, and in the pre-clinical model. A second pre-clinical model will be used to gain insight into the underlying mechanisms of protection.\";\r\n  dcterms:hasVersion \"1.0\";\r\n  dcterms:publisher [ a foaf:Agent;\r\n      foaf:name \"XiaoFeng Liao\"\r\n    ];\r\n  dcterms:title \"Pertussis Correlates of Protection Europe\" .\r\n\r\n<https://fdp.x-omics.nl/investigation/e54a55c9-9ac7-44d5-ad1e-832b5440c90d/metrics/445c0a70d1e214e545b261559e2842f4>\r\n  <http://semanticscience.org/resource/SIO_000332> <https://www.ietf.org/rfc/rfc3986.txt>;\r\n  <http://semanticscience.org/resource/SIO_000628> <https://www.ietf.org/rfc/rfc3986.txt> .\r\n\r\n<https://fdp.x-omics.nl/investigation/e54a55c9-9ac7-44d5-ad1e-832b5440c90d/metrics/5d27e854a9e78eb3f663331cd47cdc13>\r\n  <http://semanticscience.org/resource/SIO_000332> <https://www.wikidata.org/wiki/Q8777>;\r\n  <http://semanticscience.org/resource/SIO_000628> <https://www.wikidata.org/wiki/Q8777> .\r\n\r\n<https://fdp.x-omics.nl/investigation/e54a55c9-9ac7-44d5-ad1e-832b5440c90d#accessRights>\r\n  a dcterms:RightsStatement;\r\n  dcterms:description \"This resource has no access restriction\" .\r\n\r\n<https://fdp.x-omics.nl/investigation/e54a55c9-9ac7-44d5-ad1e-832b5440c90d#identifier>\r\n  a <http://purl.org/spar/datacite/Identifier>;\r\n  dcterms:identifier \"https://fdp.x-omics.nl/investigation/e54a55c9-9ac7-44d5-ad1e-832b5440c90d\" .\r\n\r\n<https://fdp.x-omics.nl/profile/54484818-9427-413b-85f2-fefa0bd74c0a> <http://www.w3.org/2000/01/rdf-schema#label>\r\n    \"Investigation Profile\" .\r\n\r\n<https://fdp.x-omics.nl/study/> a ldp:DirectContainer;\r\n  ldp:hasMemberRelation <http://purl.org/biosemantics-lumc/ontologies/dcat-extension/Study>;\r\n  ldp:membershipResource <https://fdp.x-omics.nl/investigation/e54a55c9-9ac7-44d5-ad1e-832b5440c90d>;\r\n  dcterms:title \"Studies\" ."
headers = {
  'Authorization': 'Bearer eyJhbGciOiJIUzI1NiJ9.eyJzdWIiOiI3ZTY0ODE4ZC02Mjc2LTQ2ZmItOGJiMS03MzJlNmUwOWY3ZTkiLCJpYXQiOjE2NDMxNDMzNDQsImV4cCI6MTY0NDM1Mjk0NH0.9wKTOZm3K5oSmsbAzTKFn1kvtx6RLvgnpP9IOH7GQzg',
  'Content-Type': 'text/turtle'
}

response = requests.request("POST", url, headers=headers, data=payload)

print(response.text)
# Out:
# @prefix dcterms: <http://purl.org/dc/terms/> .
# @prefix dcat: <http://www.w3.org/ns/dcat#> .
# @prefix foaf: <http://xmlns.com/foaf/0.1/> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
# @prefix ldp: <http://www.w3.org/ns/ldp#> .
#
# <https://fdp.x-omics.nl/dataset/712a7c5c-ed26-49a8-8020-ac48222d4b76> a dcat:Resource,
#     dcat:Dataset;
#   dcterms:accessRights <https://fdp.x-omics.nl/investigation/e54a55c9-9ac7-44d5-ad1e-832b5440c90d#accessRights>;
#   dcterms:conformsTo <https://fdp.x-omics.nl/profile/54484818-9427-413b-85f2-fefa0bd74c0a>;
#   dcterms:language <http://id.loc.gov/vocabulary/iso639-1/en>;
#   dcterms:license <http://rdflicense.appspot.com/rdflicense/cc-by-nc-nd3.0>;
#   dcat:theme <http://www.wikidata.org/entity/Q14944328>;
#   dcterms:isPartOf <https://fdp.x-omics.nl/catalog/c6c73d4f-97bb-40e7-9068-e1eeadf1f2a4>;
#   dcterms:rights <http://rdflicense.appspot.com/rdflicense/cc-by-nc-nd3.0>;
#   foaf:homePage <http://example.com>;
# ...

# %%
#below is the script for submit study

# %%
import requests

url = "https://fdp.x-omics.nl/study"

payload = "@prefix dcterms: <http://purl.org/dc/terms/> .\r\n@prefix dcat: <http://www.w3.org/ns/dcat#> .\r\n@prefix foaf: <http://xmlns.com/foaf/0.1/> .\r\n@prefix xsd: <http://www.w3.org/2001/XMLSchema#> .\r\n@prefix ldp: <http://www.w3.org/ns/ldp#> .\r\n\r\n<https://fdp.x-omics.nl/study/327806bb-b628-4c02-a491-071d9b7fe404> a dcat:Resource,\r\n    <http://purl.org/biosemantics-lumc/ontologies/dcat-extension/Study>;\r\n  dcterms:accessRights <https://fdp.x-omics.nl/study/327806bb-b628-4c02-a491-071d9b7fe404#accessRights>;\r\n  dcterms:conformsTo <https://fdp.x-omics.nl/profile/fd879b89-0df4-4a81-b92a-a5359061b17d>;\r\n  dcterms:language <http://id.loc.gov/vocabulary/iso639-1/en>;\r\n  dcterms:license <http://rdflicense.appspot.com/rdflicense/cc-by-nc-nd3.0>;\r\n  <http://rdf.biosemantics.org/ontologies/fdp-o#metadataIdentifier> <https://fdp.x-omics.nl/study/327806bb-b628-4c02-a491-071d9b7fe404#identifier>;\r\n  <http://rdf.biosemantics.org/ontologies/fdp-o#metadataIssued> \"2022-02-07T08:28:23.111Z\"^^xsd:dateTime;\r\n  <http://rdf.biosemantics.org/ontologies/fdp-o#metadataModified> \"2022-02-07T08:56:52.866Z\"^^xsd:dateTime;\r\n    dcat:theme <http://www.wikidata.org/entity/Q14944328> ;\r\n  dcterms:isPartOf <https://fdp.x-omics.nl/investigation/e54a55c9-9ac7-44d5-ad1e-832b5440c90d>;\r\n  dcterms:rights <http://rdflicense.appspot.com/rdflicense/cc-by-nc-nd3.0>;\r\n  <http://semanticscience.org/resource/SIO_000628> <https://fdp.x-omics.nl/study/327806bb-b628-4c02-a491-071d9b7fe404/metrics/445c0a70d1e214e545b261559e2842f4>,\r\n    <https://fdp.x-omics.nl/study/327806bb-b628-4c02-a491-071d9b7fe404/metrics/5d27e854a9e78eb3f663331cd47cdc13>;\r\n  <http://semanticscience.org/resource/SIO_000001> <http://localhost/distribution/63b4e9eb-e548-4cf2-a7db-5eae72c948df>;\r\n  <http://www.example.com/resources/Assay> [ a <http://www.example.com/resources/Assay>;\r\n      <http://www.example.com/resources/AssayMeasurementShape> [ a <http://www.example.com/resources/AssayMeasurementShape>;\r\n          <http://purl.org/iot/vocab/m3-liteMeasurementType> \"cytokines\";\r\n          <http://www.w3.org/ns/lemon/vartranssource> \"0000115\";\r\n          <http://purl.org/healthcarevocab/v1AccessionNumber> \"0000115\"\r\n        ];\r\n      <http://www.example.com/resources/AssayTechnologyShape> [ a <http://www.example.com/resources/AssayTechnologyShape>;\r\n          <http://www.w3.org/ns/lemon/vartranssource> \"0000115\";\r\n          <http://purl.org/healthcarevocab/v1AccessionNumber> \"0000115\";\r\n          <http://usefulinc.com/ns/doapplatform> \"0000115\";\r\n          dcterms:title \"luminex\"\r\n        ];\r\n      <http://www.w3.org/2001/sw/hcls/ns/transmedTMO_0076> \"a_bert_luminex.txt\"\r\n    ];\r\n  <http://www.example.com/resources/protocol> [ a <http://www.example.com/resources/Protocol>;\r\n      <http://purl.org/healthcarevocab/v1PerformedProtocolType> \"blood draw, stimulation, luminex pass on\";\r\n      <http://purl.org/healthcarevocab/v1ProtocolName> \"blood draw, stimulation, luminex pass on\";\r\n      <http://www.example.com/resources/StudyProtocolComponent> [ a <http://www.example.com/resources/StudyProtocolComponent>;\r\n          <http://purl.org/healthcarevocab/v1PerformedProtocolType> \"stimulation time\";\r\n          <http://purl.org/healthcarevocab/v1ProtocolName> \"stimulation time\";\r\n          <http://www.w3.org/ns/lemon/vartranssource> \"0000115\";\r\n          <http://purl.org/healthcarevocab/v1AccessionNumber> \"0000115\"\r\n        ];\r\n      <http://www.example.com/resources/StudyProtocolParameters> [ a <http://www.example.com/resources/StudyProtocolParameters>;\r\n          <http://purl.org/healthcarevocab/v1ProtocolName> \"stimulation time; stimulant; stimulant concentration; costimulant; costimulant concentration cytokine\";\r\n          <http://www.w3.org/ns/lemon/vartranssource> \"0000115\";\r\n          <http://purl.org/healthcarevocab/v1AccessionNumber> \"0000115\"\r\n        ];\r\n      <http://www.w3.org/ns/lemon/vartranssource> \"http://purl.obolibrary.org/obo/0000115\";\r\n      <http://ontology.ethereal.cz/iraoProtocol> \"http://purl.obolibrary.org/obo/0000115\";\r\n      <http://purl.org/healthcarevocab/v1AccessionNumber> \"0000115\";\r\n      <http://usefulinc.com/ns/doapVersion> \"1.9\";\r\n      dcterms:description \"study protocol\"\r\n    ];\r\n  <http://www.example.com/resources/StudyPerson> [ a foaf:Person;\r\n      <http://d-nb.info/standards/elementset/gndaffiliation> \"Radboud UMC, RIVM, the Netherlands\";\r\n      <http://www.w3.org/2006/vcard/nsAddress> \"Radboud UMC, RIVM, the Netherlands\";\r\n      <http://www.w3.org/2006/vcard/nsrole> \"Researcher\";\r\n      <http://www.w3.org/ns/lemon/vartranssource> \"http://purl.obolibrary.org/obo/RoleO_0000464\";\r\n      <http://purl.org/healthcarevocab/v1AccessionNumber> \"0000116\";\r\n      foaf:OnlineAccount \"evi.vanSchuppen@radboudumc.nl\";\r\n      foaf:firstName \"Evi\";\r\n      foaf:lastName \"van Schuppen\"\r\n    ];\r\n  <http://www.example.com/resources/StudyPublication> [ a <http://www.example.com/resources/StudyPublication>;\r\n      <http://www.example.com/resources/author> [ a foaf:Person;\r\n          <http://d-nb.info/standards/elementset/gndaffiliation> \"Faculty of Medicine and Institute for Life Sciences, University of Southampton, Academic Unit of Clinical Experimental Sciences, National Institute of Health Research (NIHR) Clinical Research Facility and NIHR Southampton Biomedical Research Centre, University Hospital Southampton, Southampton, United Kingdom\";\r\n          <http://www.w3.org/2006/vcard/nsAddress> \"Faculty of Medicine and Institute for Life Sciences, University of Southampton\";\r\n          <http://www.w3.org/2006/vcard/nsrole> \"co-investigator\";\r\n          foaf:OnlineAccount \"H.De-Graaf@soton.ac.uk\";\r\n          foaf:firstName \"Hans\";\r\n          foaf:lastName \"de Graaf\"\r\n        ];\r\n      <http://www.example.com/resources/hasDOI> <https://doi.org/10.1136/bmjopen-2017-018594>;\r\n      <http://www.example.com/resources/hasPublicationID> <https://pubmed.ncbi.nlm.nih.gov/31652530/>;\r\n      <http://www.example.com/resources/hasStatus> \"published\";\r\n      <http://www.example.com/resources/hasAccessionNumber> \"0000115\";\r\n      <http://www.example.com/resources/hasStatusTerm> \"0000115\";\r\n      dcterms:title \"\"\"Investigating Bordetella pertussis colonisation and immunity: protocol for an inpatient controlled human infection model\tPeriscope\"\"\"\r\n    ];\r\n  <http://www.w3.org/2000/01/rdf-schema#label> \"Booster Against Pertussis\";\r\n  dcterms:description \"\"\"The BERT (Booster pertussis vaccine study) study investigates how cells in the blood respond to a recurrent vaccination against whooping cough. It determines whether this response depends on age, the number of vaccines that someone has received during his/her childhood and the type of vaccine that has been administered to someone in his/her youth. The study investigates the immune response in the blood of people of different ages. In the blood the amount of antibodies that someone produces for whooping cough is measured. Further, the reaction of the memory cells in the blood is investigated in different ways. These results can contribute to better vaccines in the future, thus optimizing the protection against whooping cough.\r\n\r\nWhooping cough is an infection of the respiratory tract. This infection is caused by the bacterium Bordetella pertussis (B. pertussis) and is characterized mainly by a typical cough that often lasts for 3-4 months. The disease is also known as 'hundred-day cough'. Whooping cough is transmitted through droplet infection. In coughing patients, infectiousness lasts three weeks after the onset of the symptoms. Also someone without symptoms can infect others.\"\"\";\r\n  dcterms:hasVersion \"1.0\";\r\n  dcterms:issued \"2022-02-07T00:00:00.000Z\"^^xsd:dateTime;\r\n  dcterms:publisher [ a foaf:Agent;\r\n      foaf:name \"XiaoFeng Liao\"\r\n    ];\r\n  dcterms:title \"Booster Against Pertussis\" .\r\n\r\n<https://fdp.x-omics.nl/study/327806bb-b628-4c02-a491-071d9b7fe404/metrics/445c0a70d1e214e545b261559e2842f4>\r\n  <http://semanticscience.org/resource/SIO_000332> <https://www.ietf.org/rfc/rfc3986.txt>;\r\n  <http://semanticscience.org/resource/SIO_000628> <https://www.ietf.org/rfc/rfc3986.txt> .\r\n\r\n<https://fdp.x-omics.nl/study/327806bb-b628-4c02-a491-071d9b7fe404/metrics/5d27e854a9e78eb3f663331cd47cdc13>\r\n  <http://semanticscience.org/resource/SIO_000332> <https://www.wikidata.org/wiki/Q8777>;\r\n  <http://semanticscience.org/resource/SIO_000628> <https://www.wikidata.org/wiki/Q8777> .\r\n\r\n<https://fdp.x-omics.nl/study/327806bb-b628-4c02-a491-071d9b7fe404#accessRights> a\r\n    dcterms:RightsStatement;\r\n  dcterms:description \"This resource has no access restriction\" .\r\n\r\n<https://fdp.x-omics.nl/study/327806bb-b628-4c02-a491-071d9b7fe404#identifier> a <http://purl.org/spar/datacite/Identifier>;\r\n  dcterms:identifier \"https://fdp.x-omics.nl/study/327806bb-b628-4c02-a491-071d9b7fe404\" .\r\n\r\n<https://fdp.x-omics.nl/profile/fd879b89-0df4-4a81-b92a-a5359061b17d> <http://www.w3.org/2000/01/rdf-schema#label>\r\n    \"Study Profile\" ."
headers = {
  'Authorization': 'Bearer eyJhbGciOiJIUzI1NiJ9.eyJzdWIiOiI3ZTY0ODE4ZC02Mjc2LTQ2ZmItOGJiMS03MzJlNmUwOWY3ZTkiLCJpYXQiOjE2NDMwNzEwOTksImV4cCI6MTY0NDI4MDY5OX0._Xq_Z-OBqS_oZp_aLGLOXJ0z_MBS_lOdstvBYRRXZDg',
  'Content-Type': 'text/turtle'
}

response = requests.request("POST", url, headers=headers, data=payload)

print(response.text)
# Out:
# @prefix dcterms: <http://purl.org/dc/terms/> .
# @prefix dcat: <http://www.w3.org/ns/dcat#> .
# @prefix foaf: <http://xmlns.com/foaf/0.1/> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
# @prefix ldp: <http://www.w3.org/ns/ldp#> .
#
# <https://fdp.x-omics.nl/study/8ae5d14b-bcbb-4bb6-98d1-ab574e25f3e3> a dcat:Resource,
#     <http://purl.org/biosemantics-lumc/ontologies/dcat-extension/Study>;
#   dcterms:accessRights <https://fdp.x-omics.nl/study/327806bb-b628-4c02-a491-071d9b7fe404#accessRights>;
#   dcterms:conformsTo <https://fdp.x-omics.nl/profile/fd879b89-0df4-4a81-b92a-a5359061b17d>;
#   dcterms:language <http://id.loc.gov/vocabulary/iso639-1/en>;
#   dcterms:license <http://rdflicense.appspot.com/rdflicense/cc-by-nc-nd3.0>;
#   dcat:theme <http://www.wikidata.org/entity/Q14944328>;
#   dcterms:isPartOf <https://fdp.x-omics.nl/investigation/e54a55c9-9ac7-44d5-ad1e-832b5440c90d>;
#   dcterms:rights <http://rdflicense.appspot.com/rdflicense/cc-by-nc-nd3.0>;
# ...

# %%
import requests
import json

url = "https://fdp.x-omics.nl/dataset"

payload = json.dumps([
  {
    "@id": "_:genid-9bf6b9b1efb5414f9be3283cb026e558-t238",
    "@type": [
      "http://xmlns.com/foaf/0.1/Agent"
    ],
    "http://xmlns.com/foaf/0.1/name": [
      {
        "@value": "XiaoFeng Liao"
      }
    ]
  },
  {
    "@id": "https://fdp.x-omics.nl/dataset/10fa166b-f08d-433f-a4c6-09aaf4783184",
    "@type": [
      "http://www.w3.org/ns/dcat#Resource",
      "http://www.w3.org/ns/dcat#Dataset"
    ],
    "http://edamontology.org/data_1188": [
      {
        "@id": "https://doi.org/10.1016/j.cell.2020.10.037"
      }
    ],
    "http://purl.obolibrary.org/obo/ExO_0000105": [
      {
        "@value": "33.7"
      }
    ],
    "http://purl.obolibrary.org/obo/GECKO_0000061": [
      {
        "@value": "Caucasian"
      }
    ],
    "http://purl.obolibrary.org/obo/HP_0006510": [
      {
        "@value": "No"
      }
    ],
    "http://purl.obolibrary.org/obo/MONDO_0100096": [
      {
        "@value": "Yes"
      }
    ],
    "http://purl.obolibrary.org/obo/NCIT_C121113": [
      {
        "@value": "none"
      }
    ],
    "http://purl.obolibrary.org/obo/NCIT_C154329": [
      {
        "@value": "Never"
      }
    ],
    "http://purl.obolibrary.org/obo/NCIT_C16960": [
      {
        "@value": "Yes"
      }
    ],
    "http://purl.obolibrary.org/obo/NCIT_C173069": [
      {
        "@value": "Yes"
      }
    ],
    "http://purl.obolibrary.org/obo/NCIT_C176422": [
      {
        "@value": "none"
      }
    ],
    "http://purl.obolibrary.org/obo/NCIT_C178899": [
      {
        "@value": "3.0"
      }
    ],
    "http://purl.obolibrary.org/obo/NCIT_C28397": [
      {
        "@value": "No"
      }
    ],
    "http://purl.obolibrary.org/obo/NCIT_C28421": [
      {
        "@value": "Female"
      }
    ],
    "http://purl.obolibrary.org/obo/NCIT_C2985": [
      {
        "@value": "none"
      }
    ],
    "http://purl.obolibrary.org/obo/NCIT_C37908": [
      {
        "@value": "77"
      }
    ],
    "http://purl.obolibrary.org/obo/NCIT_C41189": [
      {
        "@value": "INCOV001"
      }
    ],
    "http://purl.obolibrary.org/obo/NCIT_C53511": [
      {
        "@value": "No"
      }
    ],
    "http://purl.obolibrary.org/obo/NCIT_C64548": [
      {
        "@value": "none"
      }
    ],
    "http://purl.obolibrary.org/obo/NCIT_C70909": [
      {
        "@value": "No"
      }
    ],
    "http://purl.obolibrary.org/obo/NCIT_C74737": [
      {
        "@value": "none"
      }
    ],
    "http://purl.obolibrary.org/obo/NCIT_C74834": [
      {
        "@value": "none"
      }
    ],
    "http://purl.org/dc/terms/accessRights": [
      {
        "@id": "https://fdp.x-omics.nl/CovidDataset/44d9d97d-37bc-46e9-92d8-d18fdd5c6d73#accessRights"
      }
    ],
    "http://purl.org/dc/terms/conformsTo": [
      {
        "@id": "https://fdp.x-omics.nl/profile/d9d8ae37-4442-4255-8616-da716acfa217"
      },
      {
        "@id": "https://fdp.x-omics.nl/profile/2f08228e-1789-40f8-84cd-28e3288c3604"
      }
    ],
    "http://purl.org/dc/terms/description": [
      {
        "@value": "IMA1601"
      }
    ],
    "http://purl.org/dc/terms/hasVersion": [
      {
        "@value": "1.0"
      }
    ],
    "http://purl.org/dc/terms/isPartOf": [
      {
        "@id": "https://fdp.x-omics.nl/catalog/c6c73d4f-97bb-40e7-9068-e1eeadf1f2a4"
      }
    ],
    "http://purl.org/dc/terms/language": [
      {
        "@id": "http://id.loc.gov/vocabulary/iso639-1/en"
      }
    ],
    "http://purl.org/dc/terms/license": [
      {
        "@id": "http://rdflicense.appspot.com/rdflicense/cc-by-nc-nd3.0"
      }
    ],
    "http://purl.org/dc/terms/publisher": [
      {
        "@id": "_:genid-9bf6b9b1efb5414f9be3283cb026e558-t238"
      }
    ],
    "http://purl.org/dc/terms/rights": [
      {
        "@id": "http://rdflicense.appspot.com/rdflicense/cc-by-nc-nd3.0"
      }
    ],
    "http://purl.org/dc/terms/title": [
      {
        "@value": "IMA1601"
      }
    ],
    "http://rdf.biosemantics.org/ontologies/fdp-o#metadataIdentifier": [
      {
        "@id": "https://fdp.x-omics.nl/dataset/10fa166b-f08d-433f-a4c6-09aaf4783184#identifier"
      }
    ],
    "http://rdf.biosemantics.org/ontologies/fdp-o#metadataIssued": [
      {
        "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
        "@value": "2022-01-28T09:00:54.479Z"
      }
    ],
    "http://rdf.biosemantics.org/ontologies/fdp-o#metadataModified": [
      {
        "@type": "http://www.w3.org/2001/XMLSchema#dateTime",
        "@value": "2022-01-28T09:00:54.479Z"
      }
    ],
    "http://semanticscience.org/resource/SIO_000628": [
      {
        "@id": "https://fdp.x-omics.nl/dataset/10fa166b-f08d-433f-a4c6-09aaf4783184/metrics/445c0a70d1e214e545b261559e2842f4"
      },
      {
        "@id": "https://fdp.x-omics.nl/dataset/10fa166b-f08d-433f-a4c6-09aaf4783184/metrics/5d27e854a9e78eb3f663331cd47cdc13"
      }
    ],
    "http://www.example.com/resources/InvestigationContact": [
      {
        "@value": "Hospital"
      }
    ],
    "http://www.w3.org/2000/01/rdf-schema#label": [
      {
        "@value": "IMA1601"
      }
    ],
    "http://www.w3.org/ns/dcat#theme": [
      {
        "@id": "http://www.wikidata.org/entity/Q14944328"
      }
    ]
  },
  {
    "@id": "https://fdp.x-omics.nl/dataset/10fa166b-f08d-433f-a4c6-09aaf4783184#identifier",
    "@type": [
      "http://purl.org/spar/datacite/Identifier"
    ],
    "http://purl.org/dc/terms/identifier": [
      {
        "@value": "https://fdp.x-omics.nl/dataset/10fa166b-f08d-433f-a4c6-09aaf4783184"
      }
    ]
  },
  {
    "@id": "https://fdp.x-omics.nl/dataset/10fa166b-f08d-433f-a4c6-09aaf4783184/metrics/445c0a70d1e214e545b261559e2842f4",
    "http://semanticscience.org/resource/SIO_000332": [
      {
        "@id": "https://www.ietf.org/rfc/rfc3986.txt"
      }
    ],
    "http://semanticscience.org/resource/SIO_000628": [
      {
        "@id": "https://www.ietf.org/rfc/rfc3986.txt"
      }
    ]
  },
  {
    "@id": "https://fdp.x-omics.nl/dataset/10fa166b-f08d-433f-a4c6-09aaf4783184/metrics/5d27e854a9e78eb3f663331cd47cdc13",
    "http://semanticscience.org/resource/SIO_000332": [
      {
        "@id": "https://www.wikidata.org/wiki/Q8777"
      }
    ],
    "http://semanticscience.org/resource/SIO_000628": [
      {
        "@id": "https://www.wikidata.org/wiki/Q8777"
      }
    ]
  },
  {
    "@id": "https://fdp.x-omics.nl/distribution/",
    "@type": [
      "http://www.w3.org/ns/ldp#DirectContainer"
    ],
    "http://purl.org/dc/terms/title": [
      {
        "@value": "Distributions"
      }
    ],
    "http://www.w3.org/ns/ldp#hasMemberRelation": [
      {
        "@id": "http://www.w3.org/ns/dcat#distribution"
      }
    ],
    "http://www.w3.org/ns/ldp#membershipResource": [
      {
        "@id": "https://fdp.x-omics.nl/dataset/10fa166b-f08d-433f-a4c6-09aaf4783184"
      }
    ]
  },
  {
    "@id": "https://fdp.x-omics.nl/profile/2f08228e-1789-40f8-84cd-28e3288c3604",
    "http://www.w3.org/2000/01/rdf-schema#label": [
      {
        "@value": "Dataset Profile"
      }
    ]
  }
])
headers = {
  'Authorization': 'Bearer eyJhbGciOiJIUzI1NiJ9.eyJzdWIiOiI3ZTY0ODE4ZC02Mjc2LTQ2ZmItOGJiMS03MzJlNmUwOWY3ZTkiLCJpYXQiOjE2NDMxNDMzNDQsImV4cCI6MTY0NDM1Mjk0NH0.9wKTOZm3K5oSmsbAzTKFn1kvtx6RLvgnpP9IOH7GQzg',
  'Content-Type': 'application/json'
}

response = requests.request("POST", url, headers=headers, data=payload)

print(response.text)
# Out:
# Unable to read RDF (parse exception)

# %%
## below is the script for submtting json metadata of Covid dataset

import requests

headers = {
    'accept': 'text/turtle',
    'Authorization': 'Bearer eyJhbGciOiJIUzI1NiJ9.eyJzdWIiOiI3ZTY0ODE4ZC02Mjc2LTQ2ZmItOGJiMS03MzJlNmUwOWY3ZTkiLCJpYXQiOjE2NDQzNDg4MDMsImV4cCI6MTY0NTU1ODQwM30.4L8V8_E7ApfYChhHHF9YP30-D9RwRKA4aGqJw8BgMGQ',
    'Content-Type': 'application/ld+json'
}

data = '[{"@id":"_:genid-9bf6b9b1efb5414f9be3283cb026e558-t238", \r\n "@type":["http://xmlns.com/foaf/0.1/Agent"], \r\n "http://xmlns.com/foaf/0.1/name":[{"@value":"XiaoFeng Liao"}]},{"@id":"https://fdp.x-omics.nl/dataset/10fa166b-f08d-433f-a4c6-09aaf4783184","@type":["http://www.w3.org/ns/dcat#Resource","http://www.w3.org/ns/dcat#Dataset"],"http://edamontology.org/data_1188":[{"@id":"https://doi.org/10.1016/j.cell.2020.10.037"}],"http://purl.obolibrary.org/obo/ExO_0000105":[{"@value":"33.7"}],"http://purl.obolibrary.org/obo/GECKO_0000061":[{"@value":"Caucasian"}],"http://purl.obolibrary.org/obo/HP_0006510":[{"@value":"No"}],"http://purl.obolibrary.org/obo/MONDO_0100096":[{"@value":"Yes"}],"http://purl.obolibrary.org/obo/NCIT_C121113":[{"@value":"none"}],"http://purl.obolibrary.org/obo/NCIT_C154329":[{"@value":"Never"}],"http://purl.obolibrary.org/obo/NCIT_C16960":[{"@value":"Yes"}],"http://purl.obolibrary.org/obo/NCIT_C173069":[{"@value":"Yes"}],"http://purl.obolibrary.org/obo/NCIT_C176422":[{"@value":"none"}],"http://purl.obolibrary.org/obo/NCIT_C178899":[{"@value":"3.0"}],"http://purl.obolibrary.org/obo/NCIT_C28397":[{"@value":"No"}],"http://purl.obolibrary.org/obo/NCIT_C28421":[{"@value":"Female"}],"http://purl.obolibrary.org/obo/NCIT_C2985":[{"@value":"none"}],"http://purl.obolibrary.org/obo/NCIT_C37908":[{"@value":"77"}],"http://purl.obolibrary.org/obo/NCIT_C41189":[{"@value":"INCOV001"}],"http://purl.obolibrary.org/obo/NCIT_C53511":[{"@value":"No"}],"http://purl.obolibrary.org/obo/NCIT_C64548":[{"@value":"none"}],"http://purl.obolibrary.org/obo/NCIT_C70909":[{"@value":"No"}],"http://purl.obolibrary.org/obo/NCIT_C74737":[{"@value":"none"}],"http://purl.obolibrary.org/obo/NCIT_C74834":[{"@value":"none"}],"http://purl.org/dc/terms/accessRights":[{"@id":"https://fdp.x-omics.nl/CovidDataset/44d9d97d-37bc-46e9-92d8-d18fdd5c6d73#accessRights"}],"http://purl.org/dc/terms/conformsTo":[{"@id":"https://fdp.x-omics.nl/profile/d9d8ae37-4442-4255-8616-da716acfa217"},{"@id":"https://fdp.x-omics.nl/profile/2f08228e-1789-40f8-84cd-28e3288c3604"}],"http://purl.org/dc/terms/description":[{"@value":"IMA1601"}],"http://purl.org/dc/terms/hasVersion":[{"@value":"1.0"}],"http://purl.org/dc/terms/isPartOf":[{"@id":"https://fdp.x-omics.nl/catalog/c6c73d4f-97bb-40e7-9068-e1eeadf1f2a4"}],"http://purl.org/dc/terms/language":[{"@id":"http://id.loc.gov/vocabulary/iso639-1/en"}],"http://purl.org/dc/terms/license":[{"@id":"http://rdflicense.appspot.com/rdflicense/cc-by-nc-nd3.0"}],"http://purl.org/dc/terms/publisher":[{"@id":"_:genid-9bf6b9b1efb5414f9be3283cb026e558-t238"}],"http://purl.org/dc/terms/rights":[{"@id":"http://rdflicense.appspot.com/rdflicense/cc-by-nc-nd3.0"}],"http://purl.org/dc/terms/title":[{"@value":"IMA1601"}],"http://rdf.biosemantics.org/ontologies/fdp-o#metadataIdentifier":[{"@id":"https://fdp.x-omics.nl/dataset/10fa166b-f08d-433f-a4c6-09aaf4783184#identifier"}],"http://rdf.biosemantics.org/ontologies/fdp-o#metadataIssued":[{"@type":"http://www.w3.org/2001/XMLSchema#dateTime","@value":"2022-01-28T09:00:54.479Z"}],"http://rdf.biosemantics.org/ontologies/fdp-o#metadataModified":[{"@type":"http://www.w3.org/2001/XMLSchema#dateTime","@value":"2022-01-28T09:00:54.479Z"}],"http://semanticscience.org/resource/SIO_000628":[{"@id":"https://fdp.x-omics.nl/dataset/10fa166b-f08d-433f-a4c6-09aaf4783184/metrics/445c0a70d1e214e545b261559e2842f4"},{"@id":"https://fdp.x-omics.nl/dataset/10fa166b-f08d-433f-a4c6-09aaf4783184/metrics/5d27e854a9e78eb3f663331cd47cdc13"}],"http://www.example.com/resources/InvestigationContact":[{"@value":"Hospital"}],"http://www.w3.org/2000/01/rdf-schema#label":[{"@value":"IMA1601"}],"http://www.w3.org/ns/dcat#theme":[{"@id":"http://www.wikidata.org/entity/Q14944328"}]},{"@id":"https://fdp.x-omics.nl/dataset/10fa166b-f08d-433f-a4c6-09aaf4783184#identifier","@type":["http://purl.org/spar/datacite/Identifier"],"http://purl.org/dc/terms/identifier":[{"@value":"https://fdp.x-omics.nl/dataset/10fa166b-f08d-433f-a4c6-09aaf4783184"}]},{"@id":"https://fdp.x-omics.nl/dataset/10fa166b-f08d-433f-a4c6-09aaf4783184/metrics/445c0a70d1e214e545b261559e2842f4","http://semanticscience.org/resource/SIO_000332":[{"@id":"https://www.ietf.org/rfc/rfc3986.txt"}],"http://semanticscience.org/resource/SIO_000628":[{"@id":"https://www.ietf.org/rfc/rfc3986.txt"}]},{"@id":"https://fdp.x-omics.nl/dataset/10fa166b-f08d-433f-a4c6-09aaf4783184/metrics/5d27e854a9e78eb3f663331cd47cdc13","http://semanticscience.org/resource/SIO_000332":[{"@id":"https://www.wikidata.org/wiki/Q8777"}],"http://semanticscience.org/resource/SIO_000628":[{"@id":"https://www.wikidata.org/wiki/Q8777"}]},{"@id":"https://fdp.x-omics.nl/distribution/","@type":["http://www.w3.org/ns/ldp#DirectContainer"],"http://purl.org/dc/terms/title":[{"@value":"Distributions"}],"http://www.w3.org/ns/ldp#hasMemberRelation":[{"@id":"http://www.w3.org/ns/dcat#distribution"}],"http://www.w3.org/ns/ldp#membershipResource":[{"@id":"https://fdp.x-omics.nl/dataset/10fa166b-f08d-433f-a4c6-09aaf4783184"}]},{"@id":"https://fdp.x-omics.nl/profile/2f08228e-1789-40f8-84cd-28e3288c3604","http://www.w3.org/2000/01/rdf-schema#label":[{"@value":"Dataset Profile"}]}]'

response = requests.post('https://fdp.x-omics.nl/dataset', headers=headers, data=data)
print(response)
print(response.text)
# Out:
# <Response [201]>
# @prefix dcterms: <http://purl.org/dc/terms/> .
# @prefix dcat: <http://www.w3.org/ns/dcat#> .
# @prefix foaf: <http://xmlns.com/foaf/0.1/> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
# @prefix ldp: <http://www.w3.org/ns/ldp#> .
#
# <https://fdp.x-omics.nl/dataset/75124ff5-269d-4db2-95ed-09f51a0dbcc7> a dcat:Resource,
#     dcat:Dataset;
#   <http://edamontology.org/data_1188> <https://doi.org/10.1016/j.cell.2020.10.037>;
#   <http://purl.obolibrary.org/obo/ExO_0000105> "33.7";
#   <http://purl.obolibrary.org/obo/GECKO_0000061> "Caucasian";
#   <http://purl.obolibrary.org/obo/HP_0006510> "No";
#   <http://purl.obolibrary.org/obo/MONDO_0100096> "Yes";
#   <http://purl.obolibrary.org/obo/NCIT_C121113> "none";
#   <http://purl.obolibrary.org/obo/NCIT_C154329> "Never";
#   <http://purl.obolibrary.org/obo/NCIT_C16960> "Yes";
#   <http://purl.obolibrary.org/obo/NCIT_C173069> "Yes";
#   <http://purl.obolibrary.org/obo/NCIT_C176422> "none";
# ...

# %%
import requests

headers = {
    'accept': 'text/turtle',
    'Authorization': 'Bearer eyJhbGciOiJIUzI1NiJ9.eyJzdWIiOiI3ZTY0ODE4ZC02Mjc2LTQ2ZmItOGJiMS03MzJlNmUwOWY3ZTkiLCJpYXQiOjE2NDQzNDg4MDMsImV4cCI6MTY0NTU1ODQwM30.4L8V8_E7ApfYChhHHF9YP30-D9RwRKA4aGqJw8BgMGQ',
    'Content-Type': 'application/ld+json',
}

data = {
  '{    "comments": [],    "description": "Predict childhood aggression with multi-omics data and demonstrate the FAIRification process and data analysis of a multi-omics project",    "identifier": "tbd", "http://www.w3.org/ns/dcat#theme" : [ {    "@id" : "http://www.wikidata.org/entity/Q14944328"  } ],    "ontologySourceReferences": [        {            "description": "Allotrope Merged Ontology Suite",            "file": "",            "name": "AFO",            "version": ""        },        {            "description": "Chemical Entities of Biological Interest",            "file": "",            "name": "CHEBI",            "version": ""        },        {            "description": "Chemical Methods Ontology",            "file": "",            "name": "CHMO",            "version": ""        },        {            "description": "Bioinformatics operations, data types, formats, identifiers and topics",            "file": "",            "name": "EDAM",            "version": ""        },        {            "description": "Experimental Factor Ontology",            "file": "",            "name": "EFO",            "version": ""        },        {            "description": "An ontology of research resources such as instruments, protocols, reagents, animal models and biospecimens",            "file": "",            "name": "eagle-i resource ontology",            "version": ""        },        {            "description": "Medical Action Ontology",            "file": "",            "name": "MAXO",            "version": ""        },        {            "description": "Metabolite Standards Initiative Ontology",            "file": "",            "name": "MSIO",            "version": ""        },        {            "description": "NCBI organismal classification",            "file": "",            "name": "NCBITAXON",            "version": ""        },        {            "description": "NCI Thesaurus OBO Edition",            "file": "",            "name": "NCIT",            "version": ""        },        {            "description": "Ontology for Biomedical Investigations",            "file": "",            "name": "OBI",            "version": ""        },        {            "description": "PATO - the Phenotype And Trait Ontology",            "file": "",            "name": "PATO",            "version": ""        },        {            "description": "Uber-anatomy ontology",            "file": "",            "name": "UBERON",            "version": ""        }    ],    "people": [],    "publicReleaseDate": "",    "publications": [],    "studies": [        {            "assays": [                {                    "characteristicCategories": [],                    "comments": [],                    "dataFiles": [],                    "filename": "a_assay_genotype.txt",                    "materials": {                        "otherMaterials": [],                        "samples": [                            {                                "@id": "#sample/139800003580448",                                "characteristics": [                                    {                                        "category": {                                            "@id": "#4cdf9dbd-6ddd-41e8-8422-9804584b2e60"                                        },                                        "value": {                                            "@id": "#df6021ba-810a-481e-a1fe-f9984f6fb114",                                            "annotationValue": "buccal mucosa",                                            "comments": [],                                            "termAccession": "http://purl.obolibrary.org/obo/UBERON_0006956",                                            "termSource": "UBERON"                                        }                                    }                                ],                                "factorValues": [],                                "name": "buccal_mucosa_XOP1"                            },                            {                                "@id": "#sample/139800003582704",                                "characteristics": [                                    {                                        "category": {                                            "@id": "#622b879f-a6f6-4546-b5e6-38b1e1694851"                                        },                                        "value": {                                            "@id": "#4f6b004d-7ec2-4f85-a574-1bbab3ca9bf1",                                            "annotationValue": "buccal mucosa",                                            "comments": [],                                            "termAccession": "http://purl.obolibrary.org/obo/UBERON_0006956",                                            "termSource": "UBERON"                                        }                                    }                                ],                                "factorValues": [],                                "name": "buccal_mucosa_XOP2"                            },                            {                                "@id": "#sample/139800003605312",                                "characteristics": [                                    {                                        "category": {                                            "@id": "#bebea860-02de-4cba-b897-c2eadb2fdb99"                                        },                                        "value": {                                            "@id": "#45d141a7-47f3-4fd5-9f5c-dfe0a30cf577",                                            "annotationValue": "buccal mucosa",                                            "comments": [],                                            "termAccession": "http://purl.obolibrary.org/obo/UBERON_0006956",                                            "termSource": "UBERON"                                        }                                    }                                ],                                "factorValues": [],                                "name": "buccal_mucosa_XOP3"                            },                            {                                "@id": "#sample/139800003607424",                                "characteristics": [                                    {                                        "category": {                                            "@id": "#ecae4233-47e2-4182-b15f-410ebc700c39"                                        },                                        "value": {                                            "@id": "#dff5b7d1-2a60-4e5c-98df-caffc23c07f9",                                            "annotationValue": "buccal mucosa",                                            "comments": [],                                            "termAccession": "http://purl.obolibrary.org/obo/UBERON_0006956",                                            "termSource": "UBERON"                                        }                                    }                                ],                                "factorValues": [],                                "name": "buccal_mucosa_XOP4"                            },                            {                                "@id": "#sample/139800003601504",                                "characteristics": [                                    {                                        "category": {                                            "@id": "#3b527ffa-7ec4-4783-99f4-6c736f285e89"                                        },                                        "value": {                                            "@id": "#088f1932-b09d-462d-bd54-2878d3ddedc7",                                            "annotationValue": "buccal mucosa",                                            "comments": [],                                            "termAccession": "http://purl.obolibrary.org/obo/UBERON_0006956",                                            "termSource": "UBERON"                                        }                                    }                                ],                                "factorValues": [],                                "name": "buccal_mucosa_XOP5"                            },                            {                                "@id": "#sample/139800003603664",                                "characteristics": [                                    {                                        "category": {                                            "@id": "#621b4f20-bce3-4e80-af92-d848423d8cdc"                                        },                                        "value": {                                            "@id": "#01906a67-37e9-48a2-8f5a-db2079b27010",                                            "annotationValue": "buccal mucosa",                                            "comments": [],                                            "termAccession": "http://purl.obolibrary.org/obo/UBERON_0006956",                                            "termSource": "UBERON"                                        }                                    }                                ],                                "factorValues": [],                                "name": "buccal_mucosa_XOP6"                            },                            {                                "@id": "#sample/139800003618080",                                "characteristics": [                                    {                                        "category": {                                            "@id": "#dca4e9b6-1a46-4458-926c-13870b8912c0"                                        },                                        "value": {                                            "@id": "#65ef2bcc-f46f-4d76-8bb5-b843d24bf11d",                                            "annotationValue": "buccal mucosa",                                            "comments": [],                                            "termAccession": "http://purl.obolibrary.org/obo/UBERON_0006956",                                            "termSource": "UBERON"                                        }                                    }                                ],                                "factorValues": [],                                "name": "buccal_mucosa_XOP7"                            },                            {                                "@id": "#sample/139800003620240",                                "characteristics": [                                    {                                        "category": {                                            "@id": "#9a95f993-895f-49de-b555-7ff5b4aec454"                                        },                                        "value": {                                            "@id": "#d19d8159-634c-43e3-8f78-bb792fdc14ee",                                            "annotationValue": "buccal mucosa",                                            "comments": [],                                            "termAccession": "http://purl.obolibrary.org/obo/UBERON_0006956",                                            "termSource": "UBERON"                                        }                                    }                                ],                                "factorValues": [],                                "name": "buccal_mucosa_XOP8"                            },                            {                                "@id": "#sample/139800003647040",                                "characteristics": [                                    {                                        "category": {                                            "@id": "#758bc0e4-f18c-4739-889c-fa795fed8f6d"                                        },                                        "value": {                                            "@id": "#55b016d6-340d-42e2-9173-3ce4904ec9fa",                                            "annotationValue": "buccal mucosa",                                            "comments": [],                                            "termAccession": "http://purl.obolibrary.org/obo/UBERON_0006956",                                            "termSource": "UBERON"                                        }                                    }                                ],                                "factorValues": [],                                "name": "buccal_mucosa_XOP9"                            },                            {                                "@id": "#sample/139800003649200",                                "characteristics": [                                    {                                        "category": {                                            "@id": "#09dae57d-2ce9-4a58-b5b9-8b6744817bae"                                        },                                        "value": {                                            "@id": "#90a9e7b6-2c7e-4fa2-b27b-d38e695ec170",                                            "annotationValue": "buccal mucosa",                                            "comments": [],                                            "termAccession": "http://purl.obolibrary.org/obo/UBERON_0006956",                                            "termSource": "UBERON"                                        }                                    }                                ],                                "factorValues": [],                                "name": "buccal_mucosa_XOP10"                            }                        ]                    },                    "measurementType": {                        "@id": "#35f6542a-939f-4998-b578-710f5ca1d3a2",                        "annotationValue": "",                        "comments": [],                        "termAccession": "",                        "termSource": ""                    },                    "processSequence": [                        {                            "@id": "#process/139800003660048",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003787312"                            },                            "inputs": [                                {                                    "@id": "#sample/139800003580448"                                }                            ],                            "name": "DNA_extraction_XOG1",                            "nextProcess": {                                "@id": "#process/139800003660432"                            },                            "outputs": [                                {                                    "@id": "#material/extract-139800003647520"                                }                            ],                            "parameterValues": [],                            "performer": ""                        },                        {                            "@id": "#process/139800003660432",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800004215280"                            },                            "inputs": [                                {                                    "@id": "#material/extract-139800003647520"                                }                            ],                            "name": "genotype_profiling_XOG1",                            "outputs": [],                            "parameterValues": [],                            "performer": "",                            "previousProcess": {                                "@id": "#process/139800003660048"                            }                        },                        {                            "@id": "#process/139800003903648",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003787312"                            },                            "inputs": [                                {                                    "@id": "#sample/139800003582704"                                }                            ],                            "name": "DNA_extraction_XOG2",                            "nextProcess": {                                "@id": "#process/139800003903696"                            },                            "outputs": [                                {                                    "@id": "#material/extract-139800003661776"                                }                            ],                            "parameterValues": [],                            "performer": ""                        },                        {                            "@id": "#process/139800003903696",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800004215280"                            },                            "inputs": [                                {                                    "@id": "#material/extract-139800003661776"                                }                            ],                            "name": "genotype_profiling_XOG2",                            "outputs": [],                            "parameterValues": [],                            "performer": "",                            "previousProcess": {                                "@id": "#process/139800003903648"                            }                        },                        {                            "@id": "#process/139800003903840",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003787312"                            },                            "inputs": [                                {                                    "@id": "#sample/139800003605312"                                }                            ],                            "name": "DNA_extraction_XOG3",                            "nextProcess": {                                "@id": "#process/139800003903888"                            },                            "outputs": [                                {                                    "@id": "#material/extract-139800003903552"                                }                            ],                            "parameterValues": [],                            "performer": ""                        },                        {                            "@id": "#process/139800003903888",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800004215280"                            },                            "inputs": [                                {                                    "@id": "#material/extract-139800003903552"                                }                            ],                            "name": "genotype_profiling_XOG3",                            "outputs": [],                            "parameterValues": [],                            "performer": "",                            "previousProcess": {                                "@id": "#process/139800003903840"                            }                        },                        {                            "@id": "#process/139800003904128",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003787312"                            },                            "inputs": [                                {                                    "@id": "#sample/139800003607424"                                }                            ],                            "name": "DNA_extraction_XOG4",                            "nextProcess": {                                "@id": "#process/139800003904176"                            },                            "outputs": [                                {                                    "@id": "#material/extract-139800003903744"                                }                            ],                            "parameterValues": [],                            "performer": ""                        },                        {                            "@id": "#process/139800003904176",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800004215280"                            },                            "inputs": [                                {                                    "@id": "#material/extract-139800003903744"                                }                            ],                            "name": "genotype_profiling_XOG4",                            "outputs": [],                            "parameterValues": [],                            "performer": "",                            "previousProcess": {                                "@id": "#process/139800003904128"                            }                        },                        {                            "@id": "#process/139800003904320",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003787312"                            },                            "inputs": [                                {                                    "@id": "#sample/139800003601504"                                }                            ],                            "name": "DNA_extraction_XOG5",                            "nextProcess": {                                "@id": "#process/139800003904368"                            },                            "outputs": [                                {                                    "@id": "#material/extract-139800003904032"                                }                            ],                            "parameterValues": [],                            "performer": ""                        },                        {                            "@id": "#process/139800003904368",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800004215280"                            },                            "inputs": [                                {                                    "@id": "#material/extract-139800003904032"                                }                            ],                            "name": "genotype_profiling_XOG5",                            "outputs": [],                            "parameterValues": [],                            "performer": "",                            "previousProcess": {                                "@id": "#process/139800003904320"                            }                        },                        {                            "@id": "#process/139800003904512",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003787312"                            },                            "inputs": [                                {                                    "@id": "#sample/139800003603664"                                }                            ],                            "name": "DNA_extraction_XOG6",                            "nextProcess": {                                "@id": "#process/139800003904560"                            },                            "outputs": [                                {                                    "@id": "#material/extract-139800003904224"                                }                            ],                            "parameterValues": [],                            "performer": ""                        },                        {                            "@id": "#process/139800003904560",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800004215280"                            },                            "inputs": [                                {                                    "@id": "#material/extract-139800003904224"                                }                            ],                            "name": "genotype_profiling_XOG6",                            "outputs": [],                            "parameterValues": [],                            "performer": "",                            "previousProcess": {                                "@id": "#process/139800003904512"                            }                        },                        {                            "@id": "#process/139800003904704",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003787312"                            },                            "inputs": [                                {                                    "@id": "#sample/139800003618080"                                }                            ],                            "name": "DNA_extraction_XOG7",                            "nextProcess": {                                "@id": "#process/139800003904752"                            },                            "outputs": [                                {                                    "@id": "#material/extract-139800003904416"                                }                            ],                            "parameterValues": [],                            "performer": ""                        },                        {                            "@id": "#process/139800003904752",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800004215280"                            },                            "inputs": [                                {                                    "@id": "#material/extract-139800003904416"                                }                            ],                            "name": "genotype_profiling_XOG7",                            "outputs": [],                            "parameterValues": [],                            "performer": "",                            "previousProcess": {                                "@id": "#process/139800003904704"                            }                        },                        {                            "@id": "#process/139800003904896",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003787312"                            },                            "inputs": [                                {                                    "@id": "#sample/139800003620240"                                }                            ],                            "name": "DNA_extraction_XOG8",                            "nextProcess": {                                "@id": "#process/139800003904944"                            },                            "outputs": [                                {                                    "@id": "#material/extract-139800003904608"                                }                            ],                            "parameterValues": [],                            "performer": ""                        },                        {                            "@id": "#process/139800003904944",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800004215280"                            },                            "inputs": [                                {                                    "@id": "#material/extract-139800003904608"                                }                            ],                            "name": "genotype_profiling_XOG8",                            "outputs": [],                            "parameterValues": [],                            "performer": "",                            "previousProcess": {                                "@id": "#process/139800003904896"                            }                        },                        {                            "@id": "#process/139800003905088",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003787312"                            },                            "inputs": [                                {                                    "@id": "#sample/139800003647040"                                }                            ],                            "name": "DNA_extraction_XOG9",                            "nextProcess": {                                "@id": "#process/139800003905136"                            },                            "outputs": [                                {                                    "@id": "#material/extract-139800003904800"                                }                            ],                            "parameterValues": [],                            "performer": ""                        },                        {                            "@id": "#process/139800003905136",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800004215280"                            },                            "inputs": [                                {                                    "@id": "#material/extract-139800003904800"                                }                            ],                            "name": "genotype_profiling_XOG9",                            "outputs": [],                            "parameterValues": [],                            "performer": "",                            "previousProcess": {                                "@id": "#process/139800003905088"                            }                        },                        {                            "@id": "#process/139800003905280",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003787312"                            },                            "inputs": [                                {                                    "@id": "#sample/139800003649200"                                }                            ],                            "name": "DNA_extraction_XOG10",                            "nextProcess": {                                "@id": "#process/139800003905328"                            },                            "outputs": [                                {                                    "@id": "#material/extract-139800003904992"                                }                            ],                            "parameterValues": [],                            "performer": ""                        },                        {                            "@id": "#process/139800003905328",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800004215280"                            },                            "inputs": [                                {                                    "@id": "#material/extract-139800003904992"                                }                            ],                            "name": "genotype_profiling_XOG10",                            "outputs": [],                            "parameterValues": [],                            "performer": "",                            "previousProcess": {                                "@id": "#process/139800003905280"                            }                        }                    ],                    "technologyPlatform": "",                    "technologyType": {                        "@id": "#f6956d0d-874f-4da1-ab57-fccf0d736a5b",                        "annotationValue": "",                        "comments": [],                        "termAccession": "",                        "termSource": ""                    },                    "unitCategories": []                },                {                    "characteristicCategories": [],                    "comments": [],                    "dataFiles": [],                    "filename": "a_assay_methylation.txt",                    "materials": {                        "otherMaterials": [],                        "samples": [                            {                                "@id": "#sample/139800003580448",                                "characteristics": [                                    {                                        "category": {                                            "@id": "#4cdf9dbd-6ddd-41e8-8422-9804584b2e60"                                        },                                        "value": {                                            "@id": "#df6021ba-810a-481e-a1fe-f9984f6fb114",                                            "annotationValue": "buccal mucosa",                                            "comments": [],                                            "termAccession": "http://purl.obolibrary.org/obo/UBERON_0006956",                                            "termSource": "UBERON"                                        }                                    }                                ],                                "factorValues": [],                                "name": "buccal_mucosa_XOP1"                            },                            {                                "@id": "#sample/139800003582704",                                "characteristics": [                                    {                                        "category": {                                            "@id": "#622b879f-a6f6-4546-b5e6-38b1e1694851"                                        },                                        "value": {                                            "@id": "#4f6b004d-7ec2-4f85-a574-1bbab3ca9bf1",                                            "annotationValue": "buccal mucosa",                                            "comments": [],                                            "termAccession": "http://purl.obolibrary.org/obo/UBERON_0006956",                                            "termSource": "UBERON"                                        }                                    }                                ],                                "factorValues": [],                                "name": "buccal_mucosa_XOP2"                            },                            {                                "@id": "#sample/139800003605312",                                "characteristics": [                                    {                                        "category": {                                            "@id": "#bebea860-02de-4cba-b897-c2eadb2fdb99"                                        },                                        "value": {                                            "@id": "#45d141a7-47f3-4fd5-9f5c-dfe0a30cf577",                                            "annotationValue": "buccal mucosa",                                            "comments": [],                                            "termAccession": "http://purl.obolibrary.org/obo/UBERON_0006956",                                            "termSource": "UBERON"                                        }                                    }                                ],                                "factorValues": [],                                "name": "buccal_mucosa_XOP3"                            },                            {                                "@id": "#sample/139800003607424",                                "characteristics": [                                    {                                        "category": {                                            "@id": "#ecae4233-47e2-4182-b15f-410ebc700c39"                                        },                                        "value": {                                            "@id": "#dff5b7d1-2a60-4e5c-98df-caffc23c07f9",                                            "annotationValue": "buccal mucosa",                                            "comments": [],                                            "termAccession": "http://purl.obolibrary.org/obo/UBERON_0006956",                                            "termSource": "UBERON"                                        }                                    }                                ],                                "factorValues": [],                                "name": "buccal_mucosa_XOP4"                            },                            {                                "@id": "#sample/139800003601504",                                "characteristics": [                                    {                                        "category": {                                            "@id": "#3b527ffa-7ec4-4783-99f4-6c736f285e89"                                        },                                        "value": {                                            "@id": "#088f1932-b09d-462d-bd54-2878d3ddedc7",                                            "annotationValue": "buccal mucosa",                                            "comments": [],                                            "termAccession": "http://purl.obolibrary.org/obo/UBERON_0006956",                                            "termSource": "UBERON"                                        }                                    }                                ],                                "factorValues": [],                                "name": "buccal_mucosa_XOP5"                            },                            {                                "@id": "#sample/139800003603664",                                "characteristics": [                                    {                                        "category": {                                            "@id": "#621b4f20-bce3-4e80-af92-d848423d8cdc"                                        },                                        "value": {                                            "@id": "#01906a67-37e9-48a2-8f5a-db2079b27010",                                            "annotationValue": "buccal mucosa",                                            "comments": [],                                            "termAccession": "http://purl.obolibrary.org/obo/UBERON_0006956",                                            "termSource": "UBERON"                                        }                                    }                                ],                                "factorValues": [],                                "name": "buccal_mucosa_XOP6"                            },                            {                                "@id": "#sample/139800003618080",                                "characteristics": [                                    {                                        "category": {                                            "@id": "#dca4e9b6-1a46-4458-926c-13870b8912c0"                                        },                                        "value": {                                            "@id": "#65ef2bcc-f46f-4d76-8bb5-b843d24bf11d",                                            "annotationValue": "buccal mucosa",                                            "comments": [],                                            "termAccession": "http://purl.obolibrary.org/obo/UBERON_0006956",                                            "termSource": "UBERON"                                        }                                    }                                ],                                "factorValues": [],                                "name": "buccal_mucosa_XOP7"                            },                            {                                "@id": "#sample/139800003620240",                                "characteristics": [                                    {                                        "category": {                                            "@id": "#9a95f993-895f-49de-b555-7ff5b4aec454"                                        },                                        "value": {                                            "@id": "#d19d8159-634c-43e3-8f78-bb792fdc14ee",                                            "annotationValue": "buccal mucosa",                                            "comments": [],                                            "termAccession": "http://purl.obolibrary.org/obo/UBERON_0006956",                                            "termSource": "UBERON"                                        }                                    }                                ],                                "factorValues": [],                                "name": "buccal_mucosa_XOP8"                            },                            {                                "@id": "#sample/139800003647040",                                "characteristics": [                                    {                                        "category": {                                            "@id": "#758bc0e4-f18c-4739-889c-fa795fed8f6d"                                        },                                        "value": {                                            "@id": "#55b016d6-340d-42e2-9173-3ce4904ec9fa",                                            "annotationValue": "buccal mucosa",                                            "comments": [],                                            "termAccession": "http://purl.obolibrary.org/obo/UBERON_0006956",                                            "termSource": "UBERON"                                        }                                    }                                ],                                "factorValues": [],                                "name": "buccal_mucosa_XOP9"                            },                            {                                "@id": "#sample/139800003649200",                                "characteristics": [                                    {                                        "category": {                                            "@id": "#09dae57d-2ce9-4a58-b5b9-8b6744817bae"                                        },                                        "value": {                                            "@id": "#90a9e7b6-2c7e-4fa2-b27b-d38e695ec170",                                            "annotationValue": "buccal mucosa",                                            "comments": [],                                            "termAccession": "http://purl.obolibrary.org/obo/UBERON_0006956",                                            "termSource": "UBERON"                                        }                                    }                                ],                                "factorValues": [],                                "name": "buccal_mucosa_XOP10"                            }                        ]                    },                    "measurementType": {                        "@id": "#e4f92279-fc96-435a-82c1-d0a1d4e2a47d",                        "annotationValue": "Methylation Beta Value",                        "comments": [],                        "termAccession": "http://purl.obolibrary.org/obo/NCIT_C164051",                        "termSource": "NCIT"                    },                    "processSequence": [                        {                            "@id": "#process/139800003903984",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003787312"                            },                            "inputs": [                                {                                    "@id": "#sample/139800003580448"                                }                            ],                            "name": "DNA_extraction_XOE1",                            "nextProcess": {                                "@id": "#process/139800003905424"                            },                            "outputs": [                                {                                    "@id": "#material/extract-139800003905184"                                }                            ],                            "parameterValues": [],                            "performer": ""                        },                        {                            "@id": "#process/139800003905424",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800004216912"                            },                            "inputs": [                                {                                    "@id": "#material/extract-139800003905184"                                }                            ],                            "name": "methylation_profiling_XOE1",                            "outputs": [],                            "parameterValues": [],                            "performer": "",                            "previousProcess": {                                "@id": "#process/139800003903984"                            }                        },                        {                            "@id": "#process/139800003905520",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003787312"                            },                            "inputs": [                                {                                    "@id": "#sample/139800003582704"                                }                            ],                            "name": "DNA_extraction_XOE2",                            "nextProcess": {                                "@id": "#process/139800003905568"                            },                            "outputs": [                                {                                    "@id": "#material/extract-139800003660768"                                }                            ],                            "parameterValues": [],                            "performer": ""                        },                        {                            "@id": "#process/139800003905568",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800004216912"                            },                            "inputs": [                                {                                    "@id": "#material/extract-139800003660768"                                }                            ],                            "name": "methylation_profiling_XOE2",                            "outputs": [],                            "parameterValues": [],                            "performer": "",                            "previousProcess": {                                "@id": "#process/139800003905520"                            }                        },                        {                            "@id": "#process/139800003905712",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003787312"                            },                            "inputs": [                                {                                    "@id": "#sample/139800003605312"                                }                            ],                            "name": "DNA_extraction_XOE3",                            "nextProcess": {                                "@id": "#process/139800003905760"                            },                            "outputs": [                                {                                    "@id": "#material/extract-139800003905376"                                }                            ],                            "parameterValues": [],                            "performer": ""                        },                        {                            "@id": "#process/139800003905760",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800004216912"                            },                            "inputs": [                                {                                    "@id": "#material/extract-139800003905376"                                }                            ],                            "name": "methylation_profiling_XOE3",                            "outputs": [],                            "parameterValues": [],                            "performer": "",                            "previousProcess": {                                "@id": "#process/139800003905712"                            }                        },                        {                            "@id": "#process/139800003906144",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003787312"                            },                            "inputs": [                                {                                    "@id": "#sample/139800003607424"                                }                            ],                            "name": "DNA_extraction_XOE4",                            "nextProcess": {                                "@id": "#process/139800003906240"                            },                            "outputs": [                                {                                    "@id": "#material/extract-139800003905616"                                }                            ],                            "parameterValues": [],                            "performer": ""                        },                        {                            "@id": "#process/139800003906240",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800004216912"                            },                            "inputs": [                                {                                    "@id": "#material/extract-139800003905616"                                }                            ],                            "name": "methylation_profiling_XOE4",                            "outputs": [],                            "parameterValues": [],                            "performer": "",                            "previousProcess": {                                "@id": "#process/139800003906144"                            }                        },                        {                            "@id": "#process/139800003906384",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003787312"                            },                            "inputs": [                                {                                    "@id": "#sample/139800003601504"                                }                            ],                            "name": "DNA_extraction_XOE5",                            "nextProcess": {                                "@id": "#process/139800003906480"                            },                            "outputs": [                                {                                    "@id": "#material/extract-139800003906000"                                }                            ],                            "parameterValues": [],                            "performer": ""                        },                        {                            "@id": "#process/139800003906480",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800004216912"                            },                            "inputs": [                                {                                    "@id": "#material/extract-139800003906000"                                }                            ],                            "name": "methylation_profiling_XOE5",                            "outputs": [],                            "parameterValues": [],                            "performer": "",                            "previousProcess": {                                "@id": "#process/139800003906384"                            }                        },                        {                            "@id": "#process/139800003906672",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003787312"                            },                            "inputs": [                                {                                    "@id": "#sample/139800003603664"                                }                            ],                            "name": "DNA_extraction_XOE6",                            "nextProcess": {                                "@id": "#process/139800003906720"                            },                            "outputs": [                                {                                    "@id": "#material/extract-139800003906288"                                }                            ],                            "parameterValues": [],                            "performer": ""                        },                        {                            "@id": "#process/139800003906720",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800004216912"                            },                            "inputs": [                                {                                    "@id": "#material/extract-139800003906288"                                }                            ],                            "name": "methylation_profiling_XOE6",                            "outputs": [],                            "parameterValues": [],                            "performer": "",                            "previousProcess": {                                "@id": "#process/139800003906672"                            }                        },                        {                            "@id": "#process/139800003906816",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003787312"                            },                            "inputs": [                                {                                    "@id": "#sample/139800003618080"                                }                            ],                            "name": "DNA_extraction_XOE7",                            "nextProcess": {                                "@id": "#process/139800003906864"                            },                            "outputs": [                                {                                    "@id": "#material/extract-139800003906576"                                }                            ],                            "parameterValues": [],                            "performer": ""                        },                        {                            "@id": "#process/139800003906864",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800004216912"                            },                            "inputs": [                                {                                    "@id": "#material/extract-139800003906576"                                }                            ],                            "name": "methylation_profiling_XOE7",                            "outputs": [],                            "parameterValues": [],                            "performer": "",                            "previousProcess": {                                "@id": "#process/139800003906816"                            }                        },                        {                            "@id": "#process/139800003906960",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003787312"                            },                            "inputs": [                                {                                    "@id": "#sample/139800003620240"                                }                            ],                            "name": "DNA_extraction_XOE8",                            "nextProcess": {                                "@id": "#process/139800003907008"                            },                            "outputs": [                                {                                    "@id": "#material/extract-139800003905952"                                }                            ],                            "parameterValues": [],                            "performer": ""                        },                        {                            "@id": "#process/139800003907008",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800004216912"                            },                            "inputs": [                                {                                    "@id": "#material/extract-139800003905952"                                }                            ],                            "name": "methylation_profiling_XOE8",                            "outputs": [],                            "parameterValues": [],                            "performer": "",                            "previousProcess": {                                "@id": "#process/139800003906960"                            }                        },                        {                            "@id": "#process/139800003907152",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003787312"                            },                            "inputs": [                                {                                    "@id": "#sample/139800003647040"                                }                            ],                            "name": "DNA_extraction_XOE9",                            "nextProcess": {                                "@id": "#process/139800003907200"                            },                            "outputs": [                                {                                    "@id": "#material/extract-139800003906912"                                }                            ],                            "parameterValues": [],                            "performer": ""                        },                        {                            "@id": "#process/139800003907200",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800004216912"                            },                            "inputs": [                                {                                    "@id": "#material/extract-139800003906912"                                }                            ],                            "name": "methylation_profiling_XOE9",                            "outputs": [],                            "parameterValues": [],                            "performer": "",                            "previousProcess": {                                "@id": "#process/139800003907152"                            }                        },                        {                            "@id": "#process/139800003907296",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003787312"                            },                            "inputs": [                                {                                    "@id": "#sample/139800003649200"                                }                            ],                            "name": "DNA_extraction_XOE10",                            "nextProcess": {                                "@id": "#process/139800003907344"                            },                            "outputs": [                                {                                    "@id": "#material/extract-139800003907056"                                }                            ],                            "parameterValues": [],                            "performer": ""                        },                        {                            "@id": "#process/139800003907344",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800004216912"                            },                            "inputs": [                                {                                    "@id": "#material/extract-139800003907056"                                }                            ],                            "name": "methylation_profiling_XOE10",                            "outputs": [],                            "parameterValues": [],                            "performer": "",                            "previousProcess": {                                "@id": "#process/139800003907296"                            }                        }                    ],                    "technologyPlatform": {                        "@id": "#e54abc19-011c-494b-a40a-e65dfeba091d",                        "annotationValue": "Illumina Infinium MethylationEPIC BeadChip",                        "comments": [],                        "termAccession": "http://purl.obolibrary.org/obo/OBI_0002131",                        "termSource": "OBI"                    },                    "technologyType": {                        "@id": "#3f252873-064c-44f9-adc4-2b6d88afb183",                        "annotationValue": "DNA methylation profiling by array assay",                        "comments": [],                        "termAccession": "http://purl.obolibrary.org/obo/OBI_0001332",                        "termSource": "OBI"                    },                    "unitCategories": []                },                {                    "characteristicCategories": [],                    "comments": [],                    "dataFiles": [                        {                            "@id": "#data/rawspectraldatafile-139800003192960",                            "comments": [],                            "name": "link/to/raw/data",                            "type": "Raw Spectral Data File"                        },                        {                            "@id": "#data/normalizationname-139800003193056",                            "comments": [],                            "name": "link/to/normalized_data",                            "type": "Normalization Name"                        },                        {                            "@id": "#data/derivedspectraldatafile-139800003193008",                            "comments": [],                            "name": "link/to/spectral_file",                            "type": "Derived Spectral Data File"                        },                        {                            "@id": "#data/datatransformationname-139800003193200",                            "comments": [],                            "name": "link/to/data_transformation_name",                            "type": "Data Transformation Name"                        },                        {                            "@id": "#data/metaboliteassignmentfile-139800003193344",                            "comments": [],                            "name": "link/to/MAF",                            "type": "Metabolite Assignment File"                        },                        {                            "@id": "#data/rawspectraldatafile-139800003192960",                            "comments": [],                            "name": "link/to/raw/data",                            "type": "Raw Spectral Data File"                        },                        {                            "@id": "#data/normalizationname-139800003193056",                            "comments": [],                            "name": "link/to/normalized_data",                            "type": "Normalization Name"                        },                        {                            "@id": "#data/derivedspectraldatafile-139800003193008",                            "comments": [],                            "name": "link/to/spectral_file",                            "type": "Derived Spectral Data File"                        },                        {                            "@id": "#data/datatransformationname-139800003193200",                            "comments": [],                            "name": "link/to/data_transformation_name",                            "type": "Data Transformation Name"                        },                        {                            "@id": "#data/metaboliteassignmentfile-139800003193344",                            "comments": [],                            "name": "link/to/MAF",                            "type": "Metabolite Assignment File"                        },                        {                            "@id": "#data/rawspectraldatafile-139800003192960",                            "comments": [],                            "name": "link/to/raw/data",                            "type": "Raw Spectral Data File"                        },                        {                            "@id": "#data/normalizationname-139800003193056",                            "comments": [],                            "name": "link/to/normalized_data",                            "type": "Normalization Name"                        },                        {                            "@id": "#data/derivedspectraldatafile-139800003193008",                            "comments": [],                            "name": "link/to/spectral_file",                            "type": "Derived Spectral Data File"                        },                        {                            "@id": "#data/datatransformationname-139800003193200",                            "comments": [],                            "name": "link/to/data_transformation_name",                            "type": "Data Transformation Name"                        },                        {                            "@id": "#data/metaboliteassignmentfile-139800003193344",                            "comments": [],                            "name": "link/to/MAF",                            "type": "Metabolite Assignment File"                        },                        {                            "@id": "#data/rawspectraldatafile-139800003192960",                            "comments": [],                            "name": "link/to/raw/data",                            "type": "Raw Spectral Data File"                        },                        {                            "@id": "#data/normalizationname-139800003193056",                            "comments": [],                            "name": "link/to/normalized_data",                            "type": "Normalization Name"                        },                        {                            "@id": "#data/derivedspectraldatafile-139800003193008",                            "comments": [],                            "name": "link/to/spectral_file",                            "type": "Derived Spectral Data File"                        },                        {                            "@id": "#data/datatransformationname-139800003193200",                            "comments": [],                            "name": "link/to/data_transformation_name",                            "type": "Data Transformation Name"                        },                        {                            "@id": "#data/metaboliteassignmentfile-139800003193344",                            "comments": [],                            "name": "link/to/MAF",                            "type": "Metabolite Assignment File"                        },                        {                            "@id": "#data/rawspectraldatafile-139800003192960",                            "comments": [],                            "name": "link/to/raw/data",                            "type": "Raw Spectral Data File"                        },                        {                            "@id": "#data/normalizationname-139800003193056",                            "comments": [],                            "name": "link/to/normalized_data",                            "type": "Normalization Name"                        },                        {                            "@id": "#data/derivedspectraldatafile-139800003193008",                            "comments": [],                            "name": "link/to/spectral_file",                            "type": "Derived Spectral Data File"                        },                        {                            "@id": "#data/datatransformationname-139800003193200",                            "comments": [],                            "name": "link/to/data_transformation_name",                            "type": "Data Transformation Name"                        },                        {                            "@id": "#data/metaboliteassignmentfile-139800003193344",                            "comments": [],                            "name": "link/to/MAF",                            "type": "Metabolite Assignment File"                        },                        {                            "@id": "#data/rawspectraldatafile-139800003192960",                            "comments": [],                            "name": "link/to/raw/data",                            "type": "Raw Spectral Data File"                        },                        {                            "@id": "#data/normalizationname-139800003193056",                            "comments": [],                            "name": "link/to/normalized_data",                            "type": "Normalization Name"                        },                        {                            "@id": "#data/derivedspectraldatafile-139800003193008",                            "comments": [],                            "name": "link/to/spectral_file",                            "type": "Derived Spectral Data File"                        },                        {                            "@id": "#data/datatransformationname-139800003193200",                            "comments": [],                            "name": "link/to/data_transformation_name",                            "type": "Data Transformation Name"                        },                        {                            "@id": "#data/metaboliteassignmentfile-139800003193344",                            "comments": [],                            "name": "link/to/MAF",                            "type": "Metabolite Assignment File"                        },                        {                            "@id": "#data/rawspectraldatafile-139800003192960",                            "comments": [],                            "name": "link/to/raw/data",                            "type": "Raw Spectral Data File"                        },                        {                            "@id": "#data/normalizationname-139800003193056",                            "comments": [],                            "name": "link/to/normalized_data",                            "type": "Normalization Name"                        },                        {                            "@id": "#data/derivedspectraldatafile-139800003193008",                            "comments": [],                            "name": "link/to/spectral_file",                            "type": "Derived Spectral Data File"                        },                        {                            "@id": "#data/datatransformationname-139800003193200",                            "comments": [],                            "name": "link/to/data_transformation_name",                            "type": "Data Transformation Name"                        },                        {                            "@id": "#data/metaboliteassignmentfile-139800003193344",                            "comments": [],                            "name": "link/to/MAF",                            "type": "Metabolite Assignment File"                        },                        {                            "@id": "#data/rawspectraldatafile-139800003192960",                            "comments": [],                            "name": "link/to/raw/data",                            "type": "Raw Spectral Data File"                        },                        {                            "@id": "#data/normalizationname-139800003193056",                            "comments": [],                            "name": "link/to/normalized_data",                            "type": "Normalization Name"                        },                        {                            "@id": "#data/derivedspectraldatafile-139800003193008",                            "comments": [],                            "name": "link/to/spectral_file",                            "type": "Derived Spectral Data File"                        },                        {                            "@id": "#data/datatransformationname-139800003193200",                            "comments": [],                            "name": "link/to/data_transformation_name",                            "type": "Data Transformation Name"                        },                        {                            "@id": "#data/metaboliteassignmentfile-139800003193344",                            "comments": [],                            "name": "link/to/MAF",                            "type": "Metabolite Assignment File"                        },                        {                            "@id": "#data/rawspectraldatafile-139800003192960",                            "comments": [],                            "name": "link/to/raw/data",                            "type": "Raw Spectral Data File"                        },                        {                            "@id": "#data/normalizationname-139800003193056",                            "comments": [],                            "name": "link/to/normalized_data",                            "type": "Normalization Name"                        },                        {                            "@id": "#data/derivedspectraldatafile-139800003193008",                            "comments": [],                            "name": "link/to/spectral_file",                            "type": "Derived Spectral Data File"                        },                        {                            "@id": "#data/datatransformationname-139800003193200",                            "comments": [],                            "name": "link/to/data_transformation_name",                            "type": "Data Transformation Name"                        },                        {                            "@id": "#data/metaboliteassignmentfile-139800003193344",                            "comments": [],                            "name": "link/to/MAF",                            "type": "Metabolite Assignment File"                        },                        {                            "@id": "#data/rawspectraldatafile-139800003192960",                            "comments": [],                            "name": "link/to/raw/data",                            "type": "Raw Spectral Data File"                        },                        {                            "@id": "#data/normalizationname-139800003193056",                            "comments": [],                            "name": "link/to/normalized_data",                            "type": "Normalization Name"                        },                        {                            "@id": "#data/derivedspectraldatafile-139800003193008",                            "comments": [],                            "name": "link/to/spectral_file",                            "type": "Derived Spectral Data File"                        },                        {                            "@id": "#data/datatransformationname-139800003193200",                            "comments": [],                            "name": "link/to/data_transformation_name",                            "type": "Data Transformation Name"                        },                        {                            "@id": "#data/metaboliteassignmentfile-139800003193344",                            "comments": [],                            "name": "link/to/MAF",                            "type": "Metabolite Assignment File"                        }                    ],                    "filename": "a_assay_metabolomics_amines.txt",                    "materials": {                        "otherMaterials": [                            {                                "@id": "#material/extract-139800003194448",                                "characteristics": [],                                "name": "extract_XOM1 ",                                "type": "Extract Name"                            },                            {                                "@id": "#material/labledextract-139800003194592",                                "characteristics": [],                                "name": "labeled_XOM1 ",                                "type": "Labeled Extract Name"                            },                            {                                "@id": "#material/extract-139800003189824",                                "characteristics": [],                                "name": "extract_XOM2",                                "type": "Extract Name"                            },                            {                                "@id": "#material/labledextract-139800003189968",                                "characteristics": [],                                "name": "labeled_XOM2",                                "type": "Labeled Extract Name"                            },                            {                                "@id": "#material/extract-139800003390048",                                "characteristics": [],                                "name": "extract_XOM3",                                "type": "Extract Name"                            },                            {                                "@id": "#material/labledextract-139800003389472",                                "characteristics": [],                                "name": "labeled_XOM3",                                "type": "Labeled Extract Name"                            },                            {                                "@id": "#material/extract-139800003213248",                                "characteristics": [],                                "name": "extract_XOM4",                                "type": "Extract Name"                            },                            {                                "@id": "#material/labledextract-139800003213392",                                "characteristics": [],                                "name": "labeled_XOM4",                                "type": "Labeled Extract Name"                            },                            {                                "@id": "#material/extract-139800003224960",                                "characteristics": [],                                "name": "extract_XOM5",                                "type": "Extract Name"                            },                            {                                "@id": "#material/labledextract-139800003225200",                                "characteristics": [],                                "name": "labeled_XOM5",                                "type": "Labeled Extract Name"                            },                            {                                "@id": "#material/extract-139800003241008",                                "characteristics": [],                                "name": "extract_XOM6",                                "type": "Extract Name"                            },                            {                                "@id": "#material/labledextract-139800003241248",                                "characteristics": [],                                "name": "labeled_XOM6",                                "type": "Labeled Extract Name"                            },                            {                                "@id": "#material/extract-139800003252768",                                "characteristics": [],                                "name": "extract_XOM7",                                "type": "Extract Name"                            },                            {                                "@id": "#material/labledextract-139800003252912",                                "characteristics": [],                                "name": "labeled_XOM7",                                "type": "Labeled Extract Name"                            },                            {                                "@id": "#material/extract-139800003253200",                                "characteristics": [],                                "name": "extract_XOM8",                                "type": "Extract Name"                            },                            {                                "@id": "#material/labledextract-139800003255504",                                "characteristics": [],                                "name": "labeled_XOM8",                                "type": "Labeled Extract Name"                            },                            {                                "@id": "#material/extract-139800003272032",                                "characteristics": [],                                "name": "extract_XOM9",                                "type": "Extract Name"                            },                            {                                "@id": "#material/labledextract-139800003272224",                                "characteristics": [],                                "name": "labeled_XOM9",                                "type": "Labeled Extract Name"                            },                            {                                "@id": "#material/extract-139800003284128",                                "characteristics": [],                                "name": "extract_XOM10",                                "type": "Extract Name"                            },                            {                                "@id": "#material/labledextract-139800003284272",                                "characteristics": [],                                "name": "labeled_XOM10",                                "type": "Labeled Extract Name"                            }                        ],                        "samples": [                            {                                "@id": "#sample/139800003550704",                                "characteristics": [                                    {                                        "category": {                                            "@id": "#196b3e41-5a75-439f-aacd-06b46d06be25"                                        },                                        "value": {                                            "@id": "#b4c7521a-9349-41b2-926e-f37c8d272824",                                            "annotationValue": "urine",                                            "comments": [],                                            "termAccession": "http://purl.obolibrary.org/obo/UBERON_0001088",                                            "termSource": "UBERON"                                        }                                    },                                    {                                        "category": {                                            "@id": "#9c885ee6-527b-4b1f-868d-b63b2c3c186b"                                        },                                        "value": {                                            "@id": "#6de4f95f-fa62-4cbb-9d7d-0613ddfa140f",                                            "annotationValue": "experimental sample",                                            "comments": [],                                            "termAccession": "http://purl.obolibrary.org/obo/CHMO_0002746",                                            "termSource": "CHMO"                                        }                                    }                                ],                                "factorValues": [],                                "name": "urine_XOP1"                            },                            {                                "@id": "#sample/139800003581792",                                "characteristics": [                                    {                                        "category": {                                            "@id": "#7f429d01-61c1-4d86-9942-d90b366be47c"                                        },                                        "value": {                                            "@id": "#850e1951-47c2-400e-947f-fd5cbe7c54a6",                                            "annotationValue": "urine",                                            "comments": [],                                            "termAccession": "http://purl.obolibrary.org/obo/UBERON_0001088",                                            "termSource": "UBERON"                                        }                                    },                                    {                                        "category": {                                            "@id": "#43caf586-7aae-4dc7-998e-6a20aef00875"                                        },                                        "value": {                                            "@id": "#4c4f5e89-8f99-4f6c-98b4-e5420d666080",                                            "annotationValue": "experimental sample",                                            "comments": [],                                            "termAccession": "http://purl.obolibrary.org/obo/CHMO_0002746",                                            "termSource": "CHMO"                                        }                                    }                                ],                                "factorValues": [],                                "name": "urine_XOP2"                            },                            {                                "@id": "#sample/139800003604592",                                "characteristics": [                                    {                                        "category": {                                            "@id": "#4720eed4-9af5-4fd5-9fb4-a750508187c0"                                        },                                        "value": {                                            "@id": "#a9ddbe6d-2102-4c3c-8214-f4eb1e91438b",                                            "annotationValue": "urine",                                            "comments": [],                                            "termAccession": "http://purl.obolibrary.org/obo/UBERON_0001088",                                            "termSource": "UBERON"                                        }                                    },                                    {                                        "category": {                                            "@id": "#d48be27a-c378-4f7c-b514-7b8439140fbc"                                        },                                        "value": {                                            "@id": "#910ea8e4-77ff-46be-acac-4dd1315d83f7",                                            "annotationValue": "experimental sample",                                            "comments": [],                                            "termAccession": "http://purl.obolibrary.org/obo/CHMO_0002746",                                            "termSource": "CHMO"                                        }                                    }                                ],                                "factorValues": [],                                "name": "urine_XOP3"                            },                            {                                "@id": "#sample/139800003606704",                                "characteristics": [                                    {                                        "category": {                                            "@id": "#2e697ec4-4d72-4b76-95d1-061fbc7269f3"                                        },                                        "value": {                                            "@id": "#ebe6698f-ec4d-440b-9aa7-e75e0a45ffce",                                            "annotationValue": "urine",                                            "comments": [],                                            "termAccession": "http://purl.obolibrary.org/obo/UBERON_0001088",                                            "termSource": "UBERON"                                        }                                    },                                    {                                        "category": {                                            "@id": "#4f140a54-71da-46d7-94dd-9a846f7961cd"                                        },                                        "value": {                                            "@id": "#4a1eda5e-2e99-4295-9c27-3f95939d6ae0",                                            "annotationValue": "experimental sample",                                            "comments": [],                                            "termAccession": "http://purl.obolibrary.org/obo/CHMO_0002746",                                            "termSource": "CHMO"                                        }                                    }                                ],                                "factorValues": [],                                "name": "urine_XOP4"                            },                            {                                "@id": "#sample/139800003600640",                                "characteristics": [                                    {                                        "category": {                                            "@id": "#64eebdc9-433a-4ce0-a07c-490b3e97427c"                                        },                                        "value": {                                            "@id": "#abc046b0-091c-4326-85ca-95f13ec34337",                                            "annotationValue": "urine",                                            "comments": [],                                            "termAccession": "http://purl.obolibrary.org/obo/UBERON_0001088",                                            "termSource": "UBERON"                                        }                                    },                                    {                                        "category": {                                            "@id": "#bfd93452-d295-474a-9fd5-73a9328fb35c"                                        },                                        "value": {                                            "@id": "#1dca670a-c7b0-48b1-b5a0-30d48bdda1bb",                                            "annotationValue": "experimental sample",                                            "comments": [],                                            "termAccession": "http://purl.obolibrary.org/obo/CHMO_0002746",                                            "termSource": "CHMO"                                        }                                    }                                ],                                "factorValues": [],                                "name": "urine_XOP5"                            },                            {                                "@id": "#sample/139800003600592",                                "characteristics": [                                    {                                        "category": {                                            "@id": "#768a76a7-4463-4937-a4de-857164e5fff3"                                        },                                        "value": {                                            "@id": "#44da0995-dc29-49aa-b8c6-1771ff1b4983",                                            "annotationValue": "urine",                                            "comments": [],                                            "termAccession": "http://purl.obolibrary.org/obo/UBERON_0001088",                                            "termSource": "UBERON"                                        }                                    },                                    {                                        "category": {                                            "@id": "#62204b82-d75c-49f3-b7db-a86c7daa395b"                                        },                                        "value": {                                            "@id": "#7eff269c-7c87-46b6-82c5-af425e533f5c",                                            "annotationValue": "experimental sample",                                            "comments": [],                                            "termAccession": "http://purl.obolibrary.org/obo/CHMO_0002746",                                            "termSource": "CHMO"                                        }                                    }                                ],                                "factorValues": [],                                "name": "urine_XOP6"                            },                            {                                "@id": "#sample/139800003617216",                                "characteristics": [                                    {                                        "category": {                                            "@id": "#7342cd89-8093-420d-ae32-20f4c328cb1f"                                        },                                        "value": {                                            "@id": "#3a2f1236-f52c-4cde-b885-8a49f8bd945f",                                            "annotationValue": "urine",                                            "comments": [],                                            "termAccession": "http://purl.obolibrary.org/obo/UBERON_0001088",                                            "termSource": "UBERON"                                        }                                    },                                    {                                        "category": {                                            "@id": "#3f136fcd-9b03-4296-a2fa-3cfd961d2041"                                        },                                        "value": {                                            "@id": "#c9983013-a289-41b0-a535-ac36b5ed66ec",                                            "annotationValue": "experimental sample",                                            "comments": [],                                            "termAccession": "http://purl.obolibrary.org/obo/CHMO_0002746",                                            "termSource": "CHMO"                                        }                                    }                                ],                                "factorValues": [],                                "name": "urine_XOP7"                            },                            {                                "@id": "#sample/139800003617120",                                "characteristics": [                                    {                                        "category": {                                            "@id": "#4ae1915a-7cf4-487e-abeb-e0378a0f881b"                                        },                                        "value": {                                            "@id": "#1be733cf-5686-46bc-9468-08af1adb0265",                                            "annotationValue": "urine",                                            "comments": [],                                            "termAccession": "http://purl.obolibrary.org/obo/UBERON_0001088",                                            "termSource": "UBERON"                                        }                                    },                                    {                                        "category": {                                            "@id": "#f85fcc53-0e49-4430-90b8-a32e79ad12ed"                                        },                                        "value": {                                            "@id": "#43d8b5bc-ffbe-47cc-9702-5f8724f3a832",                                            "annotationValue": "experimental sample",                                            "comments": [],                                            "termAccession": "http://purl.obolibrary.org/obo/CHMO_0002746",                                            "termSource": "CHMO"                                        }                                    }                                ],                                "factorValues": [],                                "name": "urine_XOP8"                            },                            {                                "@id": "#sample/139800003646176",                                "characteristics": [                                    {                                        "category": {                                            "@id": "#df3be894-44ea-4f1e-9f38-79bf2811b4ba"                                        },                                        "value": {                                            "@id": "#8a42510b-d0a2-4b5c-9c77-96b0ab30fbf3",                                            "annotationValue": "urine",                                            "comments": [],                                            "termAccession": "http://purl.obolibrary.org/obo/UBERON_0001088",                                            "termSource": "UBERON"                                        }                                    },                                    {                                        "category": {                                            "@id": "#de90c9fc-5316-490d-aa56-c0a5af098e70"                                        },                                        "value": {                                            "@id": "#73b93652-4208-4191-91fd-bc6b0b521260",                                            "annotationValue": "experimental sample",                                            "comments": [],                                            "termAccession": "http://purl.obolibrary.org/obo/CHMO_0002746",                                            "termSource": "CHMO"                                        }                                    }                                ],                                "factorValues": [],                                "name": "urine_XOP9"                            },                            {                                "@id": "#sample/139800003646080",                                "characteristics": [                                    {                                        "category": {                                            "@id": "#713c5fa7-ee56-42e5-b084-a5008269ff0c"                                        },                                        "value": {                                            "@id": "#cf7e8c2e-3b58-46a2-8ed7-1fc3ceff8e30",                                            "annotationValue": "urine",                                            "comments": [],                                            "termAccession": "http://purl.obolibrary.org/obo/UBERON_0001088",                                            "termSource": "UBERON"                                        }                                    },                                    {                                        "category": {                                            "@id": "#8e38bdf2-412e-402b-89a6-7483806710b3"                                        },                                        "value": {                                            "@id": "#b2e45b85-affa-4582-9712-22b704630657",                                            "annotationValue": "experimental sample",                                            "comments": [],                                            "termAccession": "http://purl.obolibrary.org/obo/CHMO_0002746",                                            "termSource": "CHMO"                                        }                                    }                                ],                                "factorValues": [],                                "name": "urine_XOP10"                            }                        ]                    },                    "measurementType": {                        "@id": "#51e4100d-df69-4a53-b889-dfea40be8daa",                        "annotationValue": "targeted metabolite profiling",                        "comments": [],                        "termAccession": "http://purl.obolibrary.org/obo/MSIO_0000100",                        "termSource": "MSIO"                    },                    "processSequence": [                        {                            "@id": "#process/139800003194544",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003740624"                            },                            "inputs": [                                {                                    "@id": "#sample/139800003550704"                                }                            ],                            "name": "",                            "nextProcess": {                                "@id": "#process/139800003194688"                            },                            "outputs": [                                {                                    "@id": "#material/extract-139800003194448"                                }                            ],                            "parameterValues": [                                {                                    "category": {                                        "@id": "#139800003193872"                                    },                                    "value": {                                        "@id": "#9a03199b-152c-4579-a274-feef9beadaf7",                                        "annotationValue": "1 uL borate buffer (pH 8.8) with AQC reagent",                                        "comments": [],                                        "termAccession": "",                                        "termSource": ""                                    }                                },                                {                                    "category": {                                        "@id": "#139800003194352"                                    },                                    "value": "AQC"                                }                            ],                            "performer": ""                        },                        {                            "@id": "#process/139800003194688",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003893328"                            },                            "inputs": [                                {                                    "@id": "#material/extract-139800003194448"                                }                            ],                            "name": "",                            "nextProcess": {                                "@id": "#process/139800003187472"                            },                            "outputs": [                                {                                    "@id": "#material/labledextract-139800003194592"                                }                            ],                            "parameterValues": [],                            "performer": "",                            "previousProcess": {                                "@id": "#process/139800003194544"                            }                        },                        {                            "@id": "#process/139800003187472",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003892176"                            },                            "inputs": [                                {                                    "@id": "#material/labledextract-139800003194592"                                }                            ],                            "name": "chromatography_XOM1 ",                            "nextProcess": {                                "@id": "#process/139800003189008"                            },                            "outputs": [],                            "parameterValues": [                                {                                    "category": {                                        "@id": "#139800003194832"                                    },                                    "value": "Agilent 1290 Infinity II"                                },                                {                                    "category": {                                        "@id": "#139800003187088"                                    },                                    "value": "Accq-Tag Ultra column (waters   FURHTER SPECS?)"                                },                                {                                    "category": {                                        "@id": "#139800003187376"                                    },                                    "value": "reverse phase"                                }                            ],                            "performer": "",                            "previousProcess": {                                "@id": "#process/139800003194688"                            }                        },                        {                            "@id": "#process/139800003189008",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003786688"                            },                            "inputs": [],                            "name": "mass_spectrometry_XOM1 ",                            "nextProcess": {                                "@id": "#process/139800003189056"                            },                            "outputs": [                                {                                    "@id": "#data/rawspectraldatafile-139800003192960"                                }                            ],                            "parameterValues": [                                {                                    "category": {                                        "@id": "#139800003187712"                                    },                                    "value": "positive"                                },                                {                                    "category": {                                        "@id": "#139800003188000"                                    },                                    "value": "5-2000?"                                },                                {                                    "category": {                                        "@id": "#139800003188288"                                    },                                    "value": "AB SCIEX Qtrap 6500"                                },                                {                                    "category": {                                        "@id": "#139800003188576"                                    },                                    "value": "ESI"                                },                                {                                    "category": {                                        "@id": "#139800003188864"                                    },                                    "value": "triple quadrupole linear ion trap"                                }                            ],                            "performer": "",                            "previousProcess": {                                "@id": "#process/139800003187472"                            }                        },                        {                            "@id": "#process/139800003189056",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003894048"                            },                            "inputs": [                                {                                    "@id": "#data/rawspectraldatafile-139800003192960"                                }                            ],                            "name": "data_transformation_XOM1 ",                            "nextProcess": {                                "@id": "#process/139800003189104"                            },                            "outputs": [                                {                                    "@id": "#data/normalizationname-139800003193056"                                },                                {                                    "@id": "#data/derivedspectraldatafile-139800003193008"                                }                            ],                            "parameterValues": [],                            "performer": "",                            "previousProcess": {                                "@id": "#process/139800003189008"                            }                        },                        {                            "@id": "#process/139800003189104",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003893904"                            },                            "inputs": [                                {                                    "@id": "#data/normalizationname-139800003193056"                                }                            ],                            "name": "metabolite_identification_XOM1 ",                            "outputs": [                                {                                    "@id": "#data/datatransformationname-139800003193200"                                },                                {                                    "@id": "#data/metaboliteassignmentfile-139800003193344"                                }                            ],                            "parameterValues": [],                            "performer": "",                            "previousProcess": {                                "@id": "#process/139800003189056"                            }                        },                        {                            "@id": "#process/139800003189920",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003740624"                            },                            "inputs": [                                {                                    "@id": "#sample/139800003581792"                                }                            ],                            "name": "",                            "nextProcess": {                                "@id": "#process/139800003190064"                            },                            "outputs": [                                {                                    "@id": "#material/extract-139800003189824"                                }                            ],                            "parameterValues": [                                {                                    "category": {                                        "@id": "#139800003189344"                                    },                                    "value": {                                        "@id": "#96709fcf-8102-4dc7-b7ba-8cd1ea493055",                                        "annotationValue": "1 uL borate buffer (pH 8.8) with AQC reagent",                                        "comments": [],                                        "termAccession": "",                                        "termSource": ""                                    }                                },                                {                                    "category": {                                        "@id": "#139800003189728"                                    },                                    "value": "AQC"                                }                            ],                            "performer": ""                        },                        {                            "@id": "#process/139800003190064",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003893328"                            },                            "inputs": [                                {                                    "@id": "#material/extract-139800003189824"                                }                            ],                            "name": "",                            "nextProcess": {                                "@id": "#process/139800003387648"                            },                            "outputs": [                                {                                    "@id": "#material/labledextract-139800003189968"                                }                            ],                            "parameterValues": [],                            "performer": "",                            "previousProcess": {                                "@id": "#process/139800003189920"                            }                        },                        {                            "@id": "#process/139800003387648",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003892176"                            },                            "inputs": [                                {                                    "@id": "#material/labledextract-139800003189968"                                }                            ],                            "name": "chromatography_XOM2",                            "nextProcess": {                                "@id": "#process/139800003389232"                            },                            "outputs": [],                            "parameterValues": [                                {                                    "category": {                                        "@id": "#139800003190304"                                    },                                    "value": "Agilent 1290 Infinity II"                                },                                {                                    "category": {                                        "@id": "#139800003190592"                                    },                                    "value": "Accq-Tag Ultra column (waters   FURHTER SPECS?)"                                },                                {                                    "category": {                                        "@id": "#139800003387552"                                    },                                    "value": "reverse phase"                                }                            ],                            "performer": "",                            "previousProcess": {                                "@id": "#process/139800003190064"                            }                        },                        {                            "@id": "#process/139800003389232",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003786688"                            },                            "inputs": [],                            "name": "mass_spectrometry_XOM2",                            "nextProcess": {                                "@id": "#process/139800003389184"                            },                            "outputs": [                                {                                    "@id": "#data/rawspectraldatafile-139800003192960"                                }                            ],                            "parameterValues": [                                {                                    "category": {                                        "@id": "#139800003388080"                                    },                                    "value": "positive"                                },                                {                                    "category": {                                        "@id": "#139800003388368"                                    },                                    "value": "5-2000?"                                },                                {                                    "category": {                                        "@id": "#139800003387792"                                    },                                    "value": "AB SCIEX Qtrap 6500"                                },                                {                                    "category": {                                        "@id": "#139800003388848"                                    },                                    "value": "ESI"                                },                                {                                    "category": {                                        "@id": "#139800003907392"                                    },                                    "value": "triple quadrupole linear ion trap"                                }                            ],                            "performer": "",                            "previousProcess": {                                "@id": "#process/139800003387648"                            }                        },                        {                            "@id": "#process/139800003389184",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003894048"                            },                            "inputs": [                                {                                    "@id": "#data/rawspectraldatafile-139800003192960"                                }                            ],                            "name": "data_transformation_XOM2",                            "nextProcess": {                                "@id": "#process/139800003389280"                            },                            "outputs": [                                {                                    "@id": "#data/normalizationname-139800003193056"                                },                                {                                    "@id": "#data/derivedspectraldatafile-139800003193008"                                }                            ],                            "parameterValues": [],                            "performer": "",                            "previousProcess": {                                "@id": "#process/139800003389232"                            }                        },                        {                            "@id": "#process/139800003389280",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003893904"                            },                            "inputs": [                                {                                    "@id": "#data/normalizationname-139800003193056"                                }                            ],                            "name": "metabolite_identification_XOM2",                            "outputs": [                                {                                    "@id": "#data/datatransformationname-139800003193200"                                },                                {                                    "@id": "#data/metaboliteassignmentfile-139800003193344"                                }                            ],                            "parameterValues": [],                            "performer": "",                            "previousProcess": {                                "@id": "#process/139800003389184"                            }                        },                        {                            "@id": "#process/139800003390192",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003740624"                            },                            "inputs": [                                {                                    "@id": "#sample/139800003604592"                                }                            ],                            "name": "",                            "nextProcess": {                                "@id": "#process/139800003390288"                            },                            "outputs": [                                {                                    "@id": "#material/extract-139800003390048"                                }                            ],                            "parameterValues": [                                {                                    "category": {                                        "@id": "#139800003389616"                                    },                                    "value": {                                        "@id": "#cc74eea3-1d4e-4c75-9862-22bee7832cb9",                                        "annotationValue": "1 uL borate buffer (pH 8.8) with AQC reagent",                                        "comments": [],                                        "termAccession": "",                                        "termSource": ""                                    }                                },                                {                                    "category": {                                        "@id": "#139800003390000"                                    },                                    "value": "AQC"                                }                            ],                            "performer": ""                        },                        {                            "@id": "#process/139800003390288",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003893328"                            },                            "inputs": [                                {                                    "@id": "#material/extract-139800003390048"                                }                            ],                            "name": "",                            "nextProcess": {                                "@id": "#process/139800003391200"                            },                            "outputs": [                                {                                    "@id": "#material/labledextract-139800003389472"                                }                            ],                            "parameterValues": [],                            "performer": "",                            "previousProcess": {                                "@id": "#process/139800003390192"                            }                        },                        {                            "@id": "#process/139800003391200",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003892176"                            },                            "inputs": [                                {                                    "@id": "#material/labledextract-139800003389472"                                }                            ],                            "name": "chromatography_XOM3",                            "nextProcess": {                                "@id": "#process/139800003212432"                            },                            "outputs": [],                            "parameterValues": [                                {                                    "category": {                                        "@id": "#139800003390528"                                    },                                    "value": "Agilent 1290 Infinity II"                                },                                {                                    "category": {                                        "@id": "#139800003390816"                                    },                                    "value": "Accq-Tag Ultra column (waters   FURHTER SPECS?)"                                },                                {                                    "category": {                                        "@id": "#139800003391104"                                    },                                    "value": "reverse phase"                                }                            ],                            "performer": "",                            "previousProcess": {                                "@id": "#process/139800003390288"                            }                        },                        {                            "@id": "#process/139800003212432",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003786688"                            },                            "inputs": [],                            "name": "mass_spectrometry_XOM3",                            "nextProcess": {                                "@id": "#process/139800003212480"                            },                            "outputs": [                                {                                    "@id": "#data/rawspectraldatafile-139800003192960"                                }                            ],                            "parameterValues": [                                {                                    "category": {                                        "@id": "#139800003391440"                                    },                                    "value": "positive"                                },                                {                                    "category": {                                        "@id": "#139800003211424"                                    },                                    "value": "5-2000?"                                },                                {                                    "category": {                                        "@id": "#139800003211712"                                    },                                    "value": "AB SCIEX Qtrap 6500"                                },                                {                                    "category": {                                        "@id": "#139800003212000"                                    },                                    "value": "ESI"                                },                                {                                    "category": {                                        "@id": "#139800003212288"                                    },                                    "value": "triple quadrupole linear ion trap"                                }                            ],                            "performer": "",                            "previousProcess": {                                "@id": "#process/139800003391200"                            }                        },                        {                            "@id": "#process/139800003212480",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003894048"                            },                            "inputs": [                                {                                    "@id": "#data/rawspectraldatafile-139800003192960"                                }                            ],                            "name": "data_transformation_XOM3",                            "nextProcess": {                                "@id": "#process/139800003212528"                            },                            "outputs": [                                {                                    "@id": "#data/normalizationname-139800003193056"                                },                                {                                    "@id": "#data/derivedspectraldatafile-139800003193008"                                }                            ],                            "parameterValues": [],                            "performer": "",                            "previousProcess": {                                "@id": "#process/139800003212432"                            }                        },                        {                            "@id": "#process/139800003212528",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003893904"                            },                            "inputs": [                                {                                    "@id": "#data/normalizationname-139800003193056"                                }                            ],                            "name": "metabolite_identification_XOM3",                            "outputs": [                                {                                    "@id": "#data/datatransformationname-139800003193200"                                },                                {                                    "@id": "#data/metaboliteassignmentfile-139800003193344"                                }                            ],                            "parameterValues": [],                            "performer": "",                            "previousProcess": {                                "@id": "#process/139800003212480"                            }                        },                        {                            "@id": "#process/139800003213344",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003740624"                            },                            "inputs": [                                {                                    "@id": "#sample/139800003606704"                                }                            ],                            "name": "",                            "nextProcess": {                                "@id": "#process/139800003213488"                            },                            "outputs": [                                {                                    "@id": "#material/extract-139800003213248"                                }                            ],                            "parameterValues": [                                {                                    "category": {                                        "@id": "#139800003212768"                                    },                                    "value": {                                        "@id": "#321499bc-d713-4a19-88cb-03548c20505d",                                        "annotationValue": "1 uL borate buffer (pH 8.8) with AQC reagent",                                        "comments": [],                                        "termAccession": "",                                        "termSource": ""                                    }                                },                                {                                    "category": {                                        "@id": "#139800003213152"                                    },                                    "value": "AQC"                                }                            ],                            "performer": ""                        },                        {                            "@id": "#process/139800003213488",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003893328"                            },                            "inputs": [                                {                                    "@id": "#material/extract-139800003213248"                                }                            ],                            "name": "",                            "nextProcess": {                                "@id": "#process/139800003214400"                            },                            "outputs": [                                {                                    "@id": "#material/labledextract-139800003213392"                                }                            ],                            "parameterValues": [],                            "performer": "",                            "previousProcess": {                                "@id": "#process/139800003213344"                            }                        },                        {                            "@id": "#process/139800003214400",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003892176"                            },                            "inputs": [                                {                                    "@id": "#material/labledextract-139800003213392"                                }                            ],                            "name": "chromatography_XOM4",                            "nextProcess": {                                "@id": "#process/139800003224240"                            },                            "outputs": [],                            "parameterValues": [                                {                                    "category": {                                        "@id": "#139800003213728"                                    },                                    "value": "Agilent 1290 Infinity II"                                },                                {                                    "category": {                                        "@id": "#139800003214016"                                    },                                    "value": "Accq-Tag Ultra column (waters   FURHTER SPECS?)"                                },                                {                                    "category": {                                        "@id": "#139800003214304"                                    },                                    "value": "reverse phase"                                }                            ],                            "performer": "",                            "previousProcess": {                                "@id": "#process/139800003213488"                            }                        },                        {                            "@id": "#process/139800003224240",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003786688"                            },                            "inputs": [],                            "name": "mass_spectrometry_XOM4",                            "nextProcess": {                                "@id": "#process/139800003224288"                            },                            "outputs": [                                {                                    "@id": "#data/rawspectraldatafile-139800003192960"                                }                            ],                            "parameterValues": [                                {                                    "category": {                                        "@id": "#139800003214640"                                    },                                    "value": "positive"                                },                                {                                    "category": {                                        "@id": "#139800003214928"                                    },                                    "value": "5-2000?"                                },                                {                                    "category": {                                        "@id": "#139800003215216"                                    },                                    "value": "AB SCIEX Qtrap 6500"                                },                                {                                    "category": {                                        "@id": "#139800003223808"                                    },                                    "value": "ESI"                                },                                {                                    "category": {                                        "@id": "#139800003224096"                                    },                                    "value": "triple quadrupole linear ion trap"                                }                            ],                            "performer": "",                            "previousProcess": {                                "@id": "#process/139800003214400"                            }                        },                        {                            "@id": "#process/139800003224288",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003894048"                            },                            "inputs": [                                {                                    "@id": "#data/rawspectraldatafile-139800003192960"                                }                            ],                            "name": "data_transformation_XOM4",                            "nextProcess": {                                "@id": "#process/139800003224336"                            },                            "outputs": [                                {                                    "@id": "#data/normalizationname-139800003193056"                                },                                {                                    "@id": "#data/derivedspectraldatafile-139800003193008"                                }                            ],                            "parameterValues": [],                            "performer": "",                            "previousProcess": {                                "@id": "#process/139800003224240"                            }                        },                        {                            "@id": "#process/139800003224336",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003893904"                            },                            "inputs": [                                {                                    "@id": "#data/normalizationname-139800003193056"                                }                            ],                            "name": "metabolite_identification_XOM4",                            "outputs": [                                {                                    "@id": "#data/datatransformationname-139800003193200"                                },                                {                                    "@id": "#data/metaboliteassignmentfile-139800003193344"                                }                            ],                            "parameterValues": [],                            "performer": "",                            "previousProcess": {                                "@id": "#process/139800003224288"                            }                        },                        {                            "@id": "#process/139800003225152",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003740624"                            },                            "inputs": [                                {                                    "@id": "#sample/139800003600640"                                }                            ],                            "name": "",                            "nextProcess": {                                "@id": "#process/139800003225296"                            },                            "outputs": [                                {                                    "@id": "#material/extract-139800003224960"                                }                            ],                            "parameterValues": [                                {                                    "category": {                                        "@id": "#139800003224528"                                    },                                    "value": {                                        "@id": "#0b5f917e-a333-4a3d-96d2-e099537486b3",                                        "annotationValue": "1 uL borate buffer (pH 8.8) with AQC reagent",                                        "comments": [],                                        "termAccession": "",                                        "termSource": ""                                    }                                },                                {                                    "category": {                                        "@id": "#139800003224912"                                    },                                    "value": "AQC"                                }                            ],                            "performer": ""                        },                        {                            "@id": "#process/139800003225296",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003893328"                            },                            "inputs": [                                {                                    "@id": "#material/extract-139800003224960"                                }                            ],                            "name": "",                            "nextProcess": {                                "@id": "#process/139800003226160"                            },                            "outputs": [                                {                                    "@id": "#material/labledextract-139800003225200"                                }                            ],                            "parameterValues": [],                            "performer": "",                            "previousProcess": {                                "@id": "#process/139800003225152"                            }                        },                        {                            "@id": "#process/139800003226160",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003892176"                            },                            "inputs": [                                {                                    "@id": "#material/labledextract-139800003225200"                                }                            ],                            "name": "chromatography_XOM5",                            "nextProcess": {                                "@id": "#process/139800003240048"                            },                            "outputs": [],                            "parameterValues": [                                {                                    "category": {                                        "@id": "#139800003225536"                                    },                                    "value": "Agilent 1290 Infinity II"                                },                                {                                    "category": {                                        "@id": "#139800003225056"                                    },                                    "value": "Accq-Tag Ultra column (waters   FURHTER SPECS?)"                                },                                {                                    "category": {                                        "@id": "#139800003226064"                                    },                                    "value": "reverse phase"                                }                            ],                            "performer": "",                            "previousProcess": {                                "@id": "#process/139800003225296"                            }                        },                        {                            "@id": "#process/139800003240048",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003786688"                            },                            "inputs": [],                            "name": "mass_spectrometry_XOM5",                            "nextProcess": {                                "@id": "#process/139800003240144"                            },                            "outputs": [                                {                                    "@id": "#data/rawspectraldatafile-139800003192960"                                }                            ],                            "parameterValues": [                                {                                    "category": {                                        "@id": "#139800003226448"                                    },                                    "value": "positive"                                },                                {                                    "category": {                                        "@id": "#139800003226784"                                    },                                    "value": "5-2000?"                                },                                {                                    "category": {                                        "@id": "#139800003227024"                                    },                                    "value": "AB SCIEX Qtrap 6500"                                },                                {                                    "category": {                                        "@id": "#139800003227312"                                    },                                    "value": "ESI"                                },                                {                                    "category": {                                        "@id": "#139800003227552"                                    },                                    "value": "triple quadrupole linear ion trap"                                }                            ],                            "performer": "",                            "previousProcess": {                                "@id": "#process/139800003226160"                            }                        },                        {                            "@id": "#process/139800003240144",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003894048"                            },                            "inputs": [                                {                                    "@id": "#data/rawspectraldatafile-139800003192960"                                }                            ],                            "name": "data_transformation_XOM5",                            "nextProcess": {                                "@id": "#process/139800003240240"                            },                            "outputs": [                                {                                    "@id": "#data/normalizationname-139800003193056"                                },                                {                                    "@id": "#data/derivedspectraldatafile-139800003193008"                                }                            ],                            "parameterValues": [],                            "performer": "",                            "previousProcess": {                                "@id": "#process/139800003240048"                            }                        },                        {                            "@id": "#process/139800003240240",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003893904"                            },                            "inputs": [                                {                                    "@id": "#data/normalizationname-139800003193056"                                }                            ],                            "name": "metabolite_identification_XOM5",                            "outputs": [                                {                                    "@id": "#data/datatransformationname-139800003193200"                                },                                {                                    "@id": "#data/metaboliteassignmentfile-139800003193344"                                }                            ],                            "parameterValues": [],                            "performer": "",                            "previousProcess": {                                "@id": "#process/139800003240144"                            }                        },                        {                            "@id": "#process/139800003241152",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003740624"                            },                            "inputs": [                                {                                    "@id": "#sample/139800003600592"                                }                            ],                            "name": "",                            "nextProcess": {                                "@id": "#process/139800003241344"                            },                            "outputs": [                                {                                    "@id": "#material/extract-139800003241008"                                }                            ],                            "parameterValues": [                                {                                    "category": {                                        "@id": "#139800003240480"                                    },                                    "value": {                                        "@id": "#d101f1e0-7150-49e1-b799-91a970ab91e3",                                        "annotationValue": "1 uL borate buffer (pH 8.8) with AQC reagent",                                        "comments": [],                                        "termAccession": "",                                        "termSource": ""                                    }                                },                                {                                    "category": {                                        "@id": "#139800003240960"                                    },                                    "value": "AQC"                                }                            ],                            "performer": ""                        },                        {                            "@id": "#process/139800003241344",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003893328"                            },                            "inputs": [                                {                                    "@id": "#material/extract-139800003241008"                                }                            ],                            "name": "",                            "nextProcess": {                                "@id": "#process/139800003242304"                            },                            "outputs": [                                {                                    "@id": "#material/labledextract-139800003241248"                                }                            ],                            "parameterValues": [],                            "performer": "",                            "previousProcess": {                                "@id": "#process/139800003241152"                            }                        },                        {                            "@id": "#process/139800003242304",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003892176"                            },                            "inputs": [                                {                                    "@id": "#material/labledextract-139800003241248"                                }                            ],                            "name": "chromatography_XOM6",                            "nextProcess": {                                "@id": "#process/139800003243888"                            },                            "outputs": [],                            "parameterValues": [                                {                                    "category": {                                        "@id": "#139800003240720"                                    },                                    "value": "Agilent 1290 Infinity II"                                },                                {                                    "category": {                                        "@id": "#139800003241920"                                    },                                    "value": "Accq-Tag Ultra column (waters   FURHTER SPECS?)"                                },                                {                                    "category": {                                        "@id": "#139800003242160"                                    },                                    "value": "reverse phase"                                }                            ],                            "performer": "",                            "previousProcess": {                                "@id": "#process/139800003241344"                            }                        },                        {                            "@id": "#process/139800003243888",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003786688"                            },                            "inputs": [],                            "name": "mass_spectrometry_XOM6",                            "nextProcess": {                                "@id": "#process/139800003243168"                            },                            "outputs": [                                {                                    "@id": "#data/rawspectraldatafile-139800003192960"                                }                            ],                            "parameterValues": [                                {                                    "category": {                                        "@id": "#139800003242544"                                    },                                    "value": "positive"                                },                                {                                    "category": {                                        "@id": "#139800003242880"                                    },                                    "value": "5-2000?"                                },                                {                                    "category": {                                        "@id": "#139800003243072"                                    },                                    "value": "AB SCIEX Qtrap 6500"                                },                                {                                    "category": {                                        "@id": "#139800003243456"                                    },                                    "value": "ESI"                                },                                {                                    "category": {                                        "@id": "#139800003243744"                                    },                                    "value": "triple quadrupole linear ion trap"                                }                            ],                            "performer": "",                            "previousProcess": {                                "@id": "#process/139800003242304"                            }                        },                        {                            "@id": "#process/139800003243168",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003894048"                            },                            "inputs": [                                {                                    "@id": "#data/rawspectraldatafile-139800003192960"                                }                            ],                            "name": "data_transformation_XOM6",                            "nextProcess": {                                "@id": "#process/139800003243936"                            },                            "outputs": [                                {                                    "@id": "#data/normalizationname-139800003193056"                                },                                {                                    "@id": "#data/derivedspectraldatafile-139800003193008"                                }                            ],                            "parameterValues": [],                            "performer": "",                            "previousProcess": {                                "@id": "#process/139800003243888"                            }                        },                        {                            "@id": "#process/139800003243936",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003893904"                            },                            "inputs": [                                {                                    "@id": "#data/normalizationname-139800003193056"                                }                            ],                            "name": "metabolite_identification_XOM6",                            "outputs": [                                {                                    "@id": "#data/datatransformationname-139800003193200"                                },                                {                                    "@id": "#data/metaboliteassignmentfile-139800003193344"                                }                            ],                            "parameterValues": [],                            "performer": "",                            "previousProcess": {                                "@id": "#process/139800003243168"                            }                        },                        {                            "@id": "#process/139800003252864",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003740624"                            },                            "inputs": [                                {                                    "@id": "#sample/139800003617216"                                }                            ],                            "name": "",                            "nextProcess": {                                "@id": "#process/139800003253008"                            },                            "outputs": [                                {                                    "@id": "#material/extract-139800003252768"                                }                            ],                            "parameterValues": [                                {                                    "category": {                                        "@id": "#139800003243792"                                    },                                    "value": {                                        "@id": "#f4a9a38d-f0d8-4740-8cb9-3ec5e5df5cd3",                                        "annotationValue": "1 uL borate buffer (pH 8.8) with AQC reagent",                                        "comments": [],                                        "termAccession": "",                                        "termSource": ""                                    }                                },                                {                                    "category": {                                        "@id": "#139800003252480"                                    },                                    "value": "AQC"                                }                            ],                            "performer": ""                        },                        {                            "@id": "#process/139800003253008",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003893328"                            },                            "inputs": [                                {                                    "@id": "#material/extract-139800003252768"                                }                            ],                            "name": "",                            "nextProcess": {                                "@id": "#process/139800003253920"                            },                            "outputs": [                                {                                    "@id": "#material/labledextract-139800003252912"                                }                            ],                            "parameterValues": [],                            "performer": "",                            "previousProcess": {                                "@id": "#process/139800003252864"                            }                        },                        {                            "@id": "#process/139800003253920",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003892176"                            },                            "inputs": [                                {                                    "@id": "#material/labledextract-139800003252912"                                }                            ],                            "name": "chromatography_XOM7",                            "nextProcess": {                                "@id": "#process/139800003255456"                            },                            "outputs": [],                            "parameterValues": [                                {                                    "category": {                                        "@id": "#139800003253344"                                    },                                    "value": "Agilent 1290 Infinity II"                                },                                {                                    "category": {                                        "@id": "#139800003252720"                                    },                                    "value": "Accq-Tag Ultra column (waters   FURHTER SPECS?)"                                },                                {                                    "category": {                                        "@id": "#139800003253824"                                    },                                    "value": "reverse phase"                                }                            ],                            "performer": "",                            "previousProcess": {                                "@id": "#process/139800003253008"                            }                        },                        {                            "@id": "#process/139800003255456",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003786688"                            },                            "inputs": [],                            "name": "mass_spectrometry_XOM7",                            "nextProcess": {                                "@id": "#process/139800003254736"                            },                            "outputs": [                                {                                    "@id": "#data/rawspectraldatafile-139800003192960"                                }                            ],                            "parameterValues": [                                {                                    "category": {                                        "@id": "#139800003254160"                                    },                                    "value": "positive"                                },                                {                                    "category": {                                        "@id": "#139800003254400"                                    },                                    "value": "5-2000?"                                },                                {                                    "category": {                                        "@id": "#139800003254640"                                    },                                    "value": "AB SCIEX Qtrap 6500"                                },                                {                                    "category": {                                        "@id": "#139800003255024"                                    },                                    "value": "ESI"                                },                                {                                    "category": {                                        "@id": "#139800003255312"                                    },                                    "value": "triple quadrupole linear ion trap"                                }                            ],                            "performer": "",                            "previousProcess": {                                "@id": "#process/139800003253920"                            }                        },                        {                            "@id": "#process/139800003254736",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003894048"                            },                            "inputs": [                                {                                    "@id": "#data/rawspectraldatafile-139800003192960"                                }                            ],                            "name": "data_transformation_XOM7",                            "nextProcess": {                                "@id": "#process/139800003255552"                            },                            "outputs": [                                {                                    "@id": "#data/normalizationname-139800003193056"                                },                                {                                    "@id": "#data/derivedspectraldatafile-139800003193008"                                }                            ],                            "parameterValues": [],                            "performer": "",                            "previousProcess": {                                "@id": "#process/139800003255456"                            }                        },                        {                            "@id": "#process/139800003255552",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003893904"                            },                            "inputs": [                                {                                    "@id": "#data/normalizationname-139800003193056"                                }                            ],                            "name": "metabolite_identification_XOM7",                            "outputs": [                                {                                    "@id": "#data/datatransformationname-139800003193200"                                },                                {                                    "@id": "#data/metaboliteassignmentfile-139800003193344"                                }                            ],                            "parameterValues": [],                            "performer": "",                            "previousProcess": {                                "@id": "#process/139800003254736"                            }                        },                        {                            "@id": "#process/139800003255600",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003740624"                            },                            "inputs": [                                {                                    "@id": "#sample/139800003617120"                                }                            ],                            "name": "",                            "nextProcess": {                                "@id": "#process/139800003268720"                            },                            "outputs": [                                {                                    "@id": "#material/extract-139800003253200"                                }                            ],                            "parameterValues": [                                {                                    "category": {                                        "@id": "#139800003255840"                                    },                                    "value": {                                        "@id": "#a65b368e-b470-415c-b759-28187dab0e0f",                                        "annotationValue": "1 uL borate buffer (pH 8.8) with AQC reagent",                                        "comments": [],                                        "termAccession": "",                                        "termSource": ""                                    }                                },                                {                                    "category": {                                        "@id": "#139800003256272"                                    },                                    "value": "AQC"                                }                            ],                            "performer": ""                        },                        {                            "@id": "#process/139800003268720",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003893328"                            },                            "inputs": [                                {                                    "@id": "#material/extract-139800003253200"                                }                            ],                            "name": "",                            "nextProcess": {                                "@id": "#process/139800003269776"                            },                            "outputs": [                                {                                    "@id": "#material/labledextract-139800003255504"                                }                            ],                            "parameterValues": [],                            "performer": "",                            "previousProcess": {                                "@id": "#process/139800003255600"                            }                        },                        {                            "@id": "#process/139800003269776",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003892176"                            },                            "inputs": [                                {                                    "@id": "#material/labledextract-139800003255504"                                }                            ],                            "name": "chromatography_XOM8",                            "nextProcess": {                                "@id": "#process/139800003271264"                            },                            "outputs": [],                            "parameterValues": [                                {                                    "category": {                                        "@id": "#139800003268960"                                    },                                    "value": "Agilent 1290 Infinity II"                                },                                {                                    "category": {                                        "@id": "#139800003269296"                                    },                                    "value": "Accq-Tag Ultra column (waters   FURHTER SPECS?)"                                },                                {                                    "category": {                                        "@id": "#139800003269680"                                    },                                    "value": "reverse phase"                                }                            ],                            "performer": "",                            "previousProcess": {                                "@id": "#process/139800003268720"                            }                        },                        {                            "@id": "#process/139800003271264",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003786688"                            },                            "inputs": [],                            "name": "mass_spectrometry_XOM8",                            "nextProcess": {                                "@id": "#process/139800003271216"                            },                            "outputs": [                                {                                    "@id": "#data/rawspectraldatafile-139800003192960"                                }                            ],                            "parameterValues": [                                {                                    "category": {                                        "@id": "#139800003269968"                                    },                                    "value": "positive"                                },                                {                                    "category": {                                        "@id": "#139800003270208"                                    },                                    "value": "5-2000?"                                },                                {                                    "category": {                                        "@id": "#139800003270496"                                    },                                    "value": "AB SCIEX Qtrap 6500"                                },                                {                                    "category": {                                        "@id": "#139800003270736"                                    },                                    "value": "ESI"                                },                                {                                    "category": {                                        "@id": "#139800003271072"                                    },                                    "value": "triple quadrupole linear ion trap"                                }                            ],                            "performer": "",                            "previousProcess": {                                "@id": "#process/139800003269776"                            }                        },                        {                            "@id": "#process/139800003271216",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003894048"                            },                            "inputs": [                                {                                    "@id": "#data/rawspectraldatafile-139800003192960"                                }                            ],                            "name": "data_transformation_XOM8",                            "nextProcess": {                                "@id": "#process/139800003271312"                            },                            "outputs": [                                {                                    "@id": "#data/normalizationname-139800003193056"                                },                                {                                    "@id": "#data/derivedspectraldatafile-139800003193008"                                }                            ],                            "parameterValues": [],                            "performer": "",                            "previousProcess": {                                "@id": "#process/139800003271264"                            }                        },                        {                            "@id": "#process/139800003271312",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003893904"                            },                            "inputs": [                                {                                    "@id": "#data/normalizationname-139800003193056"                                }                            ],                            "name": "metabolite_identification_XOM8",                            "outputs": [                                {                                    "@id": "#data/datatransformationname-139800003193200"                                },                                {                                    "@id": "#data/metaboliteassignmentfile-139800003193344"                                }                            ],                            "parameterValues": [],                            "performer": "",                            "previousProcess": {                                "@id": "#process/139800003271216"                            }                        },                        {                            "@id": "#process/139800003272176",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003740624"                            },                            "inputs": [                                {                                    "@id": "#sample/139800003646176"                                }                            ],                            "name": "",                            "nextProcess": {                                "@id": "#process/139800003272320"                            },                            "outputs": [                                {                                    "@id": "#material/extract-139800003272032"                                }                            ],                            "parameterValues": [                                {                                    "category": {                                        "@id": "#139800003271504"                                    },                                    "value": {                                        "@id": "#08de959c-d652-4b2d-a7cd-c6f108b854bd",                                        "annotationValue": "1 uL borate buffer (pH 8.8) with AQC reagent",                                        "comments": [],                                        "termAccession": "",                                        "termSource": ""                                    }                                },                                {                                    "category": {                                        "@id": "#139800003271936"                                    },                                    "value": "AQC"                                }                            ],                            "performer": ""                        },                        {                            "@id": "#process/139800003272320",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003893328"                            },                            "inputs": [                                {                                    "@id": "#material/extract-139800003272032"                                }                            ],                            "name": "",                            "nextProcess": {                                "@id": "#process/139800003281488"                            },                            "outputs": [                                {                                    "@id": "#material/labledextract-139800003272224"                                }                            ],                            "parameterValues": [],                            "performer": "",                            "previousProcess": {                                "@id": "#process/139800003272176"                            }                        },                        {                            "@id": "#process/139800003281488",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003892176"                            },                            "inputs": [                                {                                    "@id": "#material/labledextract-139800003272224"                                }                            ],                            "name": "chromatography_XOM9",                            "nextProcess": {                                "@id": "#process/139800003283264"                            },                            "outputs": [],                            "parameterValues": [                                {                                    "category": {                                        "@id": "#139800003272560"                                    },                                    "value": "Agilent 1290 Infinity II"                                },                                {                                    "category": {                                        "@id": "#139800003269344"                                    },                                    "value": "Accq-Tag Ultra column (waters   FURHTER SPECS?)"                                },                                {                                    "category": {                                        "@id": "#139800003281392"                                    },                                    "value": "reverse phase"                                }                            ],                            "performer": "",                            "previousProcess": {                                "@id": "#process/139800003272320"                            }                        },                        {                            "@id": "#process/139800003283264",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003786688"                            },                            "inputs": [],                            "name": "mass_spectrometry_XOM9",                            "nextProcess": {                                "@id": "#process/139800003283312"                            },                            "outputs": [                                {                                    "@id": "#data/rawspectraldatafile-139800003192960"                                }                            ],                            "parameterValues": [                                {                                    "category": {                                        "@id": "#139800003281824"                                    },                                    "value": "positive"                                },                                {                                    "category": {                                        "@id": "#139800003282064"                                    },                                    "value": "5-2000?"                                },                                {                                    "category": {                                        "@id": "#139800003282448"                                    },                                    "value": "AB SCIEX Qtrap 6500"                                },                                {                                    "category": {                                        "@id": "#139800003282784"                                    },                                    "value": "ESI"                                },                                {                                    "category": {                                        "@id": "#139800003283072"                                    },                                    "value": "triple quadrupole linear ion trap"                                }                            ],                            "performer": "",                            "previousProcess": {                                "@id": "#process/139800003281488"                            }                        },                        {                            "@id": "#process/139800003283312",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003894048"                            },                            "inputs": [                                {                                    "@id": "#data/rawspectraldatafile-139800003192960"                                }                            ],                            "name": "data_transformation_XOM9",                            "nextProcess": {                                "@id": "#process/139800003283360"                            },                            "outputs": [                                {                                    "@id": "#data/normalizationname-139800003193056"                                },                                {                                    "@id": "#data/derivedspectraldatafile-139800003193008"                                }                            ],                            "parameterValues": [],                            "performer": "",                            "previousProcess": {                                "@id": "#process/139800003283264"                            }                        },                        {                            "@id": "#process/139800003283360",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003893904"                            },                            "inputs": [                                {                                    "@id": "#data/normalizationname-139800003193056"                                }                            ],                            "name": "metabolite_identification_XOM9",                            "outputs": [                                {                                    "@id": "#data/datatransformationname-139800003193200"                                },                                {                                    "@id": "#data/metaboliteassignmentfile-139800003193344"                                }                            ],                            "parameterValues": [],                            "performer": "",                            "previousProcess": {                                "@id": "#process/139800003283312"                            }                        },                        {                            "@id": "#process/139800003284224",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003740624"                            },                            "inputs": [                                {                                    "@id": "#sample/139800003646080"                                }                            ],                            "name": "",                            "nextProcess": {                                "@id": "#process/139800003284368"                            },                            "outputs": [                                {                                    "@id": "#material/extract-139800003284128"                                }                            ],                            "parameterValues": [                                {                                    "category": {                                        "@id": "#139800003283552"                                    },                                    "value": {                                        "@id": "#bc36b111-b7c6-4e1d-87da-ee2938f18d81",                                        "annotationValue": "1 uL borate buffer (pH 8.8) with AQC reagent",                                        "comments": [],                                        "termAccession": "",                                        "termSource": ""                                    }                                },                                {                                    "category": {                                        "@id": "#139800003283984"                                    },                                    "value": "AQC"                                }                            ],                            "performer": ""                        },                        {                            "@id": "#process/139800003284368",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003893328"                            },                            "inputs": [                                {                                    "@id": "#material/extract-139800003284128"                                }                            ],                            "name": "",                            "nextProcess": {                                "@id": "#process/139800003283792"                            },                            "outputs": [                                {                                    "@id": "#material/labledextract-139800003284272"                                }                            ],                            "parameterValues": [],                            "performer": "",                            "previousProcess": {                                "@id": "#process/139800003284224"                            }                        },                        {                            "@id": "#process/139800003283792",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003892176"                            },                            "inputs": [                                {                                    "@id": "#material/labledextract-139800003284272"                                }                            ],                            "name": "chromatography_XOM10",                            "nextProcess": {                                "@id": "#process/139800003303024"                            },                            "outputs": [],                            "parameterValues": [                                {                                    "category": {                                        "@id": "#139800003284560"                                    },                                    "value": "Agilent 1290 Infinity II"                                },                                {                                    "category": {                                        "@id": "#139800003284896"                                    },                                    "value": "Accq-Tag Ultra column (waters   FURHTER SPECS?)"                                },                                {                                    "category": {                                        "@id": "#139800003282592"                                    },                                    "value": "reverse phase"                                }                            ],                            "performer": "",                            "previousProcess": {                                "@id": "#process/139800003284368"                            }                        },                        {                            "@id": "#process/139800003303024",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003786688"                            },                            "inputs": [],                            "name": "mass_spectrometry_XOM10",                            "nextProcess": {                                "@id": "#process/139800003303072"                            },                            "outputs": [                                {                                    "@id": "#data/rawspectraldatafile-139800003192960"                                }                            ],                            "parameterValues": [                                {                                    "category": {                                        "@id": "#139800003301584"                                    },                                    "value": "positive"                                },                                {                                    "category": {                                        "@id": "#139800003301968"                                    },                                    "value": "5-2000?"                                },                                {                                    "category": {                                        "@id": "#139800003302256"                                    },                                    "value": "AB SCIEX Qtrap 6500"                                },                                {                                    "category": {                                        "@id": "#139800003302640"                                    },                                    "value": "ESI"                                },                                {                                    "category": {                                        "@id": "#139800003302880"                                    },                                    "value": "triple quadrupole linear ion trap"                                }                            ],                            "performer": "",                            "previousProcess": {                                "@id": "#process/139800003283792"                            }                        },                        {                            "@id": "#process/139800003303072",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003894048"                            },                            "inputs": [                                {                                    "@id": "#data/rawspectraldatafile-139800003192960"                                }                            ],                            "name": "data_transformation_XOM10",                            "nextProcess": {                                "@id": "#process/139800003303120"                            },                            "outputs": [                                {                                    "@id": "#data/normalizationname-139800003193056"                                },                                {                                    "@id": "#data/derivedspectraldatafile-139800003193008"                                }                            ],                            "parameterValues": [],                            "performer": "",                            "previousProcess": {                                "@id": "#process/139800003303024"                            }                        },                        {                            "@id": "#process/139800003303120",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003893904"                            },                            "inputs": [                                {                                    "@id": "#data/normalizationname-139800003193056"                                }                            ],                            "name": "metabolite_identification_XOM10",                            "outputs": [                                {                                    "@id": "#data/datatransformationname-139800003193200"                                },                                {                                    "@id": "#data/metaboliteassignmentfile-139800003193344"                                }                            ],                            "parameterValues": [],                            "performer": "",                            "previousProcess": {                                "@id": "#process/139800003303072"                            }                        }                    ],                    "technologyPlatform": "",                    "technologyType": {                        "@id": "#9942b0a9-d977-4859-9394-5150d5ba89b4",                        "annotationValue": "liquid chromatography-mass spectrometry",                        "comments": [],                        "termAccession": "http://purl.obolibrary.org/obo/CHMO_0000524",                        "termSource": "CHMO"                    },                    "unitCategories": []                },                {                    "characteristicCategories": [],                    "comments": [],                    "dataFiles": [                        {                            "@id": "#data/rawspectraldatafile-139800003298880",                            "comments": [],                            "name": "link/to/raw/data",                            "type": "Raw Spectral Data File"                        },                        {                            "@id": "#data/normalizationname-139800003299024",                            "comments": [],                            "name": "link/to/normalized_data",                            "type": "Normalization Name"                        },                        {                            "@id": "#data/derivedspectraldatafile-139800003298976",                            "comments": [],                            "name": "link/to/spectral_file",                            "type": "Derived Spectral Data File"                        },                        {                            "@id": "#data/datatransformationname-139800003299168",                            "comments": [],                            "name": "link/to/data_transformation_name",                            "type": "Data Transformation Name"                        },                        {                            "@id": "#data/metaboliteassignmentfile-139800003299312",                            "comments": [],                            "name": "link/to/MAF",                            "type": "Metabolite Assignment File"                        },                        {                            "@id": "#data/rawspectraldatafile-139800003298880",                            "comments": [],                            "name": "link/to/raw/data",                            "type": "Raw Spectral Data File"                        },                        {                            "@id": "#data/normalizationname-139800003299024",                            "comments": [],                            "name": "link/to/normalized_data",                            "type": "Normalization Name"                        },                        {                            "@id": "#data/derivedspectraldatafile-139800003298976",                            "comments": [],                            "name": "link/to/spectral_file",                            "type": "Derived Spectral Data File"                        },                        {                            "@id": "#data/datatransformationname-139800003299168",                            "comments": [],                            "name": "link/to/data_transformation_name",                            "type": "Data Transformation Name"                        },                        {                            "@id": "#data/metaboliteassignmentfile-139800003299312",                            "comments": [],                            "name": "link/to/MAF",                            "type": "Metabolite Assignment File"                        },                        {                            "@id": "#data/rawspectraldatafile-139800003298880",                            "comments": [],                            "name": "link/to/raw/data",                            "type": "Raw Spectral Data File"                        },                        {                            "@id": "#data/normalizationname-139800003299024",                            "comments": [],                            "name": "link/to/normalized_data",                            "type": "Normalization Name"                        },                        {                            "@id": "#data/derivedspectraldatafile-139800003298976",                            "comments": [],                            "name": "link/to/spectral_file",                            "type": "Derived Spectral Data File"                        },                        {                            "@id": "#data/datatransformationname-139800003299168",                            "comments": [],                            "name": "link/to/data_transformation_name",                            "type": "Data Transformation Name"                        },                        {                            "@id": "#data/metaboliteassignmentfile-139800003299312",                            "comments": [],                            "name": "link/to/MAF",                            "type": "Metabolite Assignment File"                        },                        {                            "@id": "#data/rawspectraldatafile-139800003298880",                            "comments": [],                            "name": "link/to/raw/data",                            "type": "Raw Spectral Data File"                        },                        {                            "@id": "#data/normalizationname-139800003299024",                            "comments": [],                            "name": "link/to/normalized_data",                            "type": "Normalization Name"                        },                        {                            "@id": "#data/derivedspectraldatafile-139800003298976",                            "comments": [],                            "name": "link/to/spectral_file",                            "type": "Derived Spectral Data File"                        },                        {                            "@id": "#data/datatransformationname-139800003299168",                            "comments": [],                            "name": "link/to/data_transformation_name",                            "type": "Data Transformation Name"                        },                        {                            "@id": "#data/metaboliteassignmentfile-139800003299312",                            "comments": [],                            "name": "link/to/MAF",                            "type": "Metabolite Assignment File"                        },                        {                            "@id": "#data/rawspectraldatafile-139800003298880",                            "comments": [],                            "name": "link/to/raw/data",                            "type": "Raw Spectral Data File"                        },                        {                            "@id": "#data/normalizationname-139800003299024",                            "comments": [],                            "name": "link/to/normalized_data",                            "type": "Normalization Name"                        },                        {                            "@id": "#data/derivedspectraldatafile-139800003298976",                            "comments": [],                            "name": "link/to/spectral_file",                            "type": "Derived Spectral Data File"                        },                        {                            "@id": "#data/datatransformationname-139800003299168",                            "comments": [],                            "name": "link/to/data_transformation_name",                            "type": "Data Transformation Name"                        },                        {                            "@id": "#data/metaboliteassignmentfile-139800003299312",                            "comments": [],                            "name": "link/to/MAF",                            "type": "Metabolite Assignment File"                        },                        {                            "@id": "#data/rawspectraldatafile-139800003298880",                            "comments": [],                            "name": "link/to/raw/data",                            "type": "Raw Spectral Data File"                        },                        {                            "@id": "#data/normalizationname-139800003299024",                            "comments": [],                            "name": "link/to/normalized_data",                            "type": "Normalization Name"                        },                        {                            "@id": "#data/derivedspectraldatafile-139800003298976",                            "comments": [],                            "name": "link/to/spectral_file",                            "type": "Derived Spectral Data File"                        },                        {                            "@id": "#data/datatransformationname-139800003299168",                            "comments": [],                            "name": "link/to/data_transformation_name",                            "type": "Data Transformation Name"                        },                        {                            "@id": "#data/metaboliteassignmentfile-139800003299312",                            "comments": [],                            "name": "link/to/MAF",                            "type": "Metabolite Assignment File"                        },                        {                            "@id": "#data/rawspectraldatafile-139800003298880",                            "comments": [],                            "name": "link/to/raw/data",                            "type": "Raw Spectral Data File"                        },                        {                            "@id": "#data/normalizationname-139800003299024",                            "comments": [],                            "name": "link/to/normalized_data",                            "type": "Normalization Name"                        },                        {                            "@id": "#data/derivedspectraldatafile-139800003298976",                            "comments": [],                            "name": "link/to/spectral_file",                            "type": "Derived Spectral Data File"                        },                        {                            "@id": "#data/datatransformationname-139800003299168",                            "comments": [],                            "name": "link/to/data_transformation_name",                            "type": "Data Transformation Name"                        },                        {                            "@id": "#data/metaboliteassignmentfile-139800003299312",                            "comments": [],                            "name": "link/to/MAF",                            "type": "Metabolite Assignment File"                        },                        {                            "@id": "#data/rawspectraldatafile-139800003298880",                            "comments": [],                            "name": "link/to/raw/data",                            "type": "Raw Spectral Data File"                        },                        {                            "@id": "#data/normalizationname-139800003299024",                            "comments": [],                            "name": "link/to/normalized_data",                            "type": "Normalization Name"                        },                        {                            "@id": "#data/derivedspectraldatafile-139800003298976",                            "comments": [],                            "name": "link/to/spectral_file",                            "type": "Derived Spectral Data File"                        },                        {                            "@id": "#data/datatransformationname-139800003299168",                            "comments": [],                            "name": "link/to/data_transformation_name",                            "type": "Data Transformation Name"                        },                        {                            "@id": "#data/metaboliteassignmentfile-139800003299312",                            "comments": [],                            "name": "link/to/MAF",                            "type": "Metabolite Assignment File"                        },                        {                            "@id": "#data/rawspectraldatafile-139800003298880",                            "comments": [],                            "name": "link/to/raw/data",                            "type": "Raw Spectral Data File"                        },                        {                            "@id": "#data/normalizationname-139800003299024",                            "comments": [],                            "name": "link/to/normalized_data",                            "type": "Normalization Name"                        },                        {                            "@id": "#data/derivedspectraldatafile-139800003298976",                            "comments": [],                            "name": "link/to/spectral_file",                            "type": "Derived Spectral Data File"                        },                        {                            "@id": "#data/datatransformationname-139800003299168",                            "comments": [],                            "name": "link/to/data_transformation_name",                            "type": "Data Transformation Name"                        },                        {                            "@id": "#data/metaboliteassignmentfile-139800003299312",                            "comments": [],                            "name": "link/to/MAF",                            "type": "Metabolite Assignment File"                        },                        {                            "@id": "#data/rawspectraldatafile-139800003298880",                            "comments": [],                            "name": "link/to/raw/data",                            "type": "Raw Spectral Data File"                        },                        {                            "@id": "#data/normalizationname-139800003299024",                            "comments": [],                            "name": "link/to/normalized_data",                            "type": "Normalization Name"                        },                        {                            "@id": "#data/derivedspectraldatafile-139800003298976",                            "comments": [],                            "name": "link/to/spectral_file",                            "type": "Derived Spectral Data File"                        },                        {                            "@id": "#data/datatransformationname-139800003299168",                            "comments": [],                            "name": "link/to/data_transformation_name",                            "type": "Data Transformation Name"                        },                        {                            "@id": "#data/metaboliteassignmentfile-139800003299312",                            "comments": [],                            "name": "link/to/MAF",                            "type": "Metabolite Assignment File"                        }                    ],                    "filename": "a_assay_metabolomics_OA.txt",                    "materials": {                        "otherMaterials": [                            {                                "@id": "#material/extract-139800003300272",                                "characteristics": [],                                "name": "extract_XOM1 ",                                "type": "Extract Name"                            },                            {                                "@id": "#material/labledextract-139800003300560",                                "characteristics": [],                                "name": "labeled)XOM1 ",                                "type": "Labeled Extract Name"                            },                            {                                "@id": "#material/extract-139800003315984",                                "characteristics": [],                                "name": "extract_XOM2",                                "type": "Extract Name"                            },                            {                                "@id": "#material/labledextract-139800003316128",                                "characteristics": [],                                "name": "labeled)XOM2",                                "type": "Labeled Extract Name"                            },                            {                                "@id": "#material/extract-139800003344032",                                "characteristics": [],                                "name": "extract_XOM3",                                "type": "Extract Name"                            },                            {                                "@id": "#material/labledextract-139800003344176",                                "characteristics": [],                                "name": "labeled)XOM3",                                "type": "Labeled Extract Name"                            },                            {                                "@id": "#material/extract-139800003359696",                                "characteristics": [],                                "name": "extract_XOM4",                                "type": "Extract Name"                            },                            {                                "@id": "#material/labledextract-139800003359840",                                "characteristics": [],                                "name": "labeled)XOM4",                                "type": "Labeled Extract Name"                            },                            {                                "@id": "#material/extract-139800003375456",                                "characteristics": [],                                "name": "extract_XOM5",                                "type": "Extract Name"                            },                            {                                "@id": "#material/labledextract-139800003375600",                                "characteristics": [],                                "name": "labeled)XOM5",                                "type": "Labeled Extract Name"                            },                            {                                "@id": "#material/extract-139800003378864",                                "characteristics": [],                                "name": "extract_XOM6",                                "type": "Extract Name"                            },                            {                                "@id": "#material/labledextract-139800003379008",                                "characteristics": [],                                "name": "labeled)XOM6",                                "type": "Labeled Extract Name"                            },                            {                                "@id": "#material/extract-139800003386720",                                "characteristics": [],                                "name": "extract_XOM7",                                "type": "Extract Name"                            },                            {                                "@id": "#material/labledextract-139800003386960",                                "characteristics": [],                                "name": "labeled)XOM7",                                "type": "Labeled Extract Name"                            },                            {                                "@id": "#material/extract-139800003426768",                                "characteristics": [],                                "name": "extract_XOM8",                                "type": "Extract Name"                            },                            {                                "@id": "#material/labledextract-139800003426912",                                "characteristics": [],                                "name": "labeled)XOM8",                                "type": "Labeled Extract Name"                            },                            {                                "@id": "#material/extract-139800003438432",                                "characteristics": [],                                "name": "extract_XOM9",                                "type": "Extract Name"                            },                            {                                "@id": "#material/labledextract-139800003438576",                                "characteristics": [],                                "name": "labeled)XOM9",                                "type": "Labeled Extract Name"                            },                            {                                "@id": "#material/extract-139800002925808",                                "characteristics": [],                                "name": "extract_XOM10",                                "type": "Extract Name"                            },                            {                                "@id": "#material/labledextract-139800002925952",                                "characteristics": [],                                "name": "labeled)XOM10",                                "type": "Labeled Extract Name"                            }                        ],                        "samples": [                            {                                "@id": "#sample/139800003550704",                                "characteristics": [                                    {                                        "category": {                                            "@id": "#196b3e41-5a75-439f-aacd-06b46d06be25"                                        },                                        "value": {                                            "@id": "#b4c7521a-9349-41b2-926e-f37c8d272824",                                            "annotationValue": "urine",                                            "comments": [],                                            "termAccession": "http://purl.obolibrary.org/obo/UBERON_0001088",                                            "termSource": "UBERON"                                        }                                    },                                    {                                        "category": {                                            "@id": "#9c885ee6-527b-4b1f-868d-b63b2c3c186b"                                        },                                        "value": {                                            "@id": "#6de4f95f-fa62-4cbb-9d7d-0613ddfa140f",                                            "annotationValue": "experimental sample",                                            "comments": [],                                            "termAccession": "http://purl.obolibrary.org/obo/CHMO_0002746",                                            "termSource": "CHMO"                                        }                                    }                                ],                                "factorValues": [],                                "name": "urine_XOP1"                            },                            {                                "@id": "#sample/139800003581792",                                "characteristics": [                                    {                                        "category": {                                            "@id": "#7f429d01-61c1-4d86-9942-d90b366be47c"                                        },                                        "value": {                                            "@id": "#850e1951-47c2-400e-947f-fd5cbe7c54a6",                                            "annotationValue": "urine",                                            "comments": [],                                            "termAccession": "http://purl.obolibrary.org/obo/UBERON_0001088",                                            "termSource": "UBERON"                                        }                                    },                                    {                                        "category": {                                            "@id": "#43caf586-7aae-4dc7-998e-6a20aef00875"                                        },                                        "value": {                                            "@id": "#4c4f5e89-8f99-4f6c-98b4-e5420d666080",                                            "annotationValue": "experimental sample",                                            "comments": [],                                            "termAccession": "http://purl.obolibrary.org/obo/CHMO_0002746",                                            "termSource": "CHMO"                                        }                                    }                                ],                                "factorValues": [],                                "name": "urine_XOP2"                            },                            {                                "@id": "#sample/139800003604592",                                "characteristics": [                                    {                                        "category": {                                            "@id": "#4720eed4-9af5-4fd5-9fb4-a750508187c0"                                        },                                        "value": {                                            "@id": "#a9ddbe6d-2102-4c3c-8214-f4eb1e91438b",                                            "annotationValue": "urine",                                            "comments": [],                                            "termAccession": "http://purl.obolibrary.org/obo/UBERON_0001088",                                            "termSource": "UBERON"                                        }                                    },                                    {                                        "category": {                                            "@id": "#d48be27a-c378-4f7c-b514-7b8439140fbc"                                        },                                        "value": {                                            "@id": "#910ea8e4-77ff-46be-acac-4dd1315d83f7",                                            "annotationValue": "experimental sample",                                            "comments": [],                                            "termAccession": "http://purl.obolibrary.org/obo/CHMO_0002746",                                            "termSource": "CHMO"                                        }                                    }                                ],                                "factorValues": [],                                "name": "urine_XOP3"                            },                            {                                "@id": "#sample/139800003606704",                                "characteristics": [                                    {                                        "category": {                                            "@id": "#2e697ec4-4d72-4b76-95d1-061fbc7269f3"                                        },                                        "value": {                                            "@id": "#ebe6698f-ec4d-440b-9aa7-e75e0a45ffce",                                            "annotationValue": "urine",                                            "comments": [],                                            "termAccession": "http://purl.obolibrary.org/obo/UBERON_0001088",                                            "termSource": "UBERON"                                        }                                    },                                    {                                        "category": {                                            "@id": "#4f140a54-71da-46d7-94dd-9a846f7961cd"                                        },                                        "value": {                                            "@id": "#4a1eda5e-2e99-4295-9c27-3f95939d6ae0",                                            "annotationValue": "experimental sample",                                            "comments": [],                                            "termAccession": "http://purl.obolibrary.org/obo/CHMO_0002746",                                            "termSource": "CHMO"                                        }                                    }                                ],                                "factorValues": [],                                "name": "urine_XOP4"                            },                            {                                "@id": "#sample/139800003600640",                                "characteristics": [                                    {                                        "category": {                                            "@id": "#64eebdc9-433a-4ce0-a07c-490b3e97427c"                                        },                                        "value": {                                            "@id": "#abc046b0-091c-4326-85ca-95f13ec34337",                                            "annotationValue": "urine",                                            "comments": [],                                            "termAccession": "http://purl.obolibrary.org/obo/UBERON_0001088",                                            "termSource": "UBERON"                                        }                                    },                                    {                                        "category": {                                            "@id": "#bfd93452-d295-474a-9fd5-73a9328fb35c"                                        },                                        "value": {                                            "@id": "#1dca670a-c7b0-48b1-b5a0-30d48bdda1bb",                                            "annotationValue": "experimental sample",                                            "comments": [],                                            "termAccession": "http://purl.obolibrary.org/obo/CHMO_0002746",                                            "termSource": "CHMO"                                        }                                    }                                ],                                "factorValues": [],                                "name": "urine_XOP5"                            },                            {                                "@id": "#sample/139800003600592",                                "characteristics": [                                    {                                        "category": {                                            "@id": "#768a76a7-4463-4937-a4de-857164e5fff3"                                        },                                        "value": {                                            "@id": "#44da0995-dc29-49aa-b8c6-1771ff1b4983",                                            "annotationValue": "urine",                                            "comments": [],                                            "termAccession": "http://purl.obolibrary.org/obo/UBERON_0001088",                                            "termSource": "UBERON"                                        }                                    },                                    {                                        "category": {                                            "@id": "#62204b82-d75c-49f3-b7db-a86c7daa395b"                                        },                                        "value": {                                            "@id": "#7eff269c-7c87-46b6-82c5-af425e533f5c",                                            "annotationValue": "experimental sample",                                            "comments": [],                                            "termAccession": "http://purl.obolibrary.org/obo/CHMO_0002746",                                            "termSource": "CHMO"                                        }                                    }                                ],                                "factorValues": [],                                "name": "urine_XOP6"                            },                            {                                "@id": "#sample/139800003617216",                                "characteristics": [                                    {                                        "category": {                                            "@id": "#7342cd89-8093-420d-ae32-20f4c328cb1f"                                        },                                        "value": {                                            "@id": "#3a2f1236-f52c-4cde-b885-8a49f8bd945f",                                            "annotationValue": "urine",                                            "comments": [],                                            "termAccession": "http://purl.obolibrary.org/obo/UBERON_0001088",                                            "termSource": "UBERON"                                        }                                    },                                    {                                        "category": {                                            "@id": "#3f136fcd-9b03-4296-a2fa-3cfd961d2041"                                        },                                        "value": {                                            "@id": "#c9983013-a289-41b0-a535-ac36b5ed66ec",                                            "annotationValue": "experimental sample",                                            "comments": [],                                            "termAccession": "http://purl.obolibrary.org/obo/CHMO_0002746",                                            "termSource": "CHMO"                                        }                                    }                                ],                                "factorValues": [],                                "name": "urine_XOP7"                            },                            {                                "@id": "#sample/139800003617120",                                "characteristics": [                                    {                                        "category": {                                            "@id": "#4ae1915a-7cf4-487e-abeb-e0378a0f881b"                                        },                                        "value": {                                            "@id": "#1be733cf-5686-46bc-9468-08af1adb0265",                                            "annotationValue": "urine",                                            "comments": [],                                            "termAccession": "http://purl.obolibrary.org/obo/UBERON_0001088",                                            "termSource": "UBERON"                                        }                                    },                                    {                                        "category": {                                            "@id": "#f85fcc53-0e49-4430-90b8-a32e79ad12ed"                                        },                                        "value": {                                            "@id": "#43d8b5bc-ffbe-47cc-9702-5f8724f3a832",                                            "annotationValue": "experimental sample",                                            "comments": [],                                            "termAccession": "http://purl.obolibrary.org/obo/CHMO_0002746",                                            "termSource": "CHMO"                                        }                                    }                                ],                                "factorValues": [],                                "name": "urine_XOP8"                            },                            {                                "@id": "#sample/139800003646176",                                "characteristics": [                                    {                                        "category": {                                            "@id": "#df3be894-44ea-4f1e-9f38-79bf2811b4ba"                                        },                                        "value": {                                            "@id": "#8a42510b-d0a2-4b5c-9c77-96b0ab30fbf3",                                            "annotationValue": "urine",                                            "comments": [],                                            "termAccession": "http://purl.obolibrary.org/obo/UBERON_0001088",                                            "termSource": "UBERON"                                        }                                    },                                    {                                        "category": {                                            "@id": "#de90c9fc-5316-490d-aa56-c0a5af098e70"                                        },                                        "value": {                                            "@id": "#73b93652-4208-4191-91fd-bc6b0b521260",                                            "annotationValue": "experimental sample",                                            "comments": [],                                            "termAccession": "http://purl.obolibrary.org/obo/CHMO_0002746",                                            "termSource": "CHMO"                                        }                                    }                                ],                                "factorValues": [],                                "name": "urine_XOP9"                            },                            {                                "@id": "#sample/139800003646080",                                "characteristics": [                                    {                                        "category": {                                            "@id": "#713c5fa7-ee56-42e5-b084-a5008269ff0c"                                        },                                        "value": {                                            "@id": "#cf7e8c2e-3b58-46a2-8ed7-1fc3ceff8e30",                                            "annotationValue": "urine",                                            "comments": [],                                            "termAccession": "http://purl.obolibrary.org/obo/UBERON_0001088",                                            "termSource": "UBERON"                                        }                                    },                                    {                                        "category": {                                            "@id": "#8e38bdf2-412e-402b-89a6-7483806710b3"                                        },                                        "value": {                                            "@id": "#b2e45b85-affa-4582-9712-22b704630657",                                            "annotationValue": "experimental sample",                                            "comments": [],                                            "termAccession": "http://purl.obolibrary.org/obo/CHMO_0002746",                                            "termSource": "CHMO"                                        }                                    }                                ],                                "factorValues": [],                                "name": "urine_XOP10"                            }                        ]                    },                    "measurementType": {                        "@id": "#6e2a12dc-d2c6-42d1-9283-4edfc15a5aad",                        "annotationValue": "targeted metabolite profiling",                        "comments": [],                        "termAccession": "http://purl.obolibrary.org/obo/MSIO_0000100",                        "termSource": "MSIO"                    },                    "processSequence": [                        {                            "@id": "#process/139800003300464",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003740624"                            },                            "inputs": [                                {                                    "@id": "#sample/139800003550704"                                }                            ],                            "name": "",                            "nextProcess": {                                "@id": "#process/139800003300608"                            },                            "outputs": [                                {                                    "@id": "#material/extract-139800003300272"                                }                            ],                            "parameterValues": [                                {                                    "category": {                                        "@id": "#139800003299840"                                    },                                    "value": "1 uL pyridine"                                },                                {                                    "category": {                                        "@id": "#139800003300128"                                    },                                    "value": "oximation followed by silylation"                                }                            ],                            "performer": ""                        },                        {                            "@id": "#process/139800003300608",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003893328"                            },                            "inputs": [                                {                                    "@id": "#material/extract-139800003300272"                                }                            ],                            "name": "",                            "nextProcess": {                                "@id": "#process/139800003313728"                            },                            "outputs": [                                {                                    "@id": "#material/labledextract-139800003300560"                                }                            ],                            "parameterValues": [],                            "performer": "",                            "previousProcess": {                                "@id": "#process/139800003300464"                            }                        },                        {                            "@id": "#process/139800003313728",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003892176"                            },                            "inputs": [                                {                                    "@id": "#material/labledextract-139800003300560"                                }                            ],                            "name": "chromatography_XOM1 ",                            "nextProcess": {                                "@id": "#process/139800003315264"                            },                            "outputs": [],                            "parameterValues": [                                {                                    "category": {                                        "@id": "#139800003300848"                                    },                                    "value": "Agilent Technologies 7890A"                                },                                {                                    "category": {                                        "@id": "#139800003300368"                                    },                                    "value": "HP-5MS UI (5% Phenyl Methyl Silox), 30 m x 0.25 m ID column with a film thickness of 25 um"                                },                                {                                    "category": {                                        "@id": "#139800003298832"                                    },                                    "value": "low polarity"                                }                            ],                            "performer": "",                            "previousProcess": {                                "@id": "#process/139800003300608"                            }                        },                        {                            "@id": "#process/139800003315264",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003786688"                            },                            "inputs": [],                            "name": "mass_spectrometry_XOM1 ",                            "nextProcess": {                                "@id": "#process/139800003315312"                            },                            "outputs": [                                {                                    "@id": "#data/rawspectraldatafile-139800003298880"                                }                            ],                            "parameterValues": [                                {                                    "category": {                                        "@id": "#139800003313968"                                    },                                    "value": "positive"                                },                                {                                    "category": {                                        "@id": "#139800003314256"                                    },                                    "value": "50-500"                                },                                {                                    "category": {                                        "@id": "#139800003314544"                                    },                                    "value": "Agilent Technologies mass selective detector (MSD 5975C) and MultiPurpose Sampler (MPS, MXY016-02A, GERSTEL)"                                },                                {                                    "category": {                                        "@id": "#139800003314832"                                    },                                    "value": "EI (70 eV)"                                },                                {                                    "category": {                                        "@id": "#139800003315120"                                    },                                    "value": "single-quadrupole"                                }                            ],                            "performer": "",                            "previousProcess": {                                "@id": "#process/139800003313728"                            }                        },                        {                            "@id": "#process/139800003315312",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003894048"                            },                            "inputs": [                                {                                    "@id": "#data/rawspectraldatafile-139800003298880"                                }                            ],                            "name": "data_transformation_XOM1 ",                            "nextProcess": {                                "@id": "#process/139800003315360"                            },                            "outputs": [                                {                                    "@id": "#data/normalizationname-139800003299024"                                },                                {                                    "@id": "#data/derivedspectraldatafile-139800003298976"                                }                            ],                            "parameterValues": [],                            "performer": "",                            "previousProcess": {                                "@id": "#process/139800003315264"                            }                        },                        {                            "@id": "#process/139800003315360",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003893904"                            },                            "inputs": [                                {                                    "@id": "#data/normalizationname-139800003299024"                                }                            ],                            "name": "metabolite_identification_XOM1 ",                            "outputs": [                                {                                    "@id": "#data/datatransformationname-139800003299168"                                },                                {                                    "@id": "#data/metaboliteassignmentfile-139800003299312"                                }                            ],                            "parameterValues": [],                            "performer": "",                            "previousProcess": {                                "@id": "#process/139800003315312"                            }                        },                        {                            "@id": "#process/139800003316080",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003740624"                            },                            "inputs": [                                {                                    "@id": "#sample/139800003581792"                                }                            ],                            "name": "",                            "nextProcess": {                                "@id": "#process/139800003316224"                            },                            "outputs": [                                {                                    "@id": "#material/extract-139800003315984"                                }                            ],                            "parameterValues": [                                {                                    "category": {                                        "@id": "#139800003315600"                                    },                                    "value": "1 uL pyridine"                                },                                {                                    "category": {                                        "@id": "#139800003315888"                                    },                                    "value": "oximation followed by silylation"                                }                            ],                            "performer": ""                        },                        {                            "@id": "#process/139800003316224",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003893328"                            },                            "inputs": [                                {                                    "@id": "#material/extract-139800003315984"                                }                            ],                            "name": "",                            "nextProcess": {                                "@id": "#process/139800003317136"                            },                            "outputs": [                                {                                    "@id": "#material/labledextract-139800003316128"                                }                            ],                            "parameterValues": [],                            "performer": "",                            "previousProcess": {                                "@id": "#process/139800003316080"                            }                        },                        {                            "@id": "#process/139800003317136",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003892176"                            },                            "inputs": [                                {                                    "@id": "#material/labledextract-139800003316128"                                }                            ],                            "name": "chromatography_XOM2",                            "nextProcess": {                                "@id": "#process/139800003343312"                            },                            "outputs": [],                            "parameterValues": [                                {                                    "category": {                                        "@id": "#139800003316464"                                    },                                    "value": "Agilent Technologies 7890A"                                },                                {                                    "category": {                                        "@id": "#139800003316752"                                    },                                    "value": "HP-5MS UI (5% Phenyl Methyl Silox), 30 m x 0.25 m ID column with a film thickness of 25 um"                                },                                {                                    "category": {                                        "@id": "#139800003317040"                                    },                                    "value": "low polarity"                                }                            ],                            "performer": "",                            "previousProcess": {                                "@id": "#process/139800003316224"                            }                        },                        {                            "@id": "#process/139800003343312",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003786688"                            },                            "inputs": [],                            "name": "mass_spectrometry_XOM2",                            "nextProcess": {                                "@id": "#process/139800003343360"                            },                            "outputs": [                                {                                    "@id": "#data/rawspectraldatafile-139800003298880"                                }                            ],                            "parameterValues": [                                {                                    "category": {                                        "@id": "#139800003317376"                                    },                                    "value": "positive"                                },                                {                                    "category": {                                        "@id": "#139800003317664"                                    },                                    "value": "50-500"                                },                                {                                    "category": {                                        "@id": "#139800003342592"                                    },                                    "value": "Agilent Technologies mass selective detector (MSD 5975C) and MultiPurpose Sampler (MPS, MXY016-02A, GERSTEL)"                                },                                {                                    "category": {                                        "@id": "#139800003342880"                                    },                                    "value": "EI (70 eV)"                                },                                {                                    "category": {                                        "@id": "#139800003343168"                                    },                                    "value": "single-quadrupole"                                }                            ],                            "performer": "",                            "previousProcess": {                                "@id": "#process/139800003317136"                            }                        },                        {                            "@id": "#process/139800003343360",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003894048"                            },                            "inputs": [                                {                                    "@id": "#data/rawspectraldatafile-139800003298880"                                }                            ],                            "name": "data_transformation_XOM2",                            "nextProcess": {                                "@id": "#process/139800003343408"                            },                            "outputs": [                                {                                    "@id": "#data/normalizationname-139800003299024"                                },                                {                                    "@id": "#data/derivedspectraldatafile-139800003298976"                                }                            ],                            "parameterValues": [],                            "performer": "",                            "previousProcess": {                                "@id": "#process/139800003343312"                            }                        },                        {                            "@id": "#process/139800003343408",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003893904"                            },                            "inputs": [                                {                                    "@id": "#data/normalizationname-139800003299024"                                }                            ],                            "name": "metabolite_identification_XOM2",                            "outputs": [                                {                                    "@id": "#data/datatransformationname-139800003299168"                                },                                {                                    "@id": "#data/metaboliteassignmentfile-139800003299312"                                }                            ],                            "parameterValues": [],                            "performer": "",                            "previousProcess": {                                "@id": "#process/139800003343360"                            }                        },                        {                            "@id": "#process/139800003344128",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003740624"                            },                            "inputs": [                                {                                    "@id": "#sample/139800003604592"                                }                            ],                            "name": "",                            "nextProcess": {                                "@id": "#process/139800003344272"                            },                            "outputs": [                                {                                    "@id": "#material/extract-139800003344032"                                }                            ],                            "parameterValues": [                                {                                    "category": {                                        "@id": "#139800003343648"                                    },                                    "value": "1 uL pyridine"                                },                                {                                    "category": {                                        "@id": "#139800003343936"                                    },                                    "value": "oximation followed by silylation"                                }                            ],                            "performer": ""                        },                        {                            "@id": "#process/139800003344272",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003893328"                            },                            "inputs": [                                {                                    "@id": "#material/extract-139800003344032"                                }                            ],                            "name": "",                            "nextProcess": {                                "@id": "#process/139800003345184"                            },                            "outputs": [                                {                                    "@id": "#material/labledextract-139800003344176"                                }                            ],                            "parameterValues": [],                            "performer": "",                            "previousProcess": {                                "@id": "#process/139800003344128"                            }                        },                        {                            "@id": "#process/139800003345184",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003892176"                            },                            "inputs": [                                {                                    "@id": "#material/labledextract-139800003344176"                                }                            ],                            "name": "chromatography_XOM3",                            "nextProcess": {                                "@id": "#process/139800003358976"                            },                            "outputs": [],                            "parameterValues": [                                {                                    "category": {                                        "@id": "#139800003344512"                                    },                                    "value": "Agilent Technologies 7890A"                                },                                {                                    "category": {                                        "@id": "#139800003344800"                                    },                                    "value": "HP-5MS UI (5% Phenyl Methyl Silox), 30 m x 0.25 m ID column with a film thickness of 25 um"                                },                                {                                    "category": {                                        "@id": "#139800003345088"                                    },                                    "value": "low polarity"                                }                            ],                            "performer": "",                            "previousProcess": {                                "@id": "#process/139800003344272"                            }                        },                        {                            "@id": "#process/139800003358976",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003786688"                            },                            "inputs": [],                            "name": "mass_spectrometry_XOM3",                            "nextProcess": {                                "@id": "#process/139800003359024"                            },                            "outputs": [                                {                                    "@id": "#data/rawspectraldatafile-139800003298880"                                }                            ],                            "parameterValues": [                                {                                    "category": {                                        "@id": "#139800003345424"                                    },                                    "value": "positive"                                },                                {                                    "category": {                                        "@id": "#139800003345712"                                    },                                    "value": "50-500"                                },                                {                                    "category": {                                        "@id": "#139800003346000"                                    },                                    "value": "Agilent Technologies mass selective detector (MSD 5975C) and MultiPurpose Sampler (MPS, MXY016-02A, GERSTEL)"                                },                                {                                    "category": {                                        "@id": "#139800003346288"                                    },                                    "value": "EI (70 eV)"                                },                                {                                    "category": {                                        "@id": "#139800003658128"                                    },                                    "value": "single-quadrupole"                                }                            ],                            "performer": "",                            "previousProcess": {                                "@id": "#process/139800003345184"                            }                        },                        {                            "@id": "#process/139800003359024",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003894048"                            },                            "inputs": [                                {                                    "@id": "#data/rawspectraldatafile-139800003298880"                                }                            ],                            "name": "data_transformation_XOM3",                            "nextProcess": {                                "@id": "#process/139800003359072"                            },                            "outputs": [                                {                                    "@id": "#data/normalizationname-139800003299024"                                },                                {                                    "@id": "#data/derivedspectraldatafile-139800003298976"                                }                            ],                            "parameterValues": [],                            "performer": "",                            "previousProcess": {                                "@id": "#process/139800003358976"                            }                        },                        {                            "@id": "#process/139800003359072",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003893904"                            },                            "inputs": [                                {                                    "@id": "#data/normalizationname-139800003299024"                                }                            ],                            "name": "metabolite_identification_XOM3",                            "outputs": [                                {                                    "@id": "#data/datatransformationname-139800003299168"                                },                                {                                    "@id": "#data/metaboliteassignmentfile-139800003299312"                                }                            ],                            "parameterValues": [],                            "performer": "",                            "previousProcess": {                                "@id": "#process/139800003359024"                            }                        },                        {                            "@id": "#process/139800003359792",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003740624"                            },                            "inputs": [                                {                                    "@id": "#sample/139800003606704"                                }                            ],                            "name": "",                            "nextProcess": {                                "@id": "#process/139800003359936"                            },                            "outputs": [                                {                                    "@id": "#material/extract-139800003359696"                                }                            ],                            "parameterValues": [                                {                                    "category": {                                        "@id": "#139800003359312"                                    },                                    "value": "1 uL pyridine"                                },                                {                                    "category": {                                        "@id": "#139800003359600"                                    },                                    "value": "oximation followed by silylation"                                }                            ],                            "performer": ""                        },                        {                            "@id": "#process/139800003359936",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003893328"                            },                            "inputs": [                                {                                    "@id": "#material/extract-139800003359696"                                }                            ],                            "name": "",                            "nextProcess": {                                "@id": "#process/139800003360848"                            },                            "outputs": [                                {                                    "@id": "#material/labledextract-139800003359840"                                }                            ],                            "parameterValues": [],                            "performer": "",                            "previousProcess": {                                "@id": "#process/139800003359792"                            }                        },                        {                            "@id": "#process/139800003360848",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003892176"                            },                            "inputs": [                                {                                    "@id": "#material/labledextract-139800003359840"                                }                            ],                            "name": "chromatography_XOM4",                            "nextProcess": {                                "@id": "#process/139800003362384"                            },                            "outputs": [],                            "parameterValues": [                                {                                    "category": {                                        "@id": "#139800003360176"                                    },                                    "value": "Agilent Technologies 7890A"                                },                                {                                    "category": {                                        "@id": "#139800003360464"                                    },                                    "value": "HP-5MS UI (5% Phenyl Methyl Silox), 30 m x 0.25 m ID column with a film thickness of 25 um"                                },                                {                                    "category": {                                        "@id": "#139800003360752"                                    },                                    "value": "low polarity"                                }                            ],                            "performer": "",                            "previousProcess": {                                "@id": "#process/139800003359936"                            }                        },                        {                            "@id": "#process/139800003362384",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003786688"                            },                            "inputs": [],                            "name": "mass_spectrometry_XOM4",                            "nextProcess": {                                "@id": "#process/139800003362432"                            },                            "outputs": [                                {                                    "@id": "#data/rawspectraldatafile-139800003298880"                                }                            ],                            "parameterValues": [                                {                                    "category": {                                        "@id": "#139800003361088"                                    },                                    "value": "positive"                                },                                {                                    "category": {                                        "@id": "#139800003361376"                                    },                                    "value": "50-500"                                },                                {                                    "category": {                                        "@id": "#139800003361664"                                    },                                    "value": "Agilent Technologies mass selective detector (MSD 5975C) and MultiPurpose Sampler (MPS, MXY016-02A, GERSTEL)"                                },                                {                                    "category": {                                        "@id": "#139800003361952"                                    },                                    "value": "EI (70 eV)"                                },                                {                                    "category": {                                        "@id": "#139800003362240"                                    },                                    "value": "single-quadrupole"                                }                            ],                            "performer": "",                            "previousProcess": {                                "@id": "#process/139800003360848"                            }                        },                        {                            "@id": "#process/139800003362432",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003894048"                            },                            "inputs": [                                {                                    "@id": "#data/rawspectraldatafile-139800003298880"                                }                            ],                            "name": "data_transformation_XOM4",                            "nextProcess": {                                "@id": "#process/139800003362480"                            },                            "outputs": [                                {                                    "@id": "#data/normalizationname-139800003299024"                                },                                {                                    "@id": "#data/derivedspectraldatafile-139800003298976"                                }                            ],                            "parameterValues": [],                            "performer": "",                            "previousProcess": {                                "@id": "#process/139800003362384"                            }                        },                        {                            "@id": "#process/139800003362480",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003893904"                            },                            "inputs": [                                {                                    "@id": "#data/normalizationname-139800003299024"                                }                            ],                            "name": "metabolite_identification_XOM4",                            "outputs": [                                {                                    "@id": "#data/datatransformationname-139800003299168"                                },                                {                                    "@id": "#data/metaboliteassignmentfile-139800003299312"                                }                            ],                            "parameterValues": [],                            "performer": "",                            "previousProcess": {                                "@id": "#process/139800003362432"                            }                        },                        {                            "@id": "#process/139800003375552",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003740624"                            },                            "inputs": [                                {                                    "@id": "#sample/139800003600640"                                }                            ],                            "name": "",                            "nextProcess": {                                "@id": "#process/139800003375696"                            },                            "outputs": [                                {                                    "@id": "#material/extract-139800003375456"                                }                            ],                            "parameterValues": [                                {                                    "category": {                                        "@id": "#139800003362720"                                    },                                    "value": "1 uL pyridine"                                },                                {                                    "category": {                                        "@id": "#139800003375360"                                    },                                    "value": "oximation followed by silylation"                                }                            ],                            "performer": ""                        },                        {                            "@id": "#process/139800003375696",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003893328"                            },                            "inputs": [                                {                                    "@id": "#material/extract-139800003375456"                                }                            ],                            "name": "",                            "nextProcess": {                                "@id": "#process/139800003376608"                            },                            "outputs": [                                {                                    "@id": "#material/labledextract-139800003375600"                                }                            ],                            "parameterValues": [],                            "performer": "",                            "previousProcess": {                                "@id": "#process/139800003375552"                            }                        },                        {                            "@id": "#process/139800003376608",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003892176"                            },                            "inputs": [                                {                                    "@id": "#material/labledextract-139800003375600"                                }                            ],                            "name": "chromatography_XOM5",                            "nextProcess": {                                "@id": "#process/139800003378144"                            },                            "outputs": [],                            "parameterValues": [                                {                                    "category": {                                        "@id": "#139800003375936"                                    },                                    "value": "Agilent Technologies 7890A"                                },                                {                                    "category": {                                        "@id": "#139800003376224"                                    },                                    "value": "HP-5MS UI (5% Phenyl Methyl Silox), 30 m x 0.25 m ID column with a film thickness of 25 um"                                },                                {                                    "category": {                                        "@id": "#139800003376512"                                    },                                    "value": "low polarity"                                }                            ],                            "performer": "",                            "previousProcess": {                                "@id": "#process/139800003375696"                            }                        },                        {                            "@id": "#process/139800003378144",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003786688"                            },                            "inputs": [],                            "name": "mass_spectrometry_XOM5",                            "nextProcess": {                                "@id": "#process/139800003378192"                            },                            "outputs": [                                {                                    "@id": "#data/rawspectraldatafile-139800003298880"                                }                            ],                            "parameterValues": [                                {                                    "category": {                                        "@id": "#139800003376848"                                    },                                    "value": "positive"                                },                                {                                    "category": {                                        "@id": "#139800003377136"                                    },                                    "value": "50-500"                                },                                {                                    "category": {                                        "@id": "#139800003377424"                                    },                                    "value": "Agilent Technologies mass selective detector (MSD 5975C) and MultiPurpose Sampler (MPS, MXY016-02A, GERSTEL)"                                },                                {                                    "category": {                                        "@id": "#139800003377712"                                    },                                    "value": "EI (70 eV)"                                },                                {                                    "category": {                                        "@id": "#139800003378000"                                    },                                    "value": "single-quadrupole"                                }                            ],                            "performer": "",                            "previousProcess": {                                "@id": "#process/139800003376608"                            }                        },                        {                            "@id": "#process/139800003378192",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003894048"                            },                            "inputs": [                                {                                    "@id": "#data/rawspectraldatafile-139800003298880"                                }                            ],                            "name": "data_transformation_XOM5",                            "nextProcess": {                                "@id": "#process/139800003378240"                            },                            "outputs": [                                {                                    "@id": "#data/normalizationname-139800003299024"                                },                                {                                    "@id": "#data/derivedspectraldatafile-139800003298976"                                }                            ],                            "parameterValues": [],                            "performer": "",                            "previousProcess": {                                "@id": "#process/139800003378144"                            }                        },                        {                            "@id": "#process/139800003378240",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003893904"                            },                            "inputs": [                                {                                    "@id": "#data/normalizationname-139800003299024"                                }                            ],                            "name": "metabolite_identification_XOM5",                            "outputs": [                                {                                    "@id": "#data/datatransformationname-139800003299168"                                },                                {                                    "@id": "#data/metaboliteassignmentfile-139800003299312"                                }                            ],                            "parameterValues": [],                            "performer": "",                            "previousProcess": {                                "@id": "#process/139800003378192"                            }                        },                        {                            "@id": "#process/139800003378960",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003740624"                            },                            "inputs": [                                {                                    "@id": "#sample/139800003600592"                                }                            ],                            "name": "",                            "nextProcess": {                                "@id": "#process/139800003379104"                            },                            "outputs": [                                {                                    "@id": "#material/extract-139800003378864"                                }                            ],                            "parameterValues": [                                {                                    "category": {                                        "@id": "#139800003378480"                                    },                                    "value": "1 uL pyridine"                                },                                {                                    "category": {                                        "@id": "#139800003378768"                                    },                                    "value": "oximation followed by silylation"                                }                            ],                            "performer": ""                        },                        {                            "@id": "#process/139800003379104",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003893328"                            },                            "inputs": [                                {                                    "@id": "#material/extract-139800003378864"                                }                            ],                            "name": "",                            "nextProcess": {                                "@id": "#process/139800003384416"                            },                            "outputs": [                                {                                    "@id": "#material/labledextract-139800003379008"                                }                            ],                            "parameterValues": [],                            "performer": "",                            "previousProcess": {                                "@id": "#process/139800003378960"                            }                        },                        {                            "@id": "#process/139800003384416",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003892176"                            },                            "inputs": [                                {                                    "@id": "#material/labledextract-139800003379008"                                }                            ],                            "name": "chromatography_XOM6",                            "nextProcess": {                                "@id": "#process/139800003386000"                            },                            "outputs": [],                            "parameterValues": [                                {                                    "category": {                                        "@id": "#139800003383552"                                    },                                    "value": "Agilent Technologies 7890A"                                },                                {                                    "category": {                                        "@id": "#139800003384032"                                    },                                    "value": "HP-5MS UI (5% Phenyl Methyl Silox), 30 m x 0.25 m ID column with a film thickness of 25 um"                                },                                {                                    "category": {                                        "@id": "#139800003384320"                                    },                                    "value": "low polarity"                                }                            ],                            "performer": "",                            "previousProcess": {                                "@id": "#process/139800003379104"                            }                        },                        {                            "@id": "#process/139800003386000",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003786688"                            },                            "inputs": [],                            "name": "mass_spectrometry_XOM6",                            "nextProcess": {                                "@id": "#process/139800003386048"                            },                            "outputs": [                                {                                    "@id": "#data/rawspectraldatafile-139800003298880"                                }                            ],                            "parameterValues": [                                {                                    "category": {                                        "@id": "#139800003384704"                                    },                                    "value": "positive"                                },                                {                                    "category": {                                        "@id": "#139800003384896"                                    },                                    "value": "50-500"                                },                                {                                    "category": {                                        "@id": "#139800003385328"                                    },                                    "value": "Agilent Technologies mass selective detector (MSD 5975C) and MultiPurpose Sampler (MPS, MXY016-02A, GERSTEL)"                                },                                {                                    "category": {                                        "@id": "#139800003385664"                                    },                                    "value": "EI (70 eV)"                                },                                {                                    "category": {                                        "@id": "#139800003385088"                                    },                                    "value": "single-quadrupole"                                }                            ],                            "performer": "",                            "previousProcess": {                                "@id": "#process/139800003384416"                            }                        },                        {                            "@id": "#process/139800003386048",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003894048"                            },                            "inputs": [                                {                                    "@id": "#data/rawspectraldatafile-139800003298880"                                }                            ],                            "name": "data_transformation_XOM6",                            "nextProcess": {                                "@id": "#process/139800003383696"                            },                            "outputs": [                                {                                    "@id": "#data/normalizationname-139800003299024"                                },                                {                                    "@id": "#data/derivedspectraldatafile-139800003298976"                                }                            ],                            "parameterValues": [],                            "performer": "",                            "previousProcess": {                                "@id": "#process/139800003386000"                            }                        },                        {                            "@id": "#process/139800003383696",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003893904"                            },                            "inputs": [                                {                                    "@id": "#data/normalizationname-139800003299024"                                }                            ],                            "name": "metabolite_identification_XOM6",                            "outputs": [                                {                                    "@id": "#data/datatransformationname-139800003299168"                                },                                {                                    "@id": "#data/metaboliteassignmentfile-139800003299312"                                }                            ],                            "parameterValues": [],                            "performer": "",                            "previousProcess": {                                "@id": "#process/139800003386048"                            }                        },                        {                            "@id": "#process/139800003386816",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003740624"                            },                            "inputs": [                                {                                    "@id": "#sample/139800003617216"                                }                            ],                            "name": "",                            "nextProcess": {                                "@id": "#process/139800003387056"                            },                            "outputs": [                                {                                    "@id": "#material/extract-139800003386720"                                }                            ],                            "parameterValues": [                                {                                    "category": {                                        "@id": "#139800003386336"                                    },                                    "value": "1 uL pyridine"                                },                                {                                    "category": {                                        "@id": "#139800003384224"                                    },                                    "value": "oximation followed by silylation"                                }                            ],                            "performer": ""                        },                        {                            "@id": "#process/139800003387056",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003893328"                            },                            "inputs": [                                {                                    "@id": "#material/extract-139800003386720"                                }                            ],                            "name": "",                            "nextProcess": {                                "@id": "#process/139800003424512"                            },                            "outputs": [                                {                                    "@id": "#material/labledextract-139800003386960"                                }                            ],                            "parameterValues": [],                            "performer": "",                            "previousProcess": {                                "@id": "#process/139800003386816"                            }                        },                        {                            "@id": "#process/139800003424512",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003892176"                            },                            "inputs": [                                {                                    "@id": "#material/labledextract-139800003386960"                                }                            ],                            "name": "chromatography_XOM7",                            "nextProcess": {                                "@id": "#process/139800003426048"                            },                            "outputs": [],                            "parameterValues": [                                {                                    "category": {                                        "@id": "#139800003387296"                                    },                                    "value": "Agilent Technologies 7890A"                                },                                {                                    "category": {                                        "@id": "#139800003386624"                                    },                                    "value": "HP-5MS UI (5% Phenyl Methyl Silox), 30 m x 0.25 m ID column with a film thickness of 25 um"                                },                                {                                    "category": {                                        "@id": "#139800003424416"                                    },                                    "value": "low polarity"                                }                            ],                            "performer": "",                            "previousProcess": {                                "@id": "#process/139800003387056"                            }                        },                        {                            "@id": "#process/139800003426048",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003786688"                            },                            "inputs": [],                            "name": "mass_spectrometry_XOM7",                            "nextProcess": {                                "@id": "#process/139800003426096"                            },                            "outputs": [                                {                                    "@id": "#data/rawspectraldatafile-139800003298880"                                }                            ],                            "parameterValues": [                                {                                    "category": {                                        "@id": "#139800003424752"                                    },                                    "value": "positive"                                },                                {                                    "category": {                                        "@id": "#139800003425040"                                    },                                    "value": "50-500"                                },                                {                                    "category": {                                        "@id": "#139800003425328"                                    },                                    "value": "Agilent Technologies mass selective detector (MSD 5975C) and MultiPurpose Sampler (MPS, MXY016-02A, GERSTEL)"                                },                                {                                    "category": {                                        "@id": "#139800003425616"                                    },                                    "value": "EI (70 eV)"                                },                                {                                    "category": {                                        "@id": "#139800003425904"                                    },                                    "value": "single-quadrupole"                                }                            ],                            "performer": "",                            "previousProcess": {                                "@id": "#process/139800003424512"                            }                        },                        {                            "@id": "#process/139800003426096",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003894048"                            },                            "inputs": [                                {                                    "@id": "#data/rawspectraldatafile-139800003298880"                                }                            ],                            "name": "data_transformation_XOM7",                            "nextProcess": {                                "@id": "#process/139800003426144"                            },                            "outputs": [                                {                                    "@id": "#data/normalizationname-139800003299024"                                },                                {                                    "@id": "#data/derivedspectraldatafile-139800003298976"                                }                            ],                            "parameterValues": [],                            "performer": "",                            "previousProcess": {                                "@id": "#process/139800003426048"                            }                        },                        {                            "@id": "#process/139800003426144",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003893904"                            },                            "inputs": [                                {                                    "@id": "#data/normalizationname-139800003299024"                                }                            ],                            "name": "metabolite_identification_XOM7",                            "outputs": [                                {                                    "@id": "#data/datatransformationname-139800003299168"                                },                                {                                    "@id": "#data/metaboliteassignmentfile-139800003299312"                                }                            ],                            "parameterValues": [],                            "performer": "",                            "previousProcess": {                                "@id": "#process/139800003426096"                            }                        },                        {                            "@id": "#process/139800003426864",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003740624"                            },                            "inputs": [                                {                                    "@id": "#sample/139800003617120"                                }                            ],                            "name": "",                            "nextProcess": {                                "@id": "#process/139800003427008"                            },                            "outputs": [                                {                                    "@id": "#material/extract-139800003426768"                                }                            ],                            "parameterValues": [                                {                                    "category": {                                        "@id": "#139800003426384"                                    },                                    "value": "1 uL pyridine"                                },                                {                                    "category": {                                        "@id": "#139800003426672"                                    },                                    "value": "oximation followed by silylation"                                }                            ],                            "performer": ""                        },                        {                            "@id": "#process/139800003427008",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003893328"                            },                            "inputs": [                                {                                    "@id": "#material/extract-139800003426768"                                }                            ],                            "name": "",                            "nextProcess": {                                "@id": "#process/139800003427920"                            },                            "outputs": [                                {                                    "@id": "#material/labledextract-139800003426912"                                }                            ],                            "parameterValues": [],                            "performer": "",                            "previousProcess": {                                "@id": "#process/139800003426864"                            }                        },                        {                            "@id": "#process/139800003427920",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003892176"                            },                            "inputs": [                                {                                    "@id": "#material/labledextract-139800003426912"                                }                            ],                            "name": "chromatography_XOM8",                            "nextProcess": {                                "@id": "#process/139800003437808"                            },                            "outputs": [],                            "parameterValues": [                                {                                    "category": {                                        "@id": "#139800003427248"                                    },                                    "value": "Agilent Technologies 7890A"                                },                                {                                    "category": {                                        "@id": "#139800003427536"                                    },                                    "value": "HP-5MS UI (5% Phenyl Methyl Silox), 30 m x 0.25 m ID column with a film thickness of 25 um"                                },                                {                                    "category": {                                        "@id": "#139800003427824"                                    },                                    "value": "low polarity"                                }                            ],                            "performer": "",                            "previousProcess": {                                "@id": "#process/139800003427008"                            }                        },                        {                            "@id": "#process/139800003437808",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003786688"                            },                            "inputs": [],                            "name": "mass_spectrometry_XOM8",                            "nextProcess": {                                "@id": "#process/139800003437856"                            },                            "outputs": [                                {                                    "@id": "#data/rawspectraldatafile-139800003298880"                                }                            ],                            "parameterValues": [                                {                                    "category": {                                        "@id": "#139800003428160"                                    },                                    "value": "positive"                                },                                {                                    "category": {                                        "@id": "#139800003436752"                                    },                                    "value": "50-500"                                },                                {                                    "category": {                                        "@id": "#139800003437040"                                    },                                    "value": "Agilent Technologies mass selective detector (MSD 5975C) and MultiPurpose Sampler (MPS, MXY016-02A, GERSTEL)"                                },                                {                                    "category": {                                        "@id": "#139800003437424"                                    },                                    "value": "EI (70 eV)"                                },                                {                                    "category": {                                        "@id": "#139800003437664"                                    },                                    "value": "single-quadrupole"                                }                            ],                            "performer": "",                            "previousProcess": {                                "@id": "#process/139800003427920"                            }                        },                        {                            "@id": "#process/139800003437856",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003894048"                            },                            "inputs": [                                {                                    "@id": "#data/rawspectraldatafile-139800003298880"                                }                            ],                            "name": "data_transformation_XOM8",                            "nextProcess": {                                "@id": "#process/139800003437904"                            },                            "outputs": [                                {                                    "@id": "#data/normalizationname-139800003299024"                                },                                {                                    "@id": "#data/derivedspectraldatafile-139800003298976"                                }                            ],                            "parameterValues": [],                            "performer": "",                            "previousProcess": {                                "@id": "#process/139800003437808"                            }                        },                        {                            "@id": "#process/139800003437904",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003893904"                            },                            "inputs": [                                {                                    "@id": "#data/normalizationname-139800003299024"                                }                            ],                            "name": "metabolite_identification_XOM8",                            "outputs": [                                {                                    "@id": "#data/datatransformationname-139800003299168"                                },                                {                                    "@id": "#data/metaboliteassignmentfile-139800003299312"                                }                            ],                            "parameterValues": [],                            "performer": "",                            "previousProcess": {                                "@id": "#process/139800003437856"                            }                        },                        {                            "@id": "#process/139800003438528",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003740624"                            },                            "inputs": [                                {                                    "@id": "#sample/139800003646176"                                }                            ],                            "name": "",                            "nextProcess": {                                "@id": "#process/139800003438672"                            },                            "outputs": [                                {                                    "@id": "#material/extract-139800003438432"                                }                            ],                            "parameterValues": [                                {                                    "category": {                                        "@id": "#139800003438096"                                    },                                    "value": "1 uL pyridine"                                },                                {                                    "category": {                                        "@id": "#139800003438336"                                    },                                    "value": "oximation followed by silylation"                                }                            ],                            "performer": ""                        },                        {                            "@id": "#process/139800003438672",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003893328"                            },                            "inputs": [                                {                                    "@id": "#material/extract-139800003438432"                                }                            ],                            "name": "",                            "nextProcess": {                                "@id": "#process/139800003439680"                            },                            "outputs": [                                {                                    "@id": "#material/labledextract-139800003438576"                                }                            ],                            "parameterValues": [],                            "performer": "",                            "previousProcess": {                                "@id": "#process/139800003438528"                            }                        },                        {                            "@id": "#process/139800003439680",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003892176"                            },                            "inputs": [                                {                                    "@id": "#material/labledextract-139800003438576"                                }                            ],                            "name": "chromatography_XOM9",                            "nextProcess": {                                "@id": "#process/139800002925088"                            },                            "outputs": [],                            "parameterValues": [                                {                                    "category": {                                        "@id": "#139800003438960"                                    },                                    "value": "Agilent Technologies 7890A"                                },                                {                                    "category": {                                        "@id": "#139800003439248"                                    },                                    "value": "HP-5MS UI (5% Phenyl Methyl Silox), 30 m x 0.25 m ID column with a film thickness of 25 um"                                },                                {                                    "category": {                                        "@id": "#139800003439536"                                    },                                    "value": "low polarity"                                }                            ],                            "performer": "",                            "previousProcess": {                                "@id": "#process/139800003438672"                            }                        },                        {                            "@id": "#process/139800002925088",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003786688"                            },                            "inputs": [],                            "name": "mass_spectrometry_XOM9",                            "nextProcess": {                                "@id": "#process/139800002925136"                            },                            "outputs": [                                {                                    "@id": "#data/rawspectraldatafile-139800003298880"                                }                            ],                            "parameterValues": [                                {                                    "category": {                                        "@id": "#139800003439920"                                    },                                    "value": "positive"                                },                                {                                    "category": {                                        "@id": "#139800003440256"                                    },                                    "value": "50-500"                                },                                {                                    "category": {                                        "@id": "#139800003440496"                                    },                                    "value": "Agilent Technologies mass selective detector (MSD 5975C) and MultiPurpose Sampler (MPS, MXY016-02A, GERSTEL)"                                },                                {                                    "category": {                                        "@id": "#139800003438768"                                    },                                    "value": "EI (70 eV)"                                },                                {                                    "category": {                                        "@id": "#139800002924944"                                    },                                    "value": "single-quadrupole"                                }                            ],                            "performer": "",                            "previousProcess": {                                "@id": "#process/139800003439680"                            }                        },                        {                            "@id": "#process/139800002925136",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003894048"                            },                            "inputs": [                                {                                    "@id": "#data/rawspectraldatafile-139800003298880"                                }                            ],                            "name": "data_transformation_XOM9",                            "nextProcess": {                                "@id": "#process/139800002925184"                            },                            "outputs": [                                {                                    "@id": "#data/normalizationname-139800003299024"                                },                                {                                    "@id": "#data/derivedspectraldatafile-139800003298976"                                }                            ],                            "parameterValues": [],                            "performer": "",                            "previousProcess": {                                "@id": "#process/139800002925088"                            }                        },                        {                            "@id": "#process/139800002925184",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003893904"                            },                            "inputs": [                                {                                    "@id": "#data/normalizationname-139800003299024"                                }                            ],                            "name": "metabolite_identification_XOM9",                            "outputs": [                                {                                    "@id": "#data/datatransformationname-139800003299168"                                },                                {                                    "@id": "#data/metaboliteassignmentfile-139800003299312"                                }                            ],                            "parameterValues": [],                            "performer": "",                            "previousProcess": {                                "@id": "#process/139800002925136"                            }                        },                        {                            "@id": "#process/139800002925904",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003740624"                            },                            "inputs": [                                {                                    "@id": "#sample/139800003646080"                                }                            ],                            "name": "",                            "nextProcess": {                                "@id": "#process/139800002926048"                            },                            "outputs": [                                {                                    "@id": "#material/extract-139800002925808"                                }                            ],                            "parameterValues": [                                {                                    "category": {                                        "@id": "#139800002925424"                                    },                                    "value": "1 uL pyridine"                                },                                {                                    "category": {                                        "@id": "#139800002925712"                                    },                                    "value": "oximation followed by silylation"                                }                            ],                            "performer": ""                        },                        {                            "@id": "#process/139800002926048",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003893328"                            },                            "inputs": [                                {                                    "@id": "#material/extract-139800002925808"                                }                            ],                            "name": "",                            "nextProcess": {                                "@id": "#process/139800002926960"                            },                            "outputs": [                                {                                    "@id": "#material/labledextract-139800002925952"                                }                            ],                            "parameterValues": [],                            "performer": "",                            "previousProcess": {                                "@id": "#process/139800002925904"                            }                        },                        {                            "@id": "#process/139800002926960",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003892176"                            },                            "inputs": [                                {                                    "@id": "#material/labledextract-139800002925952"                                }                            ],                            "name": "chromatography_XOM10",                            "nextProcess": {                                "@id": "#process/139800002928496"                            },                            "outputs": [],                            "parameterValues": [                                {                                    "category": {                                        "@id": "#139800002926288"                                    },                                    "value": "Agilent Technologies 7890A"                                },                                {                                    "category": {                                        "@id": "#139800002926576"                                    },                                    "value": "HP-5MS UI (5% Phenyl Methyl Silox), 30 m x 0.25 m ID column with a film thickness of 25 um"                                },                                {                                    "category": {                                        "@id": "#139800002926864"                                    },                                    "value": "low polarity"                                }                            ],                            "performer": "",                            "previousProcess": {                                "@id": "#process/139800002926048"                            }                        },                        {                            "@id": "#process/139800002928496",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003786688"                            },                            "inputs": [],                            "name": "mass_spectrometry_XOM10",                            "nextProcess": {                                "@id": "#process/139800002928544"                            },                            "outputs": [                                {                                    "@id": "#data/rawspectraldatafile-139800003298880"                                }                            ],                            "parameterValues": [                                {                                    "category": {                                        "@id": "#139800002927200"                                    },                                    "value": "positive"                                },                                {                                    "category": {                                        "@id": "#139800002927488"                                    },                                    "value": "50-500"                                },                                {                                    "category": {                                        "@id": "#139800002927776"                                    },                                    "value": "Agilent Technologies mass selective detector (MSD 5975C) and MultiPurpose Sampler (MPS, MXY016-02A, GERSTEL)"                                },                                {                                    "category": {                                        "@id": "#139800002928064"                                    },                                    "value": "EI (70 eV)"                                },                                {                                    "category": {                                        "@id": "#139800002928352"                                    },                                    "value": "single-quadrupole"                                }                            ],                            "performer": "",                            "previousProcess": {                                "@id": "#process/139800002926960"                            }                        },                        {                            "@id": "#process/139800002928544",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003894048"                            },                            "inputs": [                                {                                    "@id": "#data/rawspectraldatafile-139800003298880"                                }                            ],                            "name": "data_transformation_XOM10",                            "nextProcess": {                                "@id": "#process/139800002928592"                            },                            "outputs": [                                {                                    "@id": "#data/normalizationname-139800003299024"                                },                                {                                    "@id": "#data/derivedspectraldatafile-139800003298976"                                }                            ],                            "parameterValues": [],                            "performer": "",                            "previousProcess": {                                "@id": "#process/139800002928496"                            }                        },                        {                            "@id": "#process/139800002928592",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003893904"                            },                            "inputs": [                                {                                    "@id": "#data/normalizationname-139800003299024"                                }                            ],                            "name": "metabolite_identification_XOM10",                            "outputs": [                                {                                    "@id": "#data/datatransformationname-139800003299168"                                },                                {                                    "@id": "#data/metaboliteassignmentfile-139800003299312"                                }                            ],                            "parameterValues": [],                            "performer": "",                            "previousProcess": {                                "@id": "#process/139800002928544"                            }                        }                    ],                    "technologyPlatform": "",                    "technologyType": {                        "@id": "#c1b4f4d9-9cc7-4887-bb69-307374015170",                        "annotationValue": "gas chromatography-mass spectrometry",                        "comments": [],                        "termAccession": "",                        "termSource": "CHMO"                    },                    "unitCategories": []                },                {                    "characteristicCategories": [],                    "comments": [],                    "dataFiles": [                        {                            "@id": "#data/rawspectraldatafile-139800002961520",                            "comments": [],                            "name": "link/to/raw/data",                            "type": "Raw Spectral Data File"                        },                        {                            "@id": "#data/normalizationname-139800002961616",                            "comments": [],                            "name": "link/to/normalized_data",                            "type": "Normalization Name"                        },                        {                            "@id": "#data/derivedspectraldatafile-139800002961568",                            "comments": [],                            "name": "link/to/spectral_file",                            "type": "Derived Spectral Data File"                        },                        {                            "@id": "#data/datatransformationname-139800002961760",                            "comments": [],                            "name": "link/to/data_transformation_name",                            "type": "Data Transformation Name"                        },                        {                            "@id": "#data/metaboliteassignmentfile-139800002961904",                            "comments": [],                            "name": "link/to/MAF",                            "type": "Metabolite Assignment File"                        },                        {                            "@id": "#data/rawspectraldatafile-139800002961520",                            "comments": [],                            "name": "link/to/raw/data",                            "type": "Raw Spectral Data File"                        },                        {                            "@id": "#data/normalizationname-139800002961616",                            "comments": [],                            "name": "link/to/normalized_data",                            "type": "Normalization Name"                        },                        {                            "@id": "#data/derivedspectraldatafile-139800002961568",                            "comments": [],                            "name": "link/to/spectral_file",                            "type": "Derived Spectral Data File"                        },                        {                            "@id": "#data/datatransformationname-139800002961760",                            "comments": [],                            "name": "link/to/data_transformation_name",                            "type": "Data Transformation Name"                        },                        {                            "@id": "#data/metaboliteassignmentfile-139800002961904",                            "comments": [],                            "name": "link/to/MAF",                            "type": "Metabolite Assignment File"                        },                        {                            "@id": "#data/rawspectraldatafile-139800002961520",                            "comments": [],                            "name": "link/to/raw/data",                            "type": "Raw Spectral Data File"                        },                        {                            "@id": "#data/normalizationname-139800002961616",                            "comments": [],                            "name": "link/to/normalized_data",                            "type": "Normalization Name"                        },                        {                            "@id": "#data/derivedspectraldatafile-139800002961568",                            "comments": [],                            "name": "link/to/spectral_file",                            "type": "Derived Spectral Data File"                        },                        {                            "@id": "#data/datatransformationname-139800002961760",                            "comments": [],                            "name": "link/to/data_transformation_name",                            "type": "Data Transformation Name"                        },                        {                            "@id": "#data/metaboliteassignmentfile-139800002961904",                            "comments": [],                            "name": "link/to/MAF",                            "type": "Metabolite Assignment File"                        },                        {                            "@id": "#data/rawspectraldatafile-139800002961520",                            "comments": [],                            "name": "link/to/raw/data",                            "type": "Raw Spectral Data File"                        },                        {                            "@id": "#data/normalizationname-139800002961616",                            "comments": [],                            "name": "link/to/normalized_data",                            "type": "Normalization Name"                        },                        {                            "@id": "#data/derivedspectraldatafile-139800002961568",                            "comments": [],                            "name": "link/to/spectral_file",                            "type": "Derived Spectral Data File"                        },                        {                            "@id": "#data/datatransformationname-139800002961760",                            "comments": [],                            "name": "link/to/data_transformation_name",                            "type": "Data Transformation Name"                        },                        {                            "@id": "#data/metaboliteassignmentfile-139800002961904",                            "comments": [],                            "name": "link/to/MAF",                            "type": "Metabolite Assignment File"                        },                        {                            "@id": "#data/rawspectraldatafile-139800002961520",                            "comments": [],                            "name": "link/to/raw/data",                            "type": "Raw Spectral Data File"                        },                        {                            "@id": "#data/normalizationname-139800002961616",                            "comments": [],                            "name": "link/to/normalized_data",                            "type": "Normalization Name"                        },                        {                            "@id": "#data/derivedspectraldatafile-139800002961568",                            "comments": [],                            "name": "link/to/spectral_file",                            "type": "Derived Spectral Data File"                        },                        {                            "@id": "#data/datatransformationname-139800002961760",                            "comments": [],                            "name": "link/to/data_transformation_name",                            "type": "Data Transformation Name"                        },                        {                            "@id": "#data/metaboliteassignmentfile-139800002961904",                            "comments": [],                            "name": "link/to/MAF",                            "type": "Metabolite Assignment File"                        },                        {                            "@id": "#data/rawspectraldatafile-139800002961520",                            "comments": [],                            "name": "link/to/raw/data",                            "type": "Raw Spectral Data File"                        },                        {                            "@id": "#data/normalizationname-139800002961616",                            "comments": [],                            "name": "link/to/normalized_data",                            "type": "Normalization Name"                        },                        {                            "@id": "#data/derivedspectraldatafile-139800002961568",                            "comments": [],                            "name": "link/to/spectral_file",                            "type": "Derived Spectral Data File"                        },                        {                            "@id": "#data/datatransformationname-139800002961760",                            "comments": [],                            "name": "link/to/data_transformation_name",                            "type": "Data Transformation Name"                        },                        {                            "@id": "#data/metaboliteassignmentfile-139800002961904",                            "comments": [],                            "name": "link/to/MAF",                            "type": "Metabolite Assignment File"                        },                        {                            "@id": "#data/rawspectraldatafile-139800002961520",                            "comments": [],                            "name": "link/to/raw/data",                            "type": "Raw Spectral Data File"                        },                        {                            "@id": "#data/normalizationname-139800002961616",                            "comments": [],                            "name": "link/to/normalized_data",                            "type": "Normalization Name"                        },                        {                            "@id": "#data/derivedspectraldatafile-139800002961568",                            "comments": [],                            "name": "link/to/spectral_file",                            "type": "Derived Spectral Data File"                        },                        {                            "@id": "#data/datatransformationname-139800002961760",                            "comments": [],                            "name": "link/to/data_transformation_name",                            "type": "Data Transformation Name"                        },                        {                            "@id": "#data/metaboliteassignmentfile-139800002961904",                            "comments": [],                            "name": "link/to/MAF",                            "type": "Metabolite Assignment File"                        },                        {                            "@id": "#data/rawspectraldatafile-139800002961520",                            "comments": [],                            "name": "link/to/raw/data",                            "type": "Raw Spectral Data File"                        },                        {                            "@id": "#data/normalizationname-139800002961616",                            "comments": [],                            "name": "link/to/normalized_data",                            "type": "Normalization Name"                        },                        {                            "@id": "#data/derivedspectraldatafile-139800002961568",                            "comments": [],                            "name": "link/to/spectral_file",                            "type": "Derived Spectral Data File"                        },                        {                            "@id": "#data/datatransformationname-139800002961760",                            "comments": [],                            "name": "link/to/data_transformation_name",                            "type": "Data Transformation Name"                        },                        {                            "@id": "#data/metaboliteassignmentfile-139800002961904",                            "comments": [],                            "name": "link/to/MAF",                            "type": "Metabolite Assignment File"                        },                        {                            "@id": "#data/rawspectraldatafile-139800002961520",                            "comments": [],                            "name": "link/to/raw/data",                            "type": "Raw Spectral Data File"                        },                        {                            "@id": "#data/normalizationname-139800002961616",                            "comments": [],                            "name": "link/to/normalized_data",                            "type": "Normalization Name"                        },                        {                            "@id": "#data/derivedspectraldatafile-139800002961568",                            "comments": [],                            "name": "link/to/spectral_file",                            "type": "Derived Spectral Data File"                        },                        {                            "@id": "#data/datatransformationname-139800002961760",                            "comments": [],                            "name": "link/to/data_transformation_name",                            "type": "Data Transformation Name"                        },                        {                            "@id": "#data/metaboliteassignmentfile-139800002961904",                            "comments": [],                            "name": "link/to/MAF",                            "type": "Metabolite Assignment File"                        },                        {                            "@id": "#data/rawspectraldatafile-139800002961520",                            "comments": [],                            "name": "link/to/raw/data",                            "type": "Raw Spectral Data File"                        },                        {                            "@id": "#data/normalizationname-139800002961616",                            "comments": [],                            "name": "link/to/normalized_data",                            "type": "Normalization Name"                        },                        {                            "@id": "#data/derivedspectraldatafile-139800002961568",                            "comments": [],                            "name": "link/to/spectral_file",                            "type": "Derived Spectral Data File"                        },                        {                            "@id": "#data/datatransformationname-139800002961760",                            "comments": [],                            "name": "link/to/data_transformation_name",                            "type": "Data Transformation Name"                        },                        {                            "@id": "#data/metaboliteassignmentfile-139800002961904",                            "comments": [],                            "name": "link/to/MAF",                            "type": "Metabolite Assignment File"                        }                    ],                    "filename": "a_assay_metabolomics_steroids.txt",                    "materials": {                        "otherMaterials": [                            {                                "@id": "#material/extract-139800002962912",                                "characteristics": [],                                "name": "extract_XOM1 ",                                "type": "Extract Name"                            },                            {                                "@id": "#material/labledextract-139800002963056",                                "characteristics": [],                                "name": "labeled_XOM1 ",                                "type": "Labeled Extract Name"                            },                            {                                "@id": "#material/extract-139800002978672",                                "characteristics": [],                                "name": "extract_XOM2",                                "type": "Extract Name"                            },                            {                                "@id": "#material/labledextract-139800002978816",                                "characteristics": [],                                "name": "labeled_XOM2",                                "type": "Labeled Extract Name"                            },                            {                                "@id": "#material/extract-139800002986288",                                "characteristics": [],                                "name": "extract_XOM3",                                "type": "Extract Name"                            },                            {                                "@id": "#material/labledextract-139800002986432",                                "characteristics": [],                                "name": "labeled_XOM3",                                "type": "Labeled Extract Name"                            },                            {                                "@id": "#material/extract-139800002989696",                                "characteristics": [],                                "name": "extract_XOM4",                                "type": "Extract Name"                            },                            {                                "@id": "#material/labledextract-139800002989840",                                "characteristics": [],                                "name": "labeled_XOM4",                                "type": "Labeled Extract Name"                            },                            {                                "@id": "#material/extract-139800003005360",                                "characteristics": [],                                "name": "extract_XOM5",                                "type": "Extract Name"                            },                            {                                "@id": "#material/labledextract-139800003005504",                                "characteristics": [],                                "name": "labeled_XOM5",                                "type": "Labeled Extract Name"                            },                            {                                "@id": "#material/extract-139800003017120",                                "characteristics": [],                                "name": "extract_XOM6",                                "type": "Extract Name"                            },                            {                                "@id": "#material/labledextract-139800003017264",                                "characteristics": [],                                "name": "labeled_XOM6",                                "type": "Labeled Extract Name"                            },                            {                                "@id": "#material/extract-139800003036976",                                "characteristics": [],                                "name": "extract_XOM7",                                "type": "Extract Name"                            },                            {                                "@id": "#material/labledextract-139800003037072",                                "characteristics": [],                                "name": "labeled_XOM7",                                "type": "Labeled Extract Name"                            },                            {                                "@id": "#material/extract-139800003052640",                                "characteristics": [],                                "name": "extract_XOM8",                                "type": "Extract Name"                            },                            {                                "@id": "#material/labledextract-139800003052784",                                "characteristics": [],                                "name": "labeled_XOM8",                                "type": "Labeled Extract Name"                            },                            {                                "@id": "#material/extract-139800003068400",                                "characteristics": [],                                "name": "extract_XOM9",                                "type": "Extract Name"                            },                            {                                "@id": "#material/labledextract-139800003068544",                                "characteristics": [],                                "name": "labeled_XOM9",                                "type": "Labeled Extract Name"                            },                            {                                "@id": "#material/extract-139800003071808",                                "characteristics": [],                                "name": "extract_XOM10",                                "type": "Extract Name"                            },                            {                                "@id": "#material/labledextract-139800003071952",                                "characteristics": [],                                "name": "labeled_XOM10",                                "type": "Labeled Extract Name"                            }                        ],                        "samples": [                            {                                "@id": "#sample/139800003550704",                                "characteristics": [                                    {                                        "category": {                                            "@id": "#196b3e41-5a75-439f-aacd-06b46d06be25"                                        },                                        "value": {                                            "@id": "#b4c7521a-9349-41b2-926e-f37c8d272824",                                            "annotationValue": "urine",                                            "comments": [],                                            "termAccession": "http://purl.obolibrary.org/obo/UBERON_0001088",                                            "termSource": "UBERON"                                        }                                    },                                    {                                        "category": {                                            "@id": "#9c885ee6-527b-4b1f-868d-b63b2c3c186b"                                        },                                        "value": {                                            "@id": "#6de4f95f-fa62-4cbb-9d7d-0613ddfa140f",                                            "annotationValue": "experimental sample",                                            "comments": [],                                            "termAccession": "http://purl.obolibrary.org/obo/CHMO_0002746",                                            "termSource": "CHMO"                                        }                                    }                                ],                                "factorValues": [],                                "name": "urine_XOP1"                            },                            {                                "@id": "#sample/139800003581792",                                "characteristics": [                                    {                                        "category": {                                            "@id": "#7f429d01-61c1-4d86-9942-d90b366be47c"                                        },                                        "value": {                                            "@id": "#850e1951-47c2-400e-947f-fd5cbe7c54a6",                                            "annotationValue": "urine",                                            "comments": [],                                            "termAccession": "http://purl.obolibrary.org/obo/UBERON_0001088",                                            "termSource": "UBERON"                                        }                                    },                                    {                                        "category": {                                            "@id": "#43caf586-7aae-4dc7-998e-6a20aef00875"                                        },                                        "value": {                                            "@id": "#4c4f5e89-8f99-4f6c-98b4-e5420d666080",                                            "annotationValue": "experimental sample",                                            "comments": [],                                            "termAccession": "http://purl.obolibrary.org/obo/CHMO_0002746",                                            "termSource": "CHMO"                                        }                                    }                                ],                                "factorValues": [],                                "name": "urine_XOP2"                            },                            {                                "@id": "#sample/139800003604592",                                "characteristics": [                                    {                                        "category": {                                            "@id": "#4720eed4-9af5-4fd5-9fb4-a750508187c0"                                        },                                        "value": {                                            "@id": "#a9ddbe6d-2102-4c3c-8214-f4eb1e91438b",                                            "annotationValue": "urine",                                            "comments": [],                                            "termAccession": "http://purl.obolibrary.org/obo/UBERON_0001088",                                            "termSource": "UBERON"                                        }                                    },                                    {                                        "category": {                                            "@id": "#d48be27a-c378-4f7c-b514-7b8439140fbc"                                        },                                        "value": {                                            "@id": "#910ea8e4-77ff-46be-acac-4dd1315d83f7",                                            "annotationValue": "experimental sample",                                            "comments": [],                                            "termAccession": "http://purl.obolibrary.org/obo/CHMO_0002746",                                            "termSource": "CHMO"                                        }                                    }                                ],                                "factorValues": [],                                "name": "urine_XOP3"                            },                            {                                "@id": "#sample/139800003606704",                                "characteristics": [                                    {                                        "category": {                                            "@id": "#2e697ec4-4d72-4b76-95d1-061fbc7269f3"                                        },                                        "value": {                                            "@id": "#ebe6698f-ec4d-440b-9aa7-e75e0a45ffce",                                            "annotationValue": "urine",                                            "comments": [],                                            "termAccession": "http://purl.obolibrary.org/obo/UBERON_0001088",                                            "termSource": "UBERON"                                        }                                    },                                    {                                        "category": {                                            "@id": "#4f140a54-71da-46d7-94dd-9a846f7961cd"                                        },                                        "value": {                                            "@id": "#4a1eda5e-2e99-4295-9c27-3f95939d6ae0",                                            "annotationValue": "experimental sample",                                            "comments": [],                                            "termAccession": "http://purl.obolibrary.org/obo/CHMO_0002746",                                            "termSource": "CHMO"                                        }                                    }                                ],                                "factorValues": [],                                "name": "urine_XOP4"                            },                            {                                "@id": "#sample/139800003600640",                                "characteristics": [                                    {                                        "category": {                                            "@id": "#64eebdc9-433a-4ce0-a07c-490b3e97427c"                                        },                                        "value": {                                            "@id": "#abc046b0-091c-4326-85ca-95f13ec34337",                                            "annotationValue": "urine",                                            "comments": [],                                            "termAccession": "http://purl.obolibrary.org/obo/UBERON_0001088",                                            "termSource": "UBERON"                                        }                                    },                                    {                                        "category": {                                            "@id": "#bfd93452-d295-474a-9fd5-73a9328fb35c"                                        },                                        "value": {                                            "@id": "#1dca670a-c7b0-48b1-b5a0-30d48bdda1bb",                                            "annotationValue": "experimental sample",                                            "comments": [],                                            "termAccession": "http://purl.obolibrary.org/obo/CHMO_0002746",                                            "termSource": "CHMO"                                        }                                    }                                ],                                "factorValues": [],                                "name": "urine_XOP5"                            },                            {                                "@id": "#sample/139800003600592",                                "characteristics": [                                    {                                        "category": {                                            "@id": "#768a76a7-4463-4937-a4de-857164e5fff3"                                        },                                        "value": {                                            "@id": "#44da0995-dc29-49aa-b8c6-1771ff1b4983",                                            "annotationValue": "urine",                                            "comments": [],                                            "termAccession": "http://purl.obolibrary.org/obo/UBERON_0001088",                                            "termSource": "UBERON"                                        }                                    },                                    {                                        "category": {                                            "@id": "#62204b82-d75c-49f3-b7db-a86c7daa395b"                                        },                                        "value": {                                            "@id": "#7eff269c-7c87-46b6-82c5-af425e533f5c",                                            "annotationValue": "experimental sample",                                            "comments": [],                                            "termAccession": "http://purl.obolibrary.org/obo/CHMO_0002746",                                            "termSource": "CHMO"                                        }                                    }                                ],                                "factorValues": [],                                "name": "urine_XOP6"                            },                            {                                "@id": "#sample/139800003617216",                                "characteristics": [                                    {                                        "category": {                                            "@id": "#7342cd89-8093-420d-ae32-20f4c328cb1f"                                        },                                        "value": {                                            "@id": "#3a2f1236-f52c-4cde-b885-8a49f8bd945f",                                            "annotationValue": "urine",                                            "comments": [],                                            "termAccession": "http://purl.obolibrary.org/obo/UBERON_0001088",                                            "termSource": "UBERON"                                        }                                    },                                    {                                        "category": {                                            "@id": "#3f136fcd-9b03-4296-a2fa-3cfd961d2041"                                        },                                        "value": {                                            "@id": "#c9983013-a289-41b0-a535-ac36b5ed66ec",                                            "annotationValue": "experimental sample",                                            "comments": [],                                            "termAccession": "http://purl.obolibrary.org/obo/CHMO_0002746",                                            "termSource": "CHMO"                                        }                                    }                                ],                                "factorValues": [],                                "name": "urine_XOP7"                            },                            {                                "@id": "#sample/139800003617120",                                "characteristics": [                                    {                                        "category": {                                            "@id": "#4ae1915a-7cf4-487e-abeb-e0378a0f881b"                                        },                                        "value": {                                            "@id": "#1be733cf-5686-46bc-9468-08af1adb0265",                                            "annotationValue": "urine",                                            "comments": [],                                            "termAccession": "http://purl.obolibrary.org/obo/UBERON_0001088",                                            "termSource": "UBERON"                                        }                                    },                                    {                                        "category": {                                            "@id": "#f85fcc53-0e49-4430-90b8-a32e79ad12ed"                                        },                                        "value": {                                            "@id": "#43d8b5bc-ffbe-47cc-9702-5f8724f3a832",                                            "annotationValue": "experimental sample",                                            "comments": [],                                            "termAccession": "http://purl.obolibrary.org/obo/CHMO_0002746",                                            "termSource": "CHMO"                                        }                                    }                                ],                                "factorValues": [],                                "name": "urine_XOP8"                            },                            {                                "@id": "#sample/139800003646176",                                "characteristics": [                                    {                                        "category": {                                            "@id": "#df3be894-44ea-4f1e-9f38-79bf2811b4ba"                                        },                                        "value": {                                            "@id": "#8a42510b-d0a2-4b5c-9c77-96b0ab30fbf3",                                            "annotationValue": "urine",                                            "comments": [],                                            "termAccession": "http://purl.obolibrary.org/obo/UBERON_0001088",                                            "termSource": "UBERON"                                        }                                    },                                    {                                        "category": {                                            "@id": "#de90c9fc-5316-490d-aa56-c0a5af098e70"                                        },                                        "value": {                                            "@id": "#73b93652-4208-4191-91fd-bc6b0b521260",                                            "annotationValue": "experimental sample",                                            "comments": [],                                            "termAccession": "http://purl.obolibrary.org/obo/CHMO_0002746",                                            "termSource": "CHMO"                                        }                                    }                                ],                                "factorValues": [],                                "name": "urine_XOP9"                            },                            {                                "@id": "#sample/139800003646080",                                "characteristics": [                                    {                                        "category": {                                            "@id": "#713c5fa7-ee56-42e5-b084-a5008269ff0c"                                        },                                        "value": {                                            "@id": "#cf7e8c2e-3b58-46a2-8ed7-1fc3ceff8e30",                                            "annotationValue": "urine",                                            "comments": [],                                            "termAccession": "http://purl.obolibrary.org/obo/UBERON_0001088",                                            "termSource": "UBERON"                                        }                                    },                                    {                                        "category": {                                            "@id": "#8e38bdf2-412e-402b-89a6-7483806710b3"                                        },                                        "value": {                                            "@id": "#b2e45b85-affa-4582-9712-22b704630657",                                            "annotationValue": "experimental sample",                                            "comments": [],                                            "termAccession": "http://purl.obolibrary.org/obo/CHMO_0002746",                                            "termSource": "CHMO"                                        }                                    }                                ],                                "factorValues": [],                                "name": "urine_XOP10"                            }                        ]                    },                    "measurementType": {                        "@id": "#5da76fae-d8cb-44ca-93c3-569630d86f4a",                        "annotationValue": "targeted metabolite profiling",                        "comments": [],                        "termAccession": "http://purl.obolibrary.org/obo/MSIO_0000100",                        "termSource": "MSIO"                    },                    "processSequence": [                        {                            "@id": "#process/139800002963008",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003740624"                            },                            "inputs": [                                {                                    "@id": "#sample/139800003550704"                                }                            ],                            "name": "",                            "nextProcess": {                                "@id": "#process/139800002963152"                            },                            "outputs": [                                {                                    "@id": "#material/extract-139800002962912"                                }                            ],                            "parameterValues": [                                {                                    "category": {                                        "@id": "#139800002962432"                                    },                                    "value": "1 uL filtered urine"                                },                                {                                    "category": {                                        "@id": "#139800002962720"                                    },                                    "value": "NA"                                }                            ],                            "performer": ""                        },                        {                            "@id": "#process/139800002963152",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003893328"                            },                            "inputs": [                                {                                    "@id": "#material/extract-139800002962912"                                }                            ],                            "name": "",                            "nextProcess": {                                "@id": "#process/139800002964064"                            },                            "outputs": [                                {                                    "@id": "#material/labledextract-139800002963056"                                }                            ],                            "parameterValues": [],                            "performer": "",                            "previousProcess": {                                "@id": "#process/139800002963008"                            }                        },                        {                            "@id": "#process/139800002964064",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003892176"                            },                            "inputs": [                                {                                    "@id": "#material/labledextract-139800002963056"                                }                            ],                            "name": "chromatography_XOM1 ",                            "nextProcess": {                                "@id": "#process/139800002977952"                            },                            "outputs": [],                            "parameterValues": [                                {                                    "category": {                                        "@id": "#139800002963392"                                    },                                    "value": "Agilent 1290"                                },                                {                                    "category": {                                        "@id": "#139800002963680"                                    },                                    "value": "Acquity UPLC CSH C18 column (Waters)"                                },                                {                                    "category": {                                        "@id": "#139800002963968"                                    },                                    "value": "reverse phase"                                }                            ],                            "performer": "",                            "previousProcess": {                                "@id": "#process/139800002963152"                            }                        },                        {                            "@id": "#process/139800002977952",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003786688"                            },                            "inputs": [],                            "name": "mass_spectrometry_XOM1 ",                            "nextProcess": {                                "@id": "#process/139800002978000"                            },                            "outputs": [                                {                                    "@id": "#data/rawspectraldatafile-139800002961520"                                }                            ],                            "parameterValues": [                                {                                    "category": {                                        "@id": "#139800002964304"                                    },                                    "value": "switching positive and negative ion mode !! MAYBE SERPARATE INTO NEGATIVE AND POSITIVE ASSAY?"                                },                                {                                    "category": {                                        "@id": "#139800002964592"                                    },                                    "value": "5-3000?"                                },                                {                                    "category": {                                        "@id": "#139800002964880"                                    },                                    "value": "Agilent 6460"                                },                                {                                    "category": {                                        "@id": "#139800002965168"                                    },                                    "value": "ESI"                                },                                {                                    "category": {                                        "@id": "#139800002965456"                                    },                                    "value": "triple quadrupole"                                }                            ],                            "performer": "",                            "previousProcess": {                                "@id": "#process/139800002964064"                            }                        },                        {                            "@id": "#process/139800002978000",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003894048"                            },                            "inputs": [                                {                                    "@id": "#data/rawspectraldatafile-139800002961520"                                }                            ],                            "name": "data_transformation_XOM1 ",                            "nextProcess": {                                "@id": "#process/139800002978048"                            },                            "outputs": [                                {                                    "@id": "#data/normalizationname-139800002961616"                                },                                {                                    "@id": "#data/derivedspectraldatafile-139800002961568"                                }                            ],                            "parameterValues": [],                            "performer": "",                            "previousProcess": {                                "@id": "#process/139800002977952"                            }                        },                        {                            "@id": "#process/139800002978048",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003893904"                            },                            "inputs": [                                {                                    "@id": "#data/normalizationname-139800002961616"                                }                            ],                            "name": "metabolite_identification_XOM1 ",                            "outputs": [                                {                                    "@id": "#data/datatransformationname-139800002961760"                                },                                {                                    "@id": "#data/metaboliteassignmentfile-139800002961904"                                }                            ],                            "parameterValues": [],                            "performer": "",                            "previousProcess": {                                "@id": "#process/139800002978000"                            }                        },                        {                            "@id": "#process/139800002978768",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003740624"                            },                            "inputs": [                                {                                    "@id": "#sample/139800003581792"                                }                            ],                            "name": "",                            "nextProcess": {                                "@id": "#process/139800002978912"                            },                            "outputs": [                                {                                    "@id": "#material/extract-139800002978672"                                }                            ],                            "parameterValues": [                                {                                    "category": {                                        "@id": "#139800002978288"                                    },                                    "value": "1 uL filtered urine"                                },                                {                                    "category": {                                        "@id": "#139800002978576"                                    },                                    "value": "NA"                                }                            ],                            "performer": ""                        },                        {                            "@id": "#process/139800002978912",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003893328"                            },                            "inputs": [                                {                                    "@id": "#material/extract-139800002978672"                                }                            ],                            "name": "",                            "nextProcess": {                                "@id": "#process/139800002979824"                            },                            "outputs": [                                {                                    "@id": "#material/labledextract-139800002978816"                                }                            ],                            "parameterValues": [],                            "performer": "",                            "previousProcess": {                                "@id": "#process/139800002978768"                            }                        },                        {                            "@id": "#process/139800002979824",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003892176"                            },                            "inputs": [                                {                                    "@id": "#material/labledextract-139800002978816"                                }                            ],                            "name": "chromatography_XOM2",                            "nextProcess": {                                "@id": "#process/139800002981408"                            },                            "outputs": [],                            "parameterValues": [                                {                                    "category": {                                        "@id": "#139800002979152"                                    },                                    "value": "Agilent 1290"                                },                                {                                    "category": {                                        "@id": "#139800002979440"                                    },                                    "value": "Acquity UPLC CSH C18 column (Waters)"                                },                                {                                    "category": {                                        "@id": "#139800002979728"                                    },                                    "value": "reverse phase"                                }                            ],                            "performer": "",                            "previousProcess": {                                "@id": "#process/139800002978912"                            }                        },                        {                            "@id": "#process/139800002981408",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003786688"                            },                            "inputs": [],                            "name": "mass_spectrometry_XOM2",                            "nextProcess": {                                "@id": "#process/139800002981456"                            },                            "outputs": [                                {                                    "@id": "#data/rawspectraldatafile-139800002961520"                                }                            ],                            "parameterValues": [                                {                                    "category": {                                        "@id": "#139800002980064"                                    },                                    "value": "switching positive and negative ion mode !! MAYBE SERPARATE INTO NEGATIVE AND POSITIVE ASSAY?"                                },                                {                                    "category": {                                        "@id": "#139800002980352"                                    },                                    "value": "5-3000?"                                },                                {                                    "category": {                                        "@id": "#139800002980640"                                    },                                    "value": "Agilent 6460"                                },                                {                                    "category": {                                        "@id": "#139800002980928"                                    },                                    "value": "ESI"                                },                                {                                    "category": {                                        "@id": "#139800002981264"                                    },                                    "value": "triple quadrupole"                                }                            ],                            "performer": "",                            "previousProcess": {                                "@id": "#process/139800002979824"                            }                        },                        {                            "@id": "#process/139800002981456",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003894048"                            },                            "inputs": [                                {                                    "@id": "#data/rawspectraldatafile-139800002961520"                                }                            ],                            "name": "data_transformation_XOM2",                            "nextProcess": {                                "@id": "#process/139800002981504"                            },                            "outputs": [                                {                                    "@id": "#data/normalizationname-139800002961616"                                },                                {                                    "@id": "#data/derivedspectraldatafile-139800002961568"                                }                            ],                            "parameterValues": [],                            "performer": "",                            "previousProcess": {                                "@id": "#process/139800002981408"                            }                        },                        {                            "@id": "#process/139800002981504",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003893904"                            },                            "inputs": [                                {                                    "@id": "#data/normalizationname-139800002961616"                                }                            ],                            "name": "metabolite_identification_XOM2",                            "outputs": [                                {                                    "@id": "#data/datatransformationname-139800002961760"                                },                                {                                    "@id": "#data/metaboliteassignmentfile-139800002961904"                                }                            ],                            "parameterValues": [],                            "performer": "",                            "previousProcess": {                                "@id": "#process/139800002981456"                            }                        },                        {                            "@id": "#process/139800002986384",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003740624"                            },                            "inputs": [                                {                                    "@id": "#sample/139800003604592"                                }                            ],                            "name": "",                            "nextProcess": {                                "@id": "#process/139800002986528"                            },                            "outputs": [                                {                                    "@id": "#material/extract-139800002986288"                                }                            ],                            "parameterValues": [                                {                                    "category": {                                        "@id": "#139800002981744"                                    },                                    "value": "1 uL filtered urine"                                },                                {                                    "category": {                                        "@id": "#139800002986192"                                    },                                    "value": "NA"                                }                            ],                            "performer": ""                        },                        {                            "@id": "#process/139800002986528",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003893328"                            },                            "inputs": [                                {                                    "@id": "#material/extract-139800002986288"                                }                            ],                            "name": "",                            "nextProcess": {                                "@id": "#process/139800002987440"                            },                            "outputs": [                                {                                    "@id": "#material/labledextract-139800002986432"                                }                            ],                            "parameterValues": [],                            "performer": "",                            "previousProcess": {                                "@id": "#process/139800002986384"                            }                        },                        {                            "@id": "#process/139800002987440",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003892176"                            },                            "inputs": [                                {                                    "@id": "#material/labledextract-139800002986432"                                }                            ],                            "name": "chromatography_XOM3",                            "nextProcess": {                                "@id": "#process/139800002988976"                            },                            "outputs": [],                            "parameterValues": [                                {                                    "category": {                                        "@id": "#139800002986768"                                    },                                    "value": "Agilent 1290"                                },                                {                                    "category": {                                        "@id": "#139800002987056"                                    },                                    "value": "Acquity UPLC CSH C18 column (Waters)"                                },                                {                                    "category": {                                        "@id": "#139800002987344"                                    },                                    "value": "reverse phase"                                }                            ],                            "performer": "",                            "previousProcess": {                                "@id": "#process/139800002986528"                            }                        },                        {                            "@id": "#process/139800002988976",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003786688"                            },                            "inputs": [],                            "name": "mass_spectrometry_XOM3",                            "nextProcess": {                                "@id": "#process/139800002989024"                            },                            "outputs": [                                {                                    "@id": "#data/rawspectraldatafile-139800002961520"                                }                            ],                            "parameterValues": [                                {                                    "category": {                                        "@id": "#139800002987680"                                    },                                    "value": "switching positive and negative ion mode !! MAYBE SERPARATE INTO NEGATIVE AND POSITIVE ASSAY?"                                },                                {                                    "category": {                                        "@id": "#139800002987968"                                    },                                    "value": "5-3000?"                                },                                {                                    "category": {                                        "@id": "#139800002988256"                                    },                                    "value": "Agilent 6460"                                },                                {                                    "category": {                                        "@id": "#139800002988544"                                    },                                    "value": "ESI"                                },                                {                                    "category": {                                        "@id": "#139800002988832"                                    },                                    "value": "triple quadrupole"                                }                            ],                            "performer": "",                            "previousProcess": {                                "@id": "#process/139800002987440"                            }                        },                        {                            "@id": "#process/139800002989024",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003894048"                            },                            "inputs": [                                {                                    "@id": "#data/rawspectraldatafile-139800002961520"                                }                            ],                            "name": "data_transformation_XOM3",                            "nextProcess": {                                "@id": "#process/139800002989072"                            },                            "outputs": [                                {                                    "@id": "#data/normalizationname-139800002961616"                                },                                {                                    "@id": "#data/derivedspectraldatafile-139800002961568"                                }                            ],                            "parameterValues": [],                            "performer": "",                            "previousProcess": {                                "@id": "#process/139800002988976"                            }                        },                        {                            "@id": "#process/139800002989072",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003893904"                            },                            "inputs": [                                {                                    "@id": "#data/normalizationname-139800002961616"                                }                            ],                            "name": "metabolite_identification_XOM3",                            "outputs": [                                {                                    "@id": "#data/datatransformationname-139800002961760"                                },                                {                                    "@id": "#data/metaboliteassignmentfile-139800002961904"                                }                            ],                            "parameterValues": [],                            "performer": "",                            "previousProcess": {                                "@id": "#process/139800002989024"                            }                        },                        {                            "@id": "#process/139800002989792",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003740624"                            },                            "inputs": [                                {                                    "@id": "#sample/139800003606704"                                }                            ],                            "name": "",                            "nextProcess": {                                "@id": "#process/139800002989936"                            },                            "outputs": [                                {                                    "@id": "#material/extract-139800002989696"                                }                            ],                            "parameterValues": [                                {                                    "category": {                                        "@id": "#139800002989312"                                    },                                    "value": "1 uL filtered urine"                                },                                {                                    "category": {                                        "@id": "#139800002989600"                                    },                                    "value": "NA"                                }                            ],                            "performer": ""                        },                        {                            "@id": "#process/139800002989936",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003893328"                            },                            "inputs": [                                {                                    "@id": "#material/extract-139800002989696"                                }                            ],                            "name": "",                            "nextProcess": {                                "@id": "#process/139800003003104"                            },                            "outputs": [                                {                                    "@id": "#material/labledextract-139800002989840"                                }                            ],                            "parameterValues": [],                            "performer": "",                            "previousProcess": {                                "@id": "#process/139800002989792"                            }                        },                        {                            "@id": "#process/139800003003104",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003892176"                            },                            "inputs": [                                {                                    "@id": "#material/labledextract-139800002989840"                                }                            ],                            "name": "chromatography_XOM4",                            "nextProcess": {                                "@id": "#process/139800003004640"                            },                            "outputs": [],                            "parameterValues": [                                {                                    "category": {                                        "@id": "#139800002981120"                                    },                                    "value": "Agilent 1290"                                },                                {                                    "category": {                                        "@id": "#139800003002720"                                    },                                    "value": "Acquity UPLC CSH C18 column (Waters)"                                },                                {                                    "category": {                                        "@id": "#139800003003008"                                    },                                    "value": "reverse phase"                                }                            ],                            "performer": "",                            "previousProcess": {                                "@id": "#process/139800002989936"                            }                        },                        {                            "@id": "#process/139800003004640",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003786688"                            },                            "inputs": [],                            "name": "mass_spectrometry_XOM4",                            "nextProcess": {                                "@id": "#process/139800003004688"                            },                            "outputs": [                                {                                    "@id": "#data/rawspectraldatafile-139800002961520"                                }                            ],                            "parameterValues": [                                {                                    "category": {                                        "@id": "#139800003003344"                                    },                                    "value": "switching positive and negative ion mode !! MAYBE SERPARATE INTO NEGATIVE AND POSITIVE ASSAY?"                                },                                {                                    "category": {                                        "@id": "#139800003003632"                                    },                                    "value": "5-3000?"                                },                                {                                    "category": {                                        "@id": "#139800003003920"                                    },                                    "value": "Agilent 6460"                                },                                {                                    "category": {                                        "@id": "#139800003004208"                                    },                                    "value": "ESI"                                },                                {                                    "category": {                                        "@id": "#139800003004496"                                    },                                    "value": "triple quadrupole"                                }                            ],                            "performer": "",                            "previousProcess": {                                "@id": "#process/139800003003104"                            }                        },                        {                            "@id": "#process/139800003004688",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003894048"                            },                            "inputs": [                                {                                    "@id": "#data/rawspectraldatafile-139800002961520"                                }                            ],                            "name": "data_transformation_XOM4",                            "nextProcess": {                                "@id": "#process/139800003004736"                            },                            "outputs": [                                {                                    "@id": "#data/normalizationname-139800002961616"                                },                                {                                    "@id": "#data/derivedspectraldatafile-139800002961568"                                }                            ],                            "parameterValues": [],                            "performer": "",                            "previousProcess": {                                "@id": "#process/139800003004640"                            }                        },                        {                            "@id": "#process/139800003004736",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003893904"                            },                            "inputs": [                                {                                    "@id": "#data/normalizationname-139800002961616"                                }                            ],                            "name": "metabolite_identification_XOM4",                            "outputs": [                                {                                    "@id": "#data/datatransformationname-139800002961760"                                },                                {                                    "@id": "#data/metaboliteassignmentfile-139800002961904"                                }                            ],                            "parameterValues": [],                            "performer": "",                            "previousProcess": {                                "@id": "#process/139800003004688"                            }                        },                        {                            "@id": "#process/139800003005456",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003740624"                            },                            "inputs": [                                {                                    "@id": "#sample/139800003600640"                                }                            ],                            "name": "",                            "nextProcess": {                                "@id": "#process/139800003005600"                            },                            "outputs": [                                {                                    "@id": "#material/extract-139800003005360"                                }                            ],                            "parameterValues": [                                {                                    "category": {                                        "@id": "#139800003004976"                                    },                                    "value": "1 uL filtered urine"                                },                                {                                    "category": {                                        "@id": "#139800003005264"                                    },                                    "value": "NA"                                }                            ],                            "performer": ""                        },                        {                            "@id": "#process/139800003005600",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003893328"                            },                            "inputs": [                                {                                    "@id": "#material/extract-139800003005360"                                }                            ],                            "name": "",                            "nextProcess": {                                "@id": "#process/139800003014768"                            },                            "outputs": [                                {                                    "@id": "#material/labledextract-139800003005504"                                }                            ],                            "parameterValues": [],                            "performer": "",                            "previousProcess": {                                "@id": "#process/139800003005456"                            }                        },                        {                            "@id": "#process/139800003014768",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003892176"                            },                            "inputs": [                                {                                    "@id": "#material/labledextract-139800003005504"                                }                            ],                            "name": "chromatography_XOM5",                            "nextProcess": {                                "@id": "#process/139800003016496"                            },                            "outputs": [],                            "parameterValues": [                                {                                    "category": {                                        "@id": "#139800003005840"                                    },                                    "value": "Agilent 1290"                                },                                {                                    "category": {                                        "@id": "#139800003006128"                                    },                                    "value": "Acquity UPLC CSH C18 column (Waters)"                                },                                {                                    "category": {                                        "@id": "#139800003006416"                                    },                                    "value": "reverse phase"                                }                            ],                            "performer": "",                            "previousProcess": {                                "@id": "#process/139800003005600"                            }                        },                        {                            "@id": "#process/139800003016496",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003786688"                            },                            "inputs": [],                            "name": "mass_spectrometry_XOM5",                            "nextProcess": {                                "@id": "#process/139800003016544"                            },                            "outputs": [                                {                                    "@id": "#data/rawspectraldatafile-139800002961520"                                }                            ],                            "parameterValues": [                                {                                    "category": {                                        "@id": "#139800003015008"                                    },                                    "value": "switching positive and negative ion mode !! MAYBE SERPARATE INTO NEGATIVE AND POSITIVE ASSAY?"                                },                                {                                    "category": {                                        "@id": "#139800003015296"                                    },                                    "value": "5-3000?"                                },                                {                                    "category": {                                        "@id": "#139800003015584"                                    },                                    "value": "Agilent 6460"                                },                                {                                    "category": {                                        "@id": "#139800003015968"                                    },                                    "value": "ESI"                                },                                {                                    "category": {                                        "@id": "#139800003016400"                                    },                                    "value": "triple quadrupole"                                }                            ],                            "performer": "",                            "previousProcess": {                                "@id": "#process/139800003014768"                            }                        },                        {                            "@id": "#process/139800003016544",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003894048"                            },                            "inputs": [                                {                                    "@id": "#data/rawspectraldatafile-139800002961520"                                }                            ],                            "name": "data_transformation_XOM5",                            "nextProcess": {                                "@id": "#process/139800003016592"                            },                            "outputs": [                                {                                    "@id": "#data/normalizationname-139800002961616"                                },                                {                                    "@id": "#data/derivedspectraldatafile-139800002961568"                                }                            ],                            "parameterValues": [],                            "performer": "",                            "previousProcess": {                                "@id": "#process/139800003016496"                            }                        },                        {                            "@id": "#process/139800003016592",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003893904"                            },                            "inputs": [                                {                                    "@id": "#data/normalizationname-139800002961616"                                }                            ],                            "name": "metabolite_identification_XOM5",                            "outputs": [                                {                                    "@id": "#data/datatransformationname-139800002961760"                                },                                {                                    "@id": "#data/metaboliteassignmentfile-139800002961904"                                }                            ],                            "parameterValues": [],                            "performer": "",                            "previousProcess": {                                "@id": "#process/139800003016544"                            }                        },                        {                            "@id": "#process/139800003017216",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003740624"                            },                            "inputs": [                                {                                    "@id": "#sample/139800003600592"                                }                            ],                            "name": "",                            "nextProcess": {                                "@id": "#process/139800003017360"                            },                            "outputs": [                                {                                    "@id": "#material/extract-139800003017120"                                }                            ],                            "parameterValues": [                                {                                    "category": {                                        "@id": "#139800003016784"                                    },                                    "value": "1 uL filtered urine"                                },                                {                                    "category": {                                        "@id": "#139800003017024"                                    },                                    "value": "NA"                                }                            ],                            "performer": ""                        },                        {                            "@id": "#process/139800003017360",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003893328"                            },                            "inputs": [                                {                                    "@id": "#material/extract-139800003017120"                                }                            ],                            "name": "",                            "nextProcess": {                                "@id": "#process/139800003018368"                            },                            "outputs": [                                {                                    "@id": "#material/labledextract-139800003017264"                                }                            ],                            "parameterValues": [],                            "performer": "",                            "previousProcess": {                                "@id": "#process/139800003017216"                            }                        },                        {                            "@id": "#process/139800003018368",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003892176"                            },                            "inputs": [                                {                                    "@id": "#material/labledextract-139800003017264"                                }                            ],                            "name": "chromatography_XOM6",                            "nextProcess": {                                "@id": "#process/139800003036208"                            },                            "outputs": [],                            "parameterValues": [                                {                                    "category": {                                        "@id": "#139800003017648"                                    },                                    "value": "Agilent 1290"                                },                                {                                    "category": {                                        "@id": "#139800003017888"                                    },                                    "value": "Acquity UPLC CSH C18 column (Waters)"                                },                                {                                    "category": {                                        "@id": "#139800003018272"                                    },                                    "value": "reverse phase"                                }                            ],                            "performer": "",                            "previousProcess": {                                "@id": "#process/139800003017360"                            }                        },                        {                            "@id": "#process/139800003036208",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003786688"                            },                            "inputs": [],                            "name": "mass_spectrometry_XOM6",                            "nextProcess": {                                "@id": "#process/139800003036304"                            },                            "outputs": [                                {                                    "@id": "#data/rawspectraldatafile-139800002961520"                                }                            ],                            "parameterValues": [                                {                                    "category": {                                        "@id": "#139800003018560"                                    },                                    "value": "switching positive and negative ion mode !! MAYBE SERPARATE INTO NEGATIVE AND POSITIVE ASSAY?"                                },                                {                                    "category": {                                        "@id": "#139800003016160"                                    },                                    "value": "5-3000?"                                },                                {                                    "category": {                                        "@id": "#139800003035440"                                    },                                    "value": "Agilent 6460"                                },                                {                                    "category": {                                        "@id": "#139800003035728"                                    },                                    "value": "ESI"                                },                                {                                    "category": {                                        "@id": "#139800003036016"                                    },                                    "value": "triple quadrupole"                                }                            ],                            "performer": "",                            "previousProcess": {                                "@id": "#process/139800003018368"                            }                        },                        {                            "@id": "#process/139800003036304",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003894048"                            },                            "inputs": [                                {                                    "@id": "#data/rawspectraldatafile-139800002961520"                                }                            ],                            "name": "data_transformation_XOM6",                            "nextProcess": {                                "@id": "#process/139800003036352"                            },                            "outputs": [                                {                                    "@id": "#data/normalizationname-139800002961616"                                },                                {                                    "@id": "#data/derivedspectraldatafile-139800002961568"                                }                            ],                            "parameterValues": [],                            "performer": "",                            "previousProcess": {                                "@id": "#process/139800003036208"                            }                        },                        {                            "@id": "#process/139800003036352",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003893904"                            },                            "inputs": [                                {                                    "@id": "#data/normalizationname-139800002961616"                                }                            ],                            "name": "metabolite_identification_XOM6",                            "outputs": [                                {                                    "@id": "#data/datatransformationname-139800002961760"                                },                                {                                    "@id": "#data/metaboliteassignmentfile-139800002961904"                                }                            ],                            "parameterValues": [],                            "performer": "",                            "previousProcess": {                                "@id": "#process/139800003036304"                            }                        },                        {                            "@id": "#process/139800003037024",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003740624"                            },                            "inputs": [                                {                                    "@id": "#sample/139800003617216"                                }                            ],                            "name": "",                            "nextProcess": {                                "@id": "#process/139800003037168"                            },                            "outputs": [                                {                                    "@id": "#material/extract-139800003036976"                                }                            ],                            "parameterValues": [                                {                                    "category": {                                        "@id": "#139800003036592"                                    },                                    "value": "1 uL filtered urine"                                },                                {                                    "category": {                                        "@id": "#139800003036880"                                    },                                    "value": "NA"                                }                            ],                            "performer": ""                        },                        {                            "@id": "#process/139800003037168",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003893328"                            },                            "inputs": [                                {                                    "@id": "#material/extract-139800003036976"                                }                            ],                            "name": "",                            "nextProcess": {                                "@id": "#process/139800003038080"                            },                            "outputs": [                                {                                    "@id": "#material/labledextract-139800003037072"                                }                            ],                            "parameterValues": [],                            "performer": "",                            "previousProcess": {                                "@id": "#process/139800003037024"                            }                        },                        {                            "@id": "#process/139800003038080",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003892176"                            },                            "inputs": [                                {                                    "@id": "#material/labledextract-139800003037072"                                }                            ],                            "name": "chromatography_XOM7",                            "nextProcess": {                                "@id": "#process/139800003051968"                            },                            "outputs": [],                            "parameterValues": [                                {                                    "category": {                                        "@id": "#139800003037408"                                    },                                    "value": "Agilent 1290"                                },                                {                                    "category": {                                        "@id": "#139800003037696"                                    },                                    "value": "Acquity UPLC CSH C18 column (Waters)"                                },                                {                                    "category": {                                        "@id": "#139800003037984"                                    },                                    "value": "reverse phase"                                }                            ],                            "performer": "",                            "previousProcess": {                                "@id": "#process/139800003037168"                            }                        },                        {                            "@id": "#process/139800003051968",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003786688"                            },                            "inputs": [],                            "name": "mass_spectrometry_XOM7",                            "nextProcess": {                                "@id": "#process/139800003052016"                            },                            "outputs": [                                {                                    "@id": "#data/rawspectraldatafile-139800002961520"                                }                            ],                            "parameterValues": [                                {                                    "category": {                                        "@id": "#139800003038320"                                    },                                    "value": "switching positive and negative ion mode !! MAYBE SERPARATE INTO NEGATIVE AND POSITIVE ASSAY?"                                },                                {                                    "category": {                                        "@id": "#139800003038560"                                    },                                    "value": "5-3000?"                                },                                {                                    "category": {                                        "@id": "#139800003038848"                                    },                                    "value": "Agilent 6460"                                },                                {                                    "category": {                                        "@id": "#139800003039136"                                    },                                    "value": "ESI"                                },                                {                                    "category": {                                        "@id": "#139800003051824"                                    },                                    "value": "triple quadrupole"                                }                            ],                            "performer": "",                            "previousProcess": {                                "@id": "#process/139800003038080"                            }                        },                        {                            "@id": "#process/139800003052016",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003894048"                            },                            "inputs": [                                {                                    "@id": "#data/rawspectraldatafile-139800002961520"                                }                            ],                            "name": "data_transformation_XOM7",                            "nextProcess": {                                "@id": "#process/139800003052064"                            },                            "outputs": [                                {                                    "@id": "#data/normalizationname-139800002961616"                                },                                {                                    "@id": "#data/derivedspectraldatafile-139800002961568"                                }                            ],                            "parameterValues": [],                            "performer": "",                            "previousProcess": {                                "@id": "#process/139800003051968"                            }                        },                        {                            "@id": "#process/139800003052064",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003893904"                            },                            "inputs": [                                {                                    "@id": "#data/normalizationname-139800002961616"                                }                            ],                            "name": "metabolite_identification_XOM7",                            "outputs": [                                {                                    "@id": "#data/datatransformationname-139800002961760"                                },                                {                                    "@id": "#data/metaboliteassignmentfile-139800002961904"                                }                            ],                            "parameterValues": [],                            "performer": "",                            "previousProcess": {                                "@id": "#process/139800003052016"                            }                        },                        {                            "@id": "#process/139800003052736",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003740624"                            },                            "inputs": [                                {                                    "@id": "#sample/139800003617120"                                }                            ],                            "name": "",                            "nextProcess": {                                "@id": "#process/139800003052928"                            },                            "outputs": [                                {                                    "@id": "#material/extract-139800003052640"                                }                            ],                            "parameterValues": [                                {                                    "category": {                                        "@id": "#139800003052304"                                    },                                    "value": "1 uL filtered urine"                                },                                {                                    "category": {                                        "@id": "#139800003052544"                                    },                                    "value": "NA"                                }                            ],                            "performer": ""                        },                        {                            "@id": "#process/139800003052928",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003893328"                            },                            "inputs": [                                {                                    "@id": "#material/extract-139800003052640"                                }                            ],                            "name": "",                            "nextProcess": {                                "@id": "#process/139800003053120"                            },                            "outputs": [                                {                                    "@id": "#material/labledextract-139800003052784"                                }                            ],                            "parameterValues": [],                            "performer": "",                            "previousProcess": {                                "@id": "#process/139800003052736"                            }                        },                        {                            "@id": "#process/139800003053120",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003892176"                            },                            "inputs": [                                {                                    "@id": "#material/labledextract-139800003052784"                                }                            ],                            "name": "chromatography_XOM8",                            "nextProcess": {                                "@id": "#process/139800003055568"                            },                            "outputs": [],                            "parameterValues": [                                {                                    "category": {                                        "@id": "#139800003053312"                                    },                                    "value": "Agilent 1290"                                },                                {                                    "category": {                                        "@id": "#139800003053600"                                    },                                    "value": "Acquity UPLC CSH C18 column (Waters)"                                },                                {                                    "category": {                                        "@id": "#139800003052976"                                    },                                    "value": "reverse phase"                                }                            ],                            "performer": "",                            "previousProcess": {                                "@id": "#process/139800003052928"                            }                        },                        {                            "@id": "#process/139800003055568",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003786688"                            },                            "inputs": [],                            "name": "mass_spectrometry_XOM8",                            "nextProcess": {                                "@id": "#process/139800003054560"                            },                            "outputs": [                                {                                    "@id": "#data/rawspectraldatafile-139800002961520"                                }                            ],                            "parameterValues": [                                {                                    "category": {                                        "@id": "#139800003054128"                                    },                                    "value": "switching positive and negative ion mode !! MAYBE SERPARATE INTO NEGATIVE AND POSITIVE ASSAY?"                                },                                {                                    "category": {                                        "@id": "#139800003054416"                                    },                                    "value": "5-3000?"                                },                                {                                    "category": {                                        "@id": "#139800003054992"                                    },                                    "value": "Agilent 6460"                                },                                {                                    "category": {                                        "@id": "#139800003055280"                                    },                                    "value": "ESI"                                },                                {                                    "category": {                                        "@id": "#139800003055472"                                    },                                    "value": "triple quadrupole"                                }                            ],                            "performer": "",                            "previousProcess": {                                "@id": "#process/139800003053120"                            }                        },                        {                            "@id": "#process/139800003054560",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003894048"                            },                            "inputs": [                                {                                    "@id": "#data/rawspectraldatafile-139800002961520"                                }                            ],                            "name": "data_transformation_XOM8",                            "nextProcess": {                                "@id": "#process/139800003053024"                            },                            "outputs": [                                {                                    "@id": "#data/normalizationname-139800002961616"                                },                                {                                    "@id": "#data/derivedspectraldatafile-139800002961568"                                }                            ],                            "parameterValues": [],                            "performer": "",                            "previousProcess": {                                "@id": "#process/139800003055568"                            }                        },                        {                            "@id": "#process/139800003053024",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003893904"                            },                            "inputs": [                                {                                    "@id": "#data/normalizationname-139800002961616"                                }                            ],                            "name": "metabolite_identification_XOM8",                            "outputs": [                                {                                    "@id": "#data/datatransformationname-139800002961760"                                },                                {                                    "@id": "#data/metaboliteassignmentfile-139800002961904"                                }                            ],                            "parameterValues": [],                            "performer": "",                            "previousProcess": {                                "@id": "#process/139800003054560"                            }                        },                        {                            "@id": "#process/139800003068496",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003740624"                            },                            "inputs": [                                {                                    "@id": "#sample/139800003646176"                                }                            ],                            "name": "",                            "nextProcess": {                                "@id": "#process/139800003068688"                            },                            "outputs": [                                {                                    "@id": "#material/extract-139800003068400"                                }                            ],                            "parameterValues": [                                {                                    "category": {                                        "@id": "#139800003054752"                                    },                                    "value": "1 uL filtered urine"                                },                                {                                    "category": {                                        "@id": "#139800003068304"                                    },                                    "value": "NA"                                }                            ],                            "performer": ""                        },                        {                            "@id": "#process/139800003068688",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003893328"                            },                            "inputs": [                                {                                    "@id": "#material/extract-139800003068400"                                }                            ],                            "name": "",                            "nextProcess": {                                "@id": "#process/139800003069600"                            },                            "outputs": [                                {                                    "@id": "#material/labledextract-139800003068544"                                }                            ],                            "parameterValues": [],                            "performer": "",                            "previousProcess": {                                "@id": "#process/139800003068496"                            }                        },                        {                            "@id": "#process/139800003069600",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003892176"                            },                            "inputs": [                                {                                    "@id": "#material/labledextract-139800003068544"                                }                            ],                            "name": "chromatography_XOM9",                            "nextProcess": {                                "@id": "#process/139800003071232"                            },                            "outputs": [],                            "parameterValues": [                                {                                    "category": {                                        "@id": "#139800003068976"                                    },                                    "value": "Agilent 1290"                                },                                {                                    "category": {                                        "@id": "#139800003069216"                                    },                                    "value": "Acquity UPLC CSH C18 column (Waters)"                                },                                {                                    "category": {                                        "@id": "#139800003068736"                                    },                                    "value": "reverse phase"                                }                            ],                            "performer": "",                            "previousProcess": {                                "@id": "#process/139800003068688"                            }                        },                        {                            "@id": "#process/139800003071232",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003786688"                            },                            "inputs": [],                            "name": "mass_spectrometry_XOM9",                            "nextProcess": {                                "@id": "#process/139800003071280"                            },                            "outputs": [                                {                                    "@id": "#data/rawspectraldatafile-139800002961520"                                }                            ],                            "parameterValues": [                                {                                    "category": {                                        "@id": "#139800003069840"                                    },                                    "value": "switching positive and negative ion mode !! MAYBE SERPARATE INTO NEGATIVE AND POSITIVE ASSAY?"                                },                                {                                    "category": {                                        "@id": "#139800003070080"                                    },                                    "value": "5-3000?"                                },                                {                                    "category": {                                        "@id": "#139800003070368"                                    },                                    "value": "Agilent 6460"                                },                                {                                    "category": {                                        "@id": "#139800003070704"                                    },                                    "value": "ESI"                                },                                {                                    "category": {                                        "@id": "#139800003071088"                                    },                                    "value": "triple quadrupole"                                }                            ],                            "performer": "",                            "previousProcess": {                                "@id": "#process/139800003069600"                            }                        },                        {                            "@id": "#process/139800003071280",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003894048"                            },                            "inputs": [                                {                                    "@id": "#data/rawspectraldatafile-139800002961520"                                }                            ],                            "name": "data_transformation_XOM9",                            "nextProcess": {                                "@id": "#process/139800003071328"                            },                            "outputs": [                                {                                    "@id": "#data/normalizationname-139800002961616"                                },                                {                                    "@id": "#data/derivedspectraldatafile-139800002961568"                                }                            ],                            "parameterValues": [],                            "performer": "",                            "previousProcess": {                                "@id": "#process/139800003071232"                            }                        },                        {                            "@id": "#process/139800003071328",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003893904"                            },                            "inputs": [                                {                                    "@id": "#data/normalizationname-139800002961616"                                }                            ],                            "name": "metabolite_identification_XOM9",                            "outputs": [                                {                                    "@id": "#data/datatransformationname-139800002961760"                                },                                {                                    "@id": "#data/metaboliteassignmentfile-139800002961904"                                }                            ],                            "parameterValues": [],                            "performer": "",                            "previousProcess": {                                "@id": "#process/139800003071280"                            }                        },                        {                            "@id": "#process/139800003071904",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003740624"                            },                            "inputs": [                                {                                    "@id": "#sample/139800003646080"                                }                            ],                            "name": "",                            "nextProcess": {                                "@id": "#process/139800003088496"                            },                            "outputs": [                                {                                    "@id": "#material/extract-139800003071808"                                }                            ],                            "parameterValues": [                                {                                    "category": {                                        "@id": "#139800003071520"                                    },                                    "value": "1 uL filtered urine"                                },                                {                                    "category": {                                        "@id": "#139800003071760"                                    },                                    "value": "NA"                                }                            ],                            "performer": ""                        },                        {                            "@id": "#process/139800003088496",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003893328"                            },                            "inputs": [                                {                                    "@id": "#material/extract-139800003071808"                                }                            ],                            "name": "",                            "nextProcess": {                                "@id": "#process/139800003089408"                            },                            "outputs": [                                {                                    "@id": "#material/labledextract-139800003071952"                                }                            ],                            "parameterValues": [],                            "performer": "",                            "previousProcess": {                                "@id": "#process/139800003071904"                            }                        },                        {                            "@id": "#process/139800003089408",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003892176"                            },                            "inputs": [                                {                                    "@id": "#material/labledextract-139800003071952"                                }                            ],                            "name": "chromatography_XOM10",                            "nextProcess": {                                "@id": "#process/139800003090944"                            },                            "outputs": [],                            "parameterValues": [                                {                                    "category": {                                        "@id": "#139800003088736"                                    },                                    "value": "Agilent 1290"                                },                                {                                    "category": {                                        "@id": "#139800003089024"                                    },                                    "value": "Acquity UPLC CSH C18 column (Waters)"                                },                                {                                    "category": {                                        "@id": "#139800003089312"                                    },                                    "value": "reverse phase"                                }                            ],                            "performer": "",                            "previousProcess": {                                "@id": "#process/139800003088496"                            }                        },                        {                            "@id": "#process/139800003090944",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003786688"                            },                            "inputs": [],                            "name": "mass_spectrometry_XOM10",                            "nextProcess": {                                "@id": "#process/139800003090992"                            },                            "outputs": [                                {                                    "@id": "#data/rawspectraldatafile-139800002961520"                                }                            ],                            "parameterValues": [                                {                                    "category": {                                        "@id": "#139800003089648"                                    },                                    "value": "switching positive and negative ion mode !! MAYBE SERPARATE INTO NEGATIVE AND POSITIVE ASSAY?"                                },                                {                                    "category": {                                        "@id": "#139800003089936"                                    },                                    "value": "5-3000?"                                },                                {                                    "category": {                                        "@id": "#139800003090224"                                    },                                    "value": "Agilent 6460"                                },                                {                                    "category": {                                        "@id": "#139800003090512"                                    },                                    "value": "ESI"                                },                                {                                    "category": {                                        "@id": "#139800003090800"                                    },                                    "value": "triple quadrupole"                                }                            ],                            "performer": "",                            "previousProcess": {                                "@id": "#process/139800003089408"                            }                        },                        {                            "@id": "#process/139800003090992",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003894048"                            },                            "inputs": [                                {                                    "@id": "#data/rawspectraldatafile-139800002961520"                                }                            ],                            "name": "data_transformation_XOM10",                            "nextProcess": {                                "@id": "#process/139800003091040"                            },                            "outputs": [                                {                                    "@id": "#data/normalizationname-139800002961616"                                },                                {                                    "@id": "#data/derivedspectraldatafile-139800002961568"                                }                            ],                            "parameterValues": [],                            "performer": "",                            "previousProcess": {                                "@id": "#process/139800003090944"                            }                        },                        {                            "@id": "#process/139800003091040",                            "comments": [],                            "date": "",                            "executesProtocol": {                                "@id": "#139800003893904"                            },                            "inputs": [                                {                                    "@id": "#data/normalizationname-139800002961616"                                }                            ],                            "name": "metabolite_identification_XOM10",                            "outputs": [                                {                                    "@id": "#data/datatransformationname-139800002961760"                                },                                {                                    "@id": "#data/metaboliteassignmentfile-139800002961904"                                }                            ],                            "parameterValues": [],                            "performer": "",                            "previousProcess": {                                "@id": "#process/139800003090992"                            }                        }                    ],                    "technologyPlatform": "",                    "technologyType": {                        "@id": "#f9891456-b39c-4e38-a67a-fb0f923aa8a4",                        "annotationValue": "high-performance liquid chromatography-mass spectrometry",                        "comments": [],                        "termAccession": "http://purl.obolibrary.org/obo/CHMO_0000796",                        "termSource": "CHMO"                    },                    "unitCategories": []                }            ],            "characteristicCategories": [],            "comments": [],            "description": "",            "factors": [],            "filename": "s_study.txt",            "identifier": "tbd",            "materials": {                "otherMaterials": [],                "samples": [                    {                        "@id": "#sample/139800003550704",                        "characteristics": [                            {                                "category": {                                    "@id": "#196b3e41-5a75-439f-aacd-06b46d06be25"                                },                                "value": {                                    "@id": "#b4c7521a-9349-41b2-926e-f37c8d272824",                                    "annotationValue": "urine",                                    "comments": [],                                    "termAccession": "http://purl.obolibrary.org/obo/UBERON_0001088",                                    "termSource": "UBERON"                                }                            },                            {                                "category": {                                    "@id": "#9c885ee6-527b-4b1f-868d-b63b2c3c186b"                                },                                "value": {                                    "@id": "#6de4f95f-fa62-4cbb-9d7d-0613ddfa140f",                                    "annotationValue": "experimental sample",                                    "comments": [],                                    "termAccession": "http://purl.obolibrary.org/obo/CHMO_0002746",                                    "termSource": "CHMO"                                }                            }                        ],                        "factorValues": [],                        "name": "urine_XOP1"                    },                    {                        "@id": "#sample/139800003580448",                        "characteristics": [                            {                                "category": {                                    "@id": "#4cdf9dbd-6ddd-41e8-8422-9804584b2e60"                                },                                "value": {                                    "@id": "#df6021ba-810a-481e-a1fe-f9984f6fb114",                                    "annotationValue": "buccal mucosa",                                    "comments": [],                                    "termAccession": "http://purl.obolibrary.org/obo/UBERON_0006956",                                    "termSource": "UBERON"                                }                            }                        ],                        "factorValues": [],                        "name": "buccal_mucosa_XOP1"                    },                    {                        "@id": "#sample/139800003581792",                        "characteristics": [                            {                                "category": {                                    "@id": "#7f429d01-61c1-4d86-9942-d90b366be47c"                                },                                "value": {                                    "@id": "#850e1951-47c2-400e-947f-fd5cbe7c54a6",                                    "annotationValue": "urine",                                    "comments": [],                                    "termAccession": "http://purl.obolibrary.org/obo/UBERON_0001088",                                    "termSource": "UBERON"                                }                            },                            {                                "category": {                                    "@id": "#43caf586-7aae-4dc7-998e-6a20aef00875"                                },                                "value": {                                    "@id": "#4c4f5e89-8f99-4f6c-98b4-e5420d666080",                                    "annotationValue": "experimental sample",                                    "comments": [],                                    "termAccession": "http://purl.obolibrary.org/obo/CHMO_0002746",                                    "termSource": "CHMO"                                }                            }                        ],                        "factorValues": [],                        "name": "urine_XOP2"                    },                    {                        "@id": "#sample/139800003582704",                        "characteristics": [                            {                                "category": {                                    "@id": "#622b879f-a6f6-4546-b5e6-38b1e1694851"                                },                                "value": {                                    "@id": "#4f6b004d-7ec2-4f85-a574-1bbab3ca9bf1",                                    "annotationValue": "buccal mucosa",                                    "comments": [],                                    "termAccession": "http://purl.obolibrary.org/obo/UBERON_0006956",                                    "termSource": "UBERON"                                }                            }                        ],                        "factorValues": [],                        "name": "buccal_mucosa_XOP2"                    },                    {                        "@id": "#sample/139800003604592",                        "characteristics": [                            {                                "category": {                                    "@id": "#4720eed4-9af5-4fd5-9fb4-a750508187c0"                                },                                "value": {                                    "@id": "#a9ddbe6d-2102-4c3c-8214-f4eb1e91438b",                                    "annotationValue": "urine",                                    "comments": [],                                    "termAccession": "http://purl.obolibrary.org/obo/UBERON_0001088",                                    "termSource": "UBERON"                                }                            },                            {                                "category": {                                    "@id": "#d48be27a-c378-4f7c-b514-7b8439140fbc"                                },                                "value": {                                    "@id": "#910ea8e4-77ff-46be-acac-4dd1315d83f7",                                    "annotationValue": "experimental sample",                                    "comments": [],                                    "termAccession": "http://purl.obolibrary.org/obo/CHMO_0002746",                                    "termSource": "CHMO"                                }                            }                        ],                        "factorValues": [],                        "name": "urine_XOP3"                    },                    {                        "@id": "#sample/139800003605312",                        "characteristics": [                            {                                "category": {                                    "@id": "#bebea860-02de-4cba-b897-c2eadb2fdb99"                                },                                "value": {                                    "@id": "#45d141a7-47f3-4fd5-9f5c-dfe0a30cf577",                                    "annotationValue": "buccal mucosa",                                    "comments": [],                                    "termAccession": "http://purl.obolibrary.org/obo/UBERON_0006956",                                    "termSource": "UBERON"                                }                            }                        ],                        "factorValues": [],                        "name": "buccal_mucosa_XOP3"                    },                    {                        "@id": "#sample/139800003606704",                        "characteristics": [                            {                                "category": {                                    "@id": "#2e697ec4-4d72-4b76-95d1-061fbc7269f3"                                },                                "value": {                                    "@id": "#ebe6698f-ec4d-440b-9aa7-e75e0a45ffce",                                    "annotationValue": "urine",                                    "comments": [],                                    "termAccession": "http://purl.obolibrary.org/obo/UBERON_0001088",                                    "termSource": "UBERON"                                }                            },                            {                                "category": {                                    "@id": "#4f140a54-71da-46d7-94dd-9a846f7961cd"                                },                                "value": {                                    "@id": "#4a1eda5e-2e99-4295-9c27-3f95939d6ae0",                                    "annotationValue": "experimental sample",                                    "comments": [],                                    "termAccession": "http://purl.obolibrary.org/obo/CHMO_0002746",                                    "termSource": "CHMO"                                }                            }                        ],                        "factorValues": [],                        "name": "urine_XOP4"                    },                    {                        "@id": "#sample/139800003607424",                        "characteristics": [                            {                                "category": {                                    "@id": "#ecae4233-47e2-4182-b15f-410ebc700c39"                                },                                "value": {                                    "@id": "#dff5b7d1-2a60-4e5c-98df-caffc23c07f9",                                    "annotationValue": "buccal mucosa",                                    "comments": [],                                    "termAccession": "http://purl.obolibrary.org/obo/UBERON_0006956",                                    "termSource": "UBERON"                                }                            }                        ],                        "factorValues": [],                        "name": "buccal_mucosa_XOP4"                    },                    {                        "@id": "#sample/139800003600640",                        "characteristics": [                            {                                "category": {                                    "@id": "#64eebdc9-433a-4ce0-a07c-490b3e97427c"                                },                                "value": {                                    "@id": "#abc046b0-091c-4326-85ca-95f13ec34337",                                    "annotationValue": "urine",                                    "comments": [],                                    "termAccession": "http://purl.obolibrary.org/obo/UBERON_0001088",                                    "termSource": "UBERON"                                }                            },                            {                                "category": {                                    "@id": "#bfd93452-d295-474a-9fd5-73a9328fb35c"                                },                                "value": {                                    "@id": "#1dca670a-c7b0-48b1-b5a0-30d48bdda1bb",                                    "annotationValue": "experimental sample",                                    "comments": [],                                    "termAccession": "http://purl.obolibrary.org/obo/CHMO_0002746",                                    "termSource": "CHMO"                                }                            }                        ],                        "factorValues": [],                        "name": "urine_XOP5"                    },                    {                        "@id": "#sample/139800003601504",                        "characteristics": [                            {                                "category": {                                    "@id": "#3b527ffa-7ec4-4783-99f4-6c736f285e89"                                },                                "value": {                                    "@id": "#088f1932-b09d-462d-bd54-2878d3ddedc7",                                    "annotationValue": "buccal mucosa",                                    "comments": [],                                    "termAccession": "http://purl.obolibrary.org/obo/UBERON_0006956",                                    "termSource": "UBERON"                                }                            }                        ],                        "factorValues": [],                        "name": "buccal_mucosa_XOP5"                    },                    {                        "@id": "#sample/139800003600592",                        "characteristics": [                            {                                "category": {                                    "@id": "#768a76a7-4463-4937-a4de-857164e5fff3"                                },                                "value": {                                    "@id": "#44da0995-dc29-49aa-b8c6-1771ff1b4983",                                    "annotationValue": "urine",                                    "comments": [],                                    "termAccession": "http://purl.obolibrary.org/obo/UBERON_0001088",                                    "termSource": "UBERON"                                }                            },                            {                                "category": {                                    "@id": "#62204b82-d75c-49f3-b7db-a86c7daa395b"                                },                                "value": {                                    "@id": "#7eff269c-7c87-46b6-82c5-af425e533f5c",                                    "annotationValue": "experimental sample",                                    "comments": [],                                    "termAccession": "http://purl.obolibrary.org/obo/CHMO_0002746",                                    "termSource": "CHMO"                                }                            }                        ],                        "factorValues": [],                        "name": "urine_XOP6"                    },                    {                        "@id": "#sample/139800003603664",                        "characteristics": [                            {                                "category": {                                    "@id": "#621b4f20-bce3-4e80-af92-d848423d8cdc"                                },                                "value": {                                    "@id": "#01906a67-37e9-48a2-8f5a-db2079b27010",                                    "annotationValue": "buccal mucosa",                                    "comments": [],                                    "termAccession": "http://purl.obolibrary.org/obo/UBERON_0006956",                                    "termSource": "UBERON"                                }                            }                        ],                        "factorValues": [],                        "name": "buccal_mucosa_XOP6"                    },                    {                        "@id": "#sample/139800003617216",                        "characteristics": [                            {                                "category": {                                    "@id": "#7342cd89-8093-420d-ae32-20f4c328cb1f"                                },                                "value": {                                    "@id": "#3a2f1236-f52c-4cde-b885-8a49f8bd945f",                                    "annotationValue": "urine",                                    "comments": [],                                    "termAccession": "http://purl.obolibrary.org/obo/UBERON_0001088",                                    "termSource": "UBERON"                                }                            },                            {                                "category": {                                    "@id": "#3f136fcd-9b03-4296-a2fa-3cfd961d2041"                                },                                "value": {                                    "@id": "#c9983013-a289-41b0-a535-ac36b5ed66ec",                                    "annotationValue": "experimental sample",                                    "comments": [],                                    "termAccession": "http://purl.obolibrary.org/obo/CHMO_0002746",                                    "termSource": "CHMO"                                }                            }                        ],                        "factorValues": [],                        "name": "urine_XOP7"                    },                    {                        "@id": "#sample/139800003618080",                        "characteristics": [                            {                                "category": {                                    "@id": "#dca4e9b6-1a46-4458-926c-13870b8912c0"                                },                                "value": {                                    "@id": "#65ef2bcc-f46f-4d76-8bb5-b843d24bf11d",                                    "annotationValue": "buccal mucosa",                                    "comments": [],                                    "termAccession": "http://purl.obolibrary.org/obo/UBERON_0006956",                                    "termSource": "UBERON"                                }                            }                        ],                        "factorValues": [],                        "name": "buccal_mucosa_XOP7"                    },                    {                        "@id": "#sample/139800003617120",                        "characteristics": [                            {                                "category": {                                    "@id": "#4ae1915a-7cf4-487e-abeb-e0378a0f881b"                                },                                "value": {                                    "@id": "#1be733cf-5686-46bc-9468-08af1adb0265",                                    "annotationValue": "urine",                                    "comments": [],                                    "termAccession": "http://purl.obolibrary.org/obo/UBERON_0001088",                                    "termSource": "UBERON"                                }                            },                            {                                "category": {                                    "@id": "#f85fcc53-0e49-4430-90b8-a32e79ad12ed"                                },                                "value": {                                    "@id": "#43d8b5bc-ffbe-47cc-9702-5f8724f3a832",                                    "annotationValue": "experimental sample",                                    "comments": [],                                    "termAccession": "http://purl.obolibrary.org/obo/CHMO_0002746",                                    "termSource": "CHMO"                                }                            }                        ],                        "factorValues": [],                        "name": "urine_XOP8"                    },                    {                        "@id": "#sample/139800003620240",                        "characteristics": [                            {                                "category": {                                    "@id": "#9a95f993-895f-49de-b555-7ff5b4aec454"                                },                                "value": {                                    "@id": "#d19d8159-634c-43e3-8f78-bb792fdc14ee",                                    "annotationValue": "buccal mucosa",                                    "comments": [],                                    "termAccession": "http://purl.obolibrary.org/obo/UBERON_0006956",                                    "termSource": "UBERON"                                }                            }                        ],                        "factorValues": [],                        "name": "buccal_mucosa_XOP8"                    },                    {                        "@id": "#sample/139800003646176",                        "characteristics": [                            {                                "category": {                                    "@id": "#df3be894-44ea-4f1e-9f38-79bf2811b4ba"                                },                                "value": {                                    "@id": "#8a42510b-d0a2-4b5c-9c77-96b0ab30fbf3",                                    "annotationValue": "urine",                                    "comments": [],                                    "termAccession": "http://purl.obolibrary.org/obo/UBERON_0001088",                                    "termSource": "UBERON"                                }                            },                            {                                "category": {                                    "@id": "#de90c9fc-5316-490d-aa56-c0a5af098e70"                                },                                "value": {                                    "@id": "#73b93652-4208-4191-91fd-bc6b0b521260",                                    "annotationValue": "experimental sample",                                    "comments": [],                                    "termAccession": "http://purl.obolibrary.org/obo/CHMO_0002746",                                    "termSource": "CHMO"                                }                            }                        ],                        "factorValues": [],                        "name": "urine_XOP9"                    },                    {                        "@id": "#sample/139800003647040",                        "characteristics": [                            {                                "category": {                                    "@id": "#758bc0e4-f18c-4739-889c-fa795fed8f6d"                                },                                "value": {                                    "@id": "#55b016d6-340d-42e2-9173-3ce4904ec9fa",                                    "annotationValue": "buccal mucosa",                                    "comments": [],                                    "termAccession": "http://purl.obolibrary.org/obo/UBERON_0006956",                                    "termSource": "UBERON"                                }                            }                        ],                        "factorValues": [],                        "name": "buccal_mucosa_XOP9"                    },                    {                        "@id": "#sample/139800003646080",                        "characteristics": [                            {                                "category": {                                    "@id": "#713c5fa7-ee56-42e5-b084-a5008269ff0c"                                },                                "value": {                                    "@id": "#cf7e8c2e-3b58-46a2-8ed7-1fc3ceff8e30",                                    "annotationValue": "urine",                                    "comments": [],                                    "termAccession": "http://purl.obolibrary.org/obo/UBERON_0001088",                                    "termSource": "UBERON"                                }                            },                            {                                "category": {                                    "@id": "#8e38bdf2-412e-402b-89a6-7483806710b3"                                },                                "value": {                                    "@id": "#b2e45b85-affa-4582-9712-22b704630657",                                    "annotationValue": "experimental sample",                                    "comments": [],                                    "termAccession": "http://purl.obolibrary.org/obo/CHMO_0002746",                                    "termSource": "CHMO"                                }                            }                        ],                        "factorValues": [],                        "name": "urine_XOP10"                    },                    {                        "@id": "#sample/139800003649200",                        "characteristics": [                            {                                "category": {                                    "@id": "#09dae57d-2ce9-4a58-b5b9-8b6744817bae"                                },                                "value": {                                    "@id": "#90a9e7b6-2c7e-4fa2-b27b-d38e695ec170",                                    "annotationValue": "buccal mucosa",                                    "comments": [],                                    "termAccession": "http://purl.obolibrary.org/obo/UBERON_0006956",                                    "termSource": "UBERON"                                }                            }                        ],                        "factorValues": [],                        "name": "buccal_mucosa_XOP10"                    }                ],                "sources": [                    {                        "@id": "#source/139800003549936",                        "characteristics": [                            {                                "category": {                                    "@id": "#f4373160-cc21-4cbf-9380-3cca6e71f617"                                },                                "value": {                                    "@id": "#2e6d8d85-e6f2-4c5c-9dce-4568699c972a",                                    "annotationValue": "Homo sapiens",                                    "comments": [],                                    "termAccession": "http://purl.bioontology.org/ontology/NCBITAXON/9606",                                    "termSource": "NCBITAXON"                                }                            },                            {                                "category": {                                    "@id": "#e32158fb-1dfa-4d29-89bc-1daef7e73489"                                },                                "value": "XOF1"                            },                            {                                "category": {                                    "@id": "#f64eb57d-4ef7-4fb0-8306-28da957bf48f"                                },                                "unit": {                                    "@id": "#3f5439c3-4ef0-4ea9-a633-61e8c51b2157"                                },                                "value": 41.52999346520022                            }                        ],                        "name": "XOP1"                    },                    {                        "@id": "#source/139800003549888",                        "characteristics": [                            {                                "category": {                                    "@id": "#b4039d97-64e3-48f8-a5df-9f2f9f6ee1b3"                                },                                "value": {                                    "@id": "#14885909-e011-4e08-8ddf-7f5be0643f4c",                                    "annotationValue": "Homo sapiens",                                    "comments": [],                                    "termAccession": "http://purl.bioontology.org/ontology/NCBITAXON/9606",                                    "termSource": "NCBITAXON"                                }                            },                            {                                "category": {                                    "@id": "#659f857a-167e-4789-8841-a7da7f0cf290"                                },                                "value": "XOF2"                            },                            {                                "category": {                                    "@id": "#b2130289-cb6f-4373-b4a4-f1bbeea355a7"                                },                                "unit": {                                    "@id": "#64edbd8c-3e79-4ce9-aec9-7b7579b91948"                                },                                "value": 41.52999346520022                            }                        ],                        "name": "XOP2"                    },                    {                        "@id": "#source/139800003580928",                        "characteristics": [                            {                                "category": {                                    "@id": "#23d5a77d-35e1-4e9a-a03c-ceb0f4ce5758"                                },                                "value": {                                    "@id": "#fa3ed785-c2a6-4327-b580-af0aca5362f5",                                    "annotationValue": "Homo sapiens",                                    "comments": [],                                    "termAccession": "http://purl.bioontology.org/ontology/NCBITAXON/9606",                                    "termSource": "NCBITAXON"                                }                            },                            {                                "category": {                                    "@id": "#74fd8d0b-c7e1-4ccc-814f-b7677e061fbc"                                },                                "value": "XOF3"                            },                            {                                "category": {                                    "@id": "#ba1a28b5-80f5-45c1-a25e-6e9876bc49a7"                                },                                "unit": {                                    "@id": "#757db3e6-d1c3-43eb-a011-402435cbf7a5"                                },                                "value": NaN                            }                        ],                        "name": "XOP3"                    },                    {                        "@id": "#source/139800003583136",                        "characteristics": [                            {                                "category": {                                    "@id": "#c0ec5ad3-85e1-48f9-b918-604649617e2f"                                },                                "value": {                                    "@id": "#b291fb52-0cdf-4584-9068-887caff6583b",                                    "annotationValue": "Homo sapiens",                                    "comments": [],                                    "termAccession": "http://purl.bioontology.org/ontology/NCBITAXON/9606",                                    "termSource": "NCBITAXON"                                }                            },                            {                                "category": {                                    "@id": "#c50e6fb2-00ec-4c2d-917f-0012adf1e921"                                },                                "value": "XOF4"                            },                            {                                "category": {                                    "@id": "#6c5569e1-1c79-4957-95cb-8fd02689d06d"                                },                                "unit": {                                    "@id": "#88c3f216-fd84-4ffe-8b5d-a421724c3b49"                                },                                "value": 57.34090314485161                            }                        ],                        "name": "XOP4"                    },                    {                        "@id": "#source/139800003605792",                        "characteristics": [                            {                                "category": {                                    "@id": "#26fef18c-1c79-4e4e-96ce-2d8765afc722"                                },                                "value": {                                    "@id": "#72b28c48-141b-4c88-b1e0-a8e481d06bdd",                                    "annotationValue": "Homo sapiens",                                    "comments": [],                                    "termAccession": "http://purl.bioontology.org/ontology/NCBITAXON/9606",                                    "termSource": "NCBITAXON"                                }                            },                            {                                "category": {                                    "@id": "#3331bd7d-8692-4894-bb5e-0c7dd7832f61"                                },                                "value": "XOF5"                            },                            {                                "category": {                                    "@id": "#197ca9f9-db44-4e42-bdf2-3742f74e00ee"                                },                                "unit": {                                    "@id": "#16ee666d-6315-4009-ba1f-db09b120511a"                                },                                "value": 51.5151271117466                            }                        ],                        "name": "XOP5"                    },                    {                        "@id": "#source/139800003607904",                        "characteristics": [                            {                                "category": {                                    "@id": "#aab98f50-8f99-4bb1-9921-560326eadda8"                                },                                "value": {                                    "@id": "#053ad604-0a7a-499d-9776-fd9009535c19",                                    "annotationValue": "Homo sapiens",                                    "comments": [],                                    "termAccession": "http://purl.bioontology.org/ontology/NCBITAXON/9606",                                    "termSource": "NCBITAXON"                                }                            },                            {                                "category": {                                    "@id": "#8fce4a37-4679-4471-9af1-42016af915c0"                                },                                "value": "XOF6"                            },                            {                                "category": {                                    "@id": "#70a92f6c-a17d-4845-ab5f-ba6c23fb0a6c"                                },                                "unit": {                                    "@id": "#4b32a4cd-e4e5-4e57-957c-5ce1f1e46973"                                },                                "value": 63.99654416992958                            }                        ],                        "name": "XOP6"                    },                    {                        "@id": "#source/139800003602080",                        "characteristics": [                            {                                "category": {                                    "@id": "#647a28c4-21d5-4a41-b1cd-25f089dadd2e"                                },                                "value": {                                    "@id": "#9844c6c4-96b8-4c1e-a340-1dd20875f699",                                    "annotationValue": "Homo sapiens",                                    "comments": [],                                    "termAccession": "http://purl.bioontology.org/ontology/NCBITAXON/9606",                                    "termSource": "NCBITAXON"                                }                            },                            {                                "category": {                                    "@id": "#4407e54b-c7ad-40b1-9c3f-53a783b29154"                                },                                "value": "XOF7"                            },                            {                                "category": {                                    "@id": "#b3298e34-305f-4c47-b18e-7769d83b470c"                                },                                "unit": {                                    "@id": "#91c78f5e-2d69-47f9-a404-2cb54f9d853d"                                },                                "value": 57.34090314485161                            }                        ],                        "name": "XOP7"                    },                    {                        "@id": "#source/139800003604192",                        "characteristics": [                            {                                "category": {                                    "@id": "#85da355c-cef2-42c4-87f6-fddd65b42c91"                                },                                "value": {                                    "@id": "#54d0f2ff-788e-4c22-97e5-c7bce20e9782",                                    "annotationValue": "Homo sapiens",                                    "comments": [],                                    "termAccession": "http://purl.bioontology.org/ontology/NCBITAXON/9606",                                    "termSource": "NCBITAXON"                                }                            },                            {                                "category": {                                    "@id": "#91eab03f-b08c-4e24-9a19-e002fa7c5459"                                },                                "value": "XOF8"                            },                            {                                "category": {                                    "@id": "#9a4b61ad-e1c3-4d73-8196-b87431f987b9"                                },                                "unit": {                                    "@id": "#95fa741f-5786-4f42-af34-0915abd29390"                                },                                "value": 41.52999346520022                            }                        ],                        "name": "XOP8"                    },                    {                        "@id": "#source/139800003618560",                        "characteristics": [                            {                                "category": {                                    "@id": "#1da6a3a1-dfc8-402e-93a2-579bff12f4cb"                                },                                "value": {                                    "@id": "#8271a831-0496-493a-b006-adf714c1b6ce",                                    "annotationValue": "Homo sapiens",                                    "comments": [],                                    "termAccession": "http://purl.bioontology.org/ontology/NCBITAXON/9606",                                    "termSource": "NCBITAXON"                                }                            },                            {                                "category": {                                    "@id": "#c67685a2-42fd-44de-98f9-cfd2316668ae"                                },                                "value": "XOF9"                            },                            {                                "category": {                                    "@id": "#e40588e8-71d4-46a5-a976-ecece1a64dc6"                                },                                "unit": {                                    "@id": "#9ab68b71-f2cd-4b60-8350-e392b3e7d06b"                                },                                "value": 49.018843700110004                            }                        ],                        "name": "XOP9"                    },                    {                        "@id": "#source/139800003620720",                        "characteristics": [                            {                                "category": {                                    "@id": "#89f0614c-e27d-40d7-8391-92981c5b168f"                                },                                "value": {                                    "@id": "#89de3ab5-f600-4ea5-a763-dbbfe4da0092",                                    "annotationValue": "Homo sapiens",                                    "comments": [],                                    "termAccession": "http://purl.bioontology.org/ontology/NCBITAXON/9606",                                    "termSource": "NCBITAXON"                                }                            },                            {                                "category": {                                    "@id": "#6cfabb19-9f5e-4730-b396-38c0e20faea9"                                },                                "value": "XOF10"                            },                            {                                "category": {                                    "@id": "#6fce248c-c1cd-4747-9da8-9a7ad8c61a50"                                },                                "unit": {                                    "@id": "#449f3714-4744-425c-9741-51b1a42e9e3a"                                },                                "value": 61.451653734508696                            }                        ],                        "name": "XOP10"                    }                ]            },            "people": [],            "processSequence": [                {                    "@id": "#process/139800003580304",                    "comments": [],                    "date": "",                    "executesProtocol": {                        "@id": "#139800003787552"                    },                    "inputs": [                        {                            "@id": "#source/139800003549936"                        }                    ],                    "name": "urine_specimen_collection_process_XOP1",                    "outputs": [                        {                            "@id": "#sample/139800003550704"                        }                    ],                    "parameterValues": [                        {                            "category": {                                "@id": "#139800003788032"                            },                            "value": "urine"                        }                    ],                    "performer": ""                },                {                    "@id": "#process/139800003580880",                    "comments": [],                    "date": "",                    "executesProtocol": {                        "@id": "#139800003787552"                    },                    "inputs": [                        {                            "@id": "#source/139800003549936"                        }                    ],                    "name": "buccal_specimen_collection_process_XOP1",                    "outputs": [                        {                            "@id": "#sample/139800003580448"                        }                    ],                    "parameterValues": [                        {                            "category": {                                "@id": "#139800003788032"                            },                            "value": "buccal mucosa"                        }                    ],                    "performer": ""                },                {                    "@id": "#process/139800003582608",                    "comments": [],                    "date": "",                    "executesProtocol": {                        "@id": "#139800003787552"                    },                    "inputs": [                        {                            "@id": "#source/139800003549888"                        }                    ],                    "name": "urine_specimen_collection_process_XOP2",                    "outputs": [                        {                            "@id": "#sample/139800003581792"                        }                    ],                    "parameterValues": [                        {                            "category": {                                "@id": "#139800003788032"                            },                            "value": "urine"                        }                    ],                    "performer": ""                },                {                    "@id": "#process/139800003583088",                    "comments": [],                    "date": "",                    "executesProtocol": {                        "@id": "#139800003787552"                    },                    "inputs": [                        {                            "@id": "#source/139800003549888"                        }                    ],                    "name": "buccal_specimen_collection_process_XOP2",                    "outputs": [                        {                            "@id": "#sample/139800003582704"                        }                    ],                    "parameterValues": [                        {                            "category": {                                "@id": "#139800003788032"                            },                            "value": "buccal mucosa"                        }                    ],                    "performer": ""                },                {                    "@id": "#process/139800003605168",                    "comments": [],                    "date": "",                    "executesProtocol": {                        "@id": "#139800003787552"                    },                    "inputs": [                        {                            "@id": "#source/139800003580928"                        }                    ],                    "name": "urine_specimen_collection_process_XOP3",                    "outputs": [                        {                            "@id": "#sample/139800003604592"                        }                    ],                    "parameterValues": [                        {                            "category": {                                "@id": "#139800003788032"                            },                            "value": "urine"                        }                    ],                    "performer": ""                },                {                    "@id": "#process/139800003605744",                    "comments": [],                    "date": "",                    "executesProtocol": {                        "@id": "#139800003787552"                    },                    "inputs": [                        {                            "@id": "#source/139800003580928"                        }                    ],                    "name": "buccal_specimen_collection_process_XOP3",                    "outputs": [                        {                            "@id": "#sample/139800003605312"                        }                    ],                    "parameterValues": [                        {                            "category": {                                "@id": "#139800003788032"                            },                            "value": "buccal mucosa"                        }                    ],                    "performer": ""                },                {                    "@id": "#process/139800003607328",                    "comments": [],                    "date": "",                    "executesProtocol": {                        "@id": "#139800003787552"                    },                    "inputs": [                        {                            "@id": "#source/139800003583136"                        }                    ],                    "name": "urine_specimen_collection_process_XOP4",                    "outputs": [                        {                            "@id": "#sample/139800003606704"                        }                    ],                    "parameterValues": [                        {                            "category": {                                "@id": "#139800003788032"                            },                            "value": "urine"                        }                    ],                    "performer": ""                },                {                    "@id": "#process/139800003607856",                    "comments": [],                    "date": "",                    "executesProtocol": {                        "@id": "#139800003787552"                    },                    "inputs": [                        {                            "@id": "#source/139800003583136"                        }                    ],                    "name": "buccal_specimen_collection_process_XOP4",                    "outputs": [                        {                            "@id": "#sample/139800003607424"                        }                    ],                    "parameterValues": [                        {                            "category": {                                "@id": "#139800003788032"                            },                            "value": "buccal mucosa"                        }                    ],                    "performer": ""                },                {                    "@id": "#process/139800003601264",                    "comments": [],                    "date": "",                    "executesProtocol": {                        "@id": "#139800003787552"                    },                    "inputs": [                        {                            "@id": "#source/139800003605792"                        }                    ],                    "name": "urine_specimen_collection_process_XOP5",                    "outputs": [                        {                            "@id": "#sample/139800003600640"                        }                    ],                    "parameterValues": [                        {                            "category": {                                "@id": "#139800003788032"                            },                            "value": "urine"                        }                    ],                    "performer": ""                },                {                    "@id": "#process/139800003601936",                    "comments": [],                    "date": "",                    "executesProtocol": {                        "@id": "#139800003787552"                    },                    "inputs": [                        {                            "@id": "#source/139800003605792"                        }                    ],                    "name": "buccal_specimen_collection_process_XOP5",                    "outputs": [                        {                            "@id": "#sample/139800003601504"                        }                    ],                    "parameterValues": [                        {                            "category": {                                "@id": "#139800003788032"                            },                            "value": "buccal mucosa"                        }                    ],                    "performer": ""                },                {                    "@id": "#process/139800003603520",                    "comments": [],                    "date": "",                    "executesProtocol": {                        "@id": "#139800003787552"                    },                    "inputs": [                        {                            "@id": "#source/139800003607904"                        }                    ],                    "name": "urine_specimen_collection_process_XOP6",                    "outputs": [                        {                            "@id": "#sample/139800003600592"                        }                    ],                    "parameterValues": [                        {                            "category": {                                "@id": "#139800003788032"                            },                            "value": "urine"                        }                    ],                    "performer": ""                },                {                    "@id": "#process/139800003604144",                    "comments": [],                    "date": "",                    "executesProtocol": {                        "@id": "#139800003787552"                    },                    "inputs": [                        {                            "@id": "#source/139800003607904"                        }                    ],                    "name": "buccal_specimen_collection_process_XOP6",                    "outputs": [                        {                            "@id": "#sample/139800003603664"                        }                    ],                    "parameterValues": [                        {                            "category": {                                "@id": "#139800003788032"                            },                            "value": "buccal mucosa"                        }                    ],                    "performer": ""                },                {                    "@id": "#process/139800003617936",                    "comments": [],                    "date": "",                    "executesProtocol": {                        "@id": "#139800003787552"                    },                    "inputs": [                        {                            "@id": "#source/139800003602080"                        }                    ],                    "name": "urine_specimen_collection_process_XOP7",                    "outputs": [                        {                            "@id": "#sample/139800003617216"                        }                    ],                    "parameterValues": [                        {                            "category": {                                "@id": "#139800003788032"                            },                            "value": "urine"                        }                    ],                    "performer": ""                },                {                    "@id": "#process/139800003618512",                    "comments": [],                    "date": "",                    "executesProtocol": {                        "@id": "#139800003787552"                    },                    "inputs": [                        {                            "@id": "#source/139800003602080"                        }                    ],                    "name": "buccal_specimen_collection_process_XOP7",                    "outputs": [                        {                            "@id": "#sample/139800003618080"                        }                    ],                    "parameterValues": [                        {                            "category": {                                "@id": "#139800003788032"                            },                            "value": "buccal mucosa"                        }                    ],                    "performer": ""                },                {                    "@id": "#process/139800003620096",                    "comments": [],                    "date": "",                    "executesProtocol": {                        "@id": "#139800003787552"                    },                    "inputs": [                        {                            "@id": "#source/139800003604192"                        }                    ],                    "name": "urine_specimen_collection_process_XOP8",                    "outputs": [                        {                            "@id": "#sample/139800003617120"                        }                    ],                    "parameterValues": [                        {                            "category": {                                "@id": "#139800003788032"                            },                            "value": "urine"                        }                    ],                    "performer": ""                },                {                    "@id": "#process/139800003620672",                    "comments": [],                    "date": "",                    "executesProtocol": {                        "@id": "#139800003787552"                    },                    "inputs": [                        {                            "@id": "#source/139800003604192"                        }                    ],                    "name": "buccal_specimen_collection_process_XOP8",                    "outputs": [                        {                            "@id": "#sample/139800003620240"                        }                    ],                    "parameterValues": [                        {                            "category": {                                "@id": "#139800003788032"                            },                            "value": "buccal mucosa"                        }                    ],                    "performer": ""                },                {                    "@id": "#process/139800003646896",                    "comments": [],                    "date": "",                    "executesProtocol": {                        "@id": "#139800003787552"                    },                    "inputs": [                        {                            "@id": "#source/139800003618560"                        }                    ],                    "name": "urine_specimen_collection_process_XOP9",                    "outputs": [                        {                            "@id": "#sample/139800003646176"                        }                    ],                    "parameterValues": [                        {                            "category": {                                "@id": "#139800003788032"                            },                            "value": "urine"                        }                    ],                    "performer": ""                },                {                    "@id": "#process/139800003647472",                    "comments": [],                    "date": "",                    "executesProtocol": {                        "@id": "#139800003787552"                    },                    "inputs": [                        {                            "@id": "#source/139800003618560"                        }                    ],                    "name": "buccal_specimen_collection_process_XOP9",                    "outputs": [                        {                            "@id": "#sample/139800003647040"                        }                    ],                    "parameterValues": [                        {                            "category": {                                "@id": "#139800003788032"                            },                            "value": "buccal mucosa"                        }                    ],                    "performer": ""                },                {                    "@id": "#process/139800003649056",                    "comments": [],                    "date": "",                    "executesProtocol": {                        "@id": "#139800003787552"                    },                    "inputs": [                        {                            "@id": "#source/139800003620720"                        }                    ],                    "name": "urine_specimen_collection_process_XOP10",                    "outputs": [                        {                            "@id": "#sample/139800003646080"                        }                    ],                    "parameterValues": [                        {                            "category": {                                "@id": "#139800003788032"                            },                            "value": "urine"                        }                    ],                    "performer": ""                },                {                    "@id": "#process/139800003657888",                    "comments": [],                    "date": "",                    "executesProtocol": {                        "@id": "#139800003787552"                    },                    "inputs": [                        {                            "@id": "#source/139800003620720"                        }                    ],                    "name": "buccal_specimen_collection_process_XOP10",                    "outputs": [                        {                            "@id": "#sample/139800003649200"                        }                    ],                    "parameterValues": [                        {                            "category": {                                "@id": "#139800003788032"                            },                            "value": "buccal mucosa"                        }                    ],                    "performer": ""                }            ],            "protocols": [                {                    "@id": "#139800003787552",                    "comments": [],                    "components": [],                    "description": "",                    "name": "sample collection",                    "parameters": [                        {                            "@id": "#139800003788032",                            "parameterName": {                                "@id": "#be88a601-a35d-4f42-933f-e6ba88103042",                                "annotationValue": "anatomical entity",                                "comments": [],                                "termAccession": "http://purl.obolibrary.org/obo/UBERON_0001062",                                "termSource": "UBERON"                            }                        }                    ],                    "protocolType": {                        "@id": "#818e296a-fd72-438e-a0a8-3d9dea7c5a5f",                        "annotationValue": "sample collection",                        "comments": [],                        "termAccession": "",                        "termSource": ""                    },                    "uri": "",                    "version": ""                },                {                    "@id": "#139800004215568",                    "comments": [],                    "components": [],                    "description": "",                    "name": "DNA extraction",                    "parameters": [],                    "protocolType": {                        "@id": "#34a296a5-36dc-456a-bab0-ba2ceed00be3",                        "annotationValue": "DNA extraction",                        "comments": [],                        "termAccession": "http://purl.obolibrary.org/obo/OBI_0000257",                        "termSource": "OBI"                    },                    "uri": "",                    "version": ""                },                {                    "@id": "#139800004215280",                    "comments": [],                    "components": [],                    "description": "",                    "name": "genotype profiling",                    "parameters": [],                    "protocolType": {                        "@id": "#4446bbb3-c12d-4e3d-9dc5-79578c28538c",                        "annotationValue": "genotyping",                        "comments": [],                        "termAccession": "http://www.ebi.ac.uk/efo/EFO_0000750",                        "termSource": "EFO"                    },                    "uri": "",                    "version": ""                },                {                    "@id": "#139800003787312",                    "comments": [],                    "components": [],                    "description": "",                    "name": "DNA extraction",                    "parameters": [],                    "protocolType": {                        "@id": "#e0166921-ee27-4c3d-b402-908396aa55f4",                        "annotationValue": "DNA extraction",                        "comments": [],                        "termAccession": "http://purl.obolibrary.org/obo/OBI_0000257",                        "termSource": "OBI"                    },                    "uri": "",                    "version": ""                },                {                    "@id": "#139800004216912",                    "comments": [],                    "components": [],                    "description": "",                    "name": "methylation profiling",                    "parameters": [],                    "protocolType": {                        "@id": "#4478adf6-c39c-4625-b9d6-c60c31cbaee4",                        "annotationValue": "methylation profiling",                        "comments": [],                        "termAccession": "http://www.ebi.ac.uk/efo/EFO_0000751",                        "termSource": "EFO"                    },                    "uri": "",                    "version": ""                },                {                    "@id": "#139800004215376",                    "comments": [],                    "components": [],                    "description": "Sinke, Lucy, van Iterson, Maarten, Cats, Davy, Slieker, Roderick, ': '',
  ' Heijmans, Bas. (2019, July 11). DNAmArray: Streamlined workflow for the quality control, normalization, and analysis of Illumina methylation array data (Version 2.1). Zenodo. http://doi.org/10.5281/zenodo.3355292",                    "name": "methylation data processing protocol",                    "parameters": [],                    "protocolType": {                        "@id": "#209ba20b-1b5d-4fd4-a50c-757ba0d5c620",                        "annotationValue": "Protocol",                        "comments": [],                        "termAccession": "http://edamontology.org/data_2531",                        "termSource": "EDAM"                    },                    "uri": "http://doi.org/10.5281/zenodo.3355292",                    "version": ""                },                {                    "@id": "#139800003742928",                    "comments": [],                    "components": [],                    "description": "",                    "name": "urine sampling",                    "parameters": [],                    "protocolType": {                        "@id": "#985900d4-dba5-4109-9d4a-18fb06d47361",                        "annotationValue": "urine speciment collection",                        "comments": [],                        "termAccession": "http://snomed.info/id/57617002",                        "termSource": ""                    },                    "uri": "",                    "version": ""                }            ],            "publicReleaseDate": "",            "publications": [],            "studyDesignDescriptors": [],            "submissionDate": "",            "title": "X-omics data analysis, integration and stewardship demonstrator dataset: NTR ACTION omics data",            "unitCategories": []        }    ],    "submissionDate": "",    "title": "X-omics data analysis, integration and stewardship demonstrator dataset: NTR ACTION omics data"}': ''
}

response = requests.post('https://fdp.x-omics.nl/dataset', headers=headers, data=data)
print(response)
print(response.text)
# Out:
# <Response [400]>
# Unable to read RDF (parse exception)

# %%
################## 
# use with caution
##################

# 9 Mar,2022
# this cell delete from fdp.x-omics.nl the datasets which were previously uploaded


import requests
import json


headers = {
    'accept': 'application/ld+json',
    'Authorization': 'Bearer eyJhbGciOiJIUzI1NiJ9.eyJzdWIiOiI3ZTY0ODE4ZC02Mjc2LTQ2ZmItOGJiMS03MzJlNmUwOWY3ZTkiLCJpYXQiOjE2NDY1MTk4NDMsImV4cCI6MTY0NzcyOTQ0M30.lmRXSYK_XyFWSkj0LMXdBFcwill-vg169hyEDJr3pyc',
}

response = requests.get('https://fdp.x-omics.nl/catalog/c6c73d4f-97bb-40e7-9068-e1eeadf1f2a4', headers=headers)
json_data = json.loads(response.text)
#print(response.text)
print(type(json_data))
#print(json_data)
print(type(json_data[2]))
#print(json_data[2])
for dataset in json_data[2]['http://www.w3.org/ns/dcat#dataset']:
#     print(type(dataset))
#     print(dataset['@id'])
    url = dataset['@id']
    print(type(url))
    print()

    headers = {
        'accept': '*/*',
        'Authorization': 'Bearer eyJhbGciOiJIUzI1NiJ9.eyJzdWIiOiI3ZTY0ODE4ZC02Mjc2LTQ2ZmItOGJiMS03MzJlNmUwOWY3ZTkiLCJpYXQiOjE2NDY1MTk4NDMsImV4cCI6MTY0NzcyOTQ0M30.lmRXSYK_XyFWSkj0LMXdBFcwill-vg169hyEDJr3pyc',
    }
    response = requests.delete(url, headers=headers)
